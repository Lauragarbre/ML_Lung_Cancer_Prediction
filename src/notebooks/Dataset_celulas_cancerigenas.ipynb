# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/lauragarcia/Projects/ML_Lung_Cancer_Prediction/src/data_sample/cancer patient data sets.csv')
df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                       4             3                     2  ...        3
# 1                       3             4                     2  ...        1
# 2                       5             5                     4  ...        8
# 3                       7             6                     7  ...        4
# 4                       7             7                     6  ...        3
# ..                    ...           ...                   ...  ...      ...
# 995                     7             7                     6  ...        5
# 996                     7             7                     6  ...        9
# 997                     5             5                     4  ...        8
# 998                     7             7                     6  ...        3
# 999                     5             5                     4  ...        8
#
#      Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0              4                    2         2                      3
# 1              3                    7         8                      6
# 2              7                    9         2                      1
# 3              2                    3         1                      4
# 4              2                    4         1                      4
# ..           ...                  ...       ...                    ...
# 995            3                    2         7                      8
# 996            6                    5         7                      2
# 997            7                    9         2                      1
# 998            2                    4         1                      4
# 999            7                    9         2                      1
#
#      Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                           1              2          3        4     Low
# 1                           2              1          7        2  Medium
# 2                           4              6          7        2    High
# 3                           5              6          7        5    High
# 4                           2              4          2        3    High
# ..                        ...            ...        ...      ...     ...
# 995                         2              4          5        3    High
# 996                         4              3          1        4    High
# 997                         4              6          7        2    High
# 998                         2              4          2        3    High
# 999                         4              6          7        2    High
#
# [1000 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1000 non-null   int64
#  1   Patient Id                1000 non-null   object
#  2   Age                       1000 non-null   int64
#  3   Gender                    1000 non-null   int64
#  4   Air Pollution             1000 non-null   int64
#  5   Alcohol use               1000 non-null   int64
#  6   Dust Allergy              1000 non-null   int64
#  7   OccuPational Hazards      1000 non-null   int64
#  8   Genetic Risk              1000 non-null   int64
#  9   chronic Lung Disease      1000 non-null   int64
#  10  Balanced Diet             1000 non-null   int64
#  11  Obesity                   1000 non-null   int64
#  12  Smoking                   1000 non-null   int64
#  13  Passive Smoker            1000 non-null   int64
#  14  Chest Pain                1000 non-null   int64
#  15  Coughing of Blood         1000 non-null   int64
#  16  Fatigue                   1000 non-null   int64
#  17  Weight Loss               1000 non-null   int64
#  18  Shortness of Breath       1000 non-null   int64
#  19  Wheezing                  1000 non-null   int64
#  20  Swallowing Difficulty     1000 non-null   int64
#  21  Clubbing of Finger Nails  1000 non-null   int64
#  22  Frequent Cold             1000 non-null   int64
#  23  Dry Cough                 1000 non-null   int64
#  24  Snoring                   1000 non-null   int64
#  25  Level                     1000 non-null   object
# dtypes: int64(24), object(2)
# memory usage: 203.3+ KB

# %%
df.describe().T
# Out:
#                            count     mean         std   min     25%    50%  \
# index                     1000.0  499.500  288.819436   0.0  249.75  499.5
# Age                       1000.0   37.174   12.005493  14.0   27.75   36.0
# Gender                    1000.0    1.402    0.490547   1.0    1.00    1.0
# Air Pollution             1000.0    3.840    2.030400   1.0    2.00    3.0
# Alcohol use               1000.0    4.563    2.620477   1.0    2.00    5.0
# Dust Allergy              1000.0    5.165    1.980833   1.0    4.00    6.0
# OccuPational Hazards      1000.0    4.840    2.107805   1.0    3.00    5.0
# Genetic Risk              1000.0    4.580    2.126999   1.0    2.00    5.0
# chronic Lung Disease      1000.0    4.380    1.848518   1.0    3.00    4.0
# Balanced Diet             1000.0    4.491    2.135528   1.0    2.00    4.0
# Obesity                   1000.0    4.465    2.124921   1.0    3.00    4.0
# Smoking                   1000.0    3.948    2.495902   1.0    2.00    3.0
# Passive Smoker            1000.0    4.195    2.311778   1.0    2.00    4.0
# Chest Pain                1000.0    4.438    2.280209   1.0    2.00    4.0
# Coughing of Blood         1000.0    4.859    2.427965   1.0    3.00    4.0
# Fatigue                   1000.0    3.856    2.244616   1.0    2.00    3.0
# Weight Loss               1000.0    3.855    2.206546   1.0    2.00    3.0
# Shortness of Breath       1000.0    4.240    2.285087   1.0    2.00    4.0
# Wheezing                  1000.0    3.777    2.041921   1.0    2.00    4.0
# Swallowing Difficulty     1000.0    3.746    2.270383   1.0    2.00    4.0
# Clubbing of Finger Nails  1000.0    3.923    2.388048   1.0    2.00    4.0
# Frequent Cold             1000.0    3.536    1.832502   1.0    2.00    3.0
# Dry Cough                 1000.0    3.853    2.039007   1.0    2.00    4.0
# Snoring                   1000.0    2.926    1.474686   1.0    2.00    3.0
#
#                              75%    max
# index                     749.25  999.0
# Age                        45.00   73.0
# Gender                      2.00    2.0
# Air Pollution               6.00    8.0
# Alcohol use                 7.00    8.0
# Dust Allergy                7.00    8.0
# OccuPational Hazards        7.00    8.0
# Genetic Risk                7.00    7.0
# chronic Lung Disease        6.00    7.0
# Balanced Diet               7.00    7.0
# Obesity                     7.00    7.0
# Smoking                     7.00    8.0
# Passive Smoker              7.00    8.0
# Chest Pain                  7.00    9.0
# Coughing of Blood           7.00    9.0
# Fatigue                     5.00    9.0
# Weight Loss                 6.00    8.0
# Shortness of Breath         6.00    9.0
# Wheezing                    5.00    8.0
# Swallowing Difficulty       5.00    8.0
# Clubbing of Finger Nails    5.00    9.0
# Frequent Cold               5.00    7.0
# Dry Cough                   6.00    7.0
# Snoring                     4.00    7.0

# %%
# Buscando valores nulos
df.isnull().sum()
# Out:
# index                       0
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
# Aparentemente no hay nulos y los datos están ya estandarizados, salvo la edad
# Voy a buscar información por si hubiera escalas a las que hace referencia esta standarización.
# Tras buscar datos de todas las varibles, no existe una ctegorización como tal de las mismas. De hecho la mayoría se categorizan como leve, moderada severa.
# Sólamente en riesgos laborales he encontrado una categorización en 7 riesgos, pero no creo que tenga mucho sentido, ya que son el tipo de riesgo y no una calificación de poco a mucho rriesgo que parece que es la tendecncia del resto de variables.
# En cuanto a la obesidad. Existen 4 grados junto al sobrepeso, si le añadimos las otras dos categorizaciones que hace la OMS, que son normopeso y bajo peso, tendríamos las 7. En este caso el 1 seria bajo peso y el 7 obesidad extrema.
# en cuanto al género, no he encontrado ninguna información, pero por otros datasets e informaciones leidas parece que 1 es mujer y 2 es hombre.

# %%
# Antes de nada voy a eiminar las columnas que no me sirven para nada como el index o el pacient Id
df.drop('index', axis= 1, inplace= True)
df.drop('Patient Id', axis= 1, inplace= True )
df
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# 2                       5             5                     4              6
# 3                       7             6                     7              7
# 4                       7             7                     6              7
# ..                    ...           ...                   ...            ...
# 995                     7             7                     6              7
# 996                     7             7                     6              7
# 997                     5             5                     4              6
# 998                     7             7                     6              7
# 999                     5             5                     4              6
#
#      Obesity  ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# 0          4  ...        3            4                    2         2
# 1          2  ...        1            3                    7         8
# 2          7  ...        8            7                    9         2
# 3          7  ...        4            2                    3         1
# 4          7  ...        3            2                    4         1
# ..       ...  ...      ...          ...                  ...       ...
# 995        7  ...        5            3                    2         7
# 996        7  ...        9            6                    5         7
# 997        7  ...        8            7                    9         2
# 998        7  ...        3            2                    4         1
# 999        7  ...        8            7                    9         2
#
#      Swallowing Difficulty  Clubbing of Finger Nails  Frequent Cold  \
# 0                        3                         1              2
# 1                        6                         2              1
# 2                        1                         4              6
# 3                        4                         5              6
# 4                        4                         2              4
# ..                     ...                       ...            ...
# 995                      8                         2              4
# 996                      2                         4              3
# 997                      1                         4              6
# 998                      4                         2              4
# 999                      1                         4              6
#
#      Dry Cough  Snoring   Level
# 0            3        4     Low
# 1            7        2  Medium
# 2            7        2    High
# 3            7        5    High
# 4            2        3    High
# ..         ...      ...     ...
# 995          5        3    High
# 996          1        4    High
# 997          7        2    High
# 998          2        3    High
# 999          7        2    High
#
# [1000 rows x 24 columns]

# %%
# Con la información preliminar que tenemos todas las variables son de tipo int, salvo Level que es de tipo object.

# %%
# El problema de negocio es intentar predecir a qué nivel o estadio de cáncer pertenece cada paciente con sus carácterísticas o síntomas clínicos.
# Es por tanto un problema de clasifficación. En este caso sería multiclase, ya que nuestra target seria Level y tiene tres valores : Low, Medium y High.
target = df['Level']

# %%
target.value_counts()
# Out:
# Level
# High      365
# Medium    332
# Low       303
# Name: count, dtype: int64

# %%
# Voy a ver cómo está distribuida la variable target
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,5))
sizes = target.value_counts()
labels = sizes.index
plt.pie(sizes.values,labels=labels,autopct='%.2f%%')
plt.legend(target)
plt.show()

# %%
# Parece que nuestra target está bastante balanceada, aspecto que es bastante bueno.
# Una vez visto esto, voy a hacer el train/test split estratificaré con la target para que estén distribuidas homogéneamente las 3 categorias

from sklearn.model_selection import train_test_split
target = 'Level'
train_set, test_set = train_test_split( df, test_size = 20, stratify = df[target], random_state = 42)

# %%
# Valorar la opcion de hacer otra partición para tener validation

# %%
# Voy a comprobar si han quedado estratificadas similarmente
train_set[target].value_counts()/len(train_set) *100
# Out:
# Level
# High      36.530612
# Medium    33.163265
# Low       30.306122
# Name: count, dtype: float64

# %%
test_set[target].value_counts()/len(test_set) *100
# Out:
# Level
# Medium    35.0
# High      35.0
# Low       30.0
# Name: count, dtype: float64

# %%
# Están similares los balanceos

# %%
# Pasamos al mini EDA
# Voy a realizar un análisis visual de las posibles features frente a la target para determinar si existe relación con ella, o no. No voy a usar un pairplot porque son muchísimas variables. Asi que haré de manera individual (variable por variable contra target)
# Target vs genero
sns.catplot( x= "Level", 
            hue = "Gender",
            kind= "count", 
            edgecolor = ".6",
            orient = "v",
            data = train_set.sort_values("Level"));

# %%
# Salvo en los niveles altos, parece que el género no es un determinante

# %%
# Target vs age
sns.boxplot(x = "Level",
            y = "Age",
            hue = "Level",
            data = train_set);

# %%
# En cuanto a a la edad, las tres gráficas son similares, sí que se ve un outlier en el caso medio, habría que revisar si el dato está bien. Revisando las estadisticas la edad máxima del estudio son 73 años que se corresponde con este outlier

# %%
# Target vs Air Pollution
sns.boxplot(x = "Level",
            y = "Air Pollution",
            hue = "Level",
            data = train_set);

# %%
# En este caso ya observamos diferencias en relación a los tres niveles

# %%
# Target vs Alcohol use
sns.boxplot(x = "Level",
            y = "Alcohol use",
            hue = "Level",
            data = train_set);

# %%
# En esta vaiable podemmos observar que parece que salvo algunos outliers que hay porr ahí a mayor consumo de alcohol, mayor nivel de "daño"

# %%
#Target vs Dust Allergy
sns.boxplot(x = "Level",
            y = "Dust Allergy",
            hue = "Level",
            data = train_set);

# %%
# Aparentemente también existe una relación, a mayor nivel de alergía al polvo, más "daño"

# %%
# Target vs Occupational Hazzards
sns.boxplot(x = "Level",
            y = "OccuPational Hazards",
            hue = "Level",
            data = train_set);

# %%
# Distribución similar a la anterior

# %%
# Target vs Genetic risk
sns.boxplot(x = "Level",
            y = "Genetic Risk",
            hue = "Level",
            data = train_set);

# %%
# Parece que si hay relación, aunque el "daño meddio" afecta tanto a personas con bajo riesgo como de alto riesgo genético

# %%
# Target vs Chronic Lung Disease
sns.boxplot(x = "Level",
            y = "chronic Lung Disease",
            hue = "Level",
            data = train_set);

# %%
# Aparentemente pueden estar relacionadas

# %%
# Target vs Balanced Diet
sns.boxplot(x = "Level",
            y = "Balanced Diet",
            hue = "Level",
            data = train_set);

# %%
# De primeras parece que la dieta también influye en un mayor o menor grado de "daño", aunque hay de todo

# %%
# Target vs Obesity 
sns.boxplot(x = "Level",
            y = "Obesity",
            hue = "Level",
            data = train_set);

# %%
# Parece que tiene cierta relación

# %%
# Target vs Smoking
sns.boxplot(x = "Level",
            y = "Smoking",
            hue = "Level",
            data = train_set);

# %%
# Esta gráfica es más dispar. Parece que cuando el daño el elevado si que hay relación con el grado de tabaquismo, pero en el medio y bajo no afecta tanto (es interesante)

# %%
# Target vs Passive Smoker
sns.boxplot(x = "Level",
            y = "Passive Smoker",
            hue = "Level",
            data = train_set);

# %%
# Aquí la distribución también es curiosa, para fumadores pasivos muy expuestos, parece que su daño es más alto. En el caso de fumadores pasivos leves o medios, el daño es similar para medio y bajo

# %%
# Target vs Chest Pain
sns.boxplot(x = "Level",
            y = "Chest Pain",
            hue = "Level",
            data = train_set);

# %%
# Similar a la anterior

# %%
# Target vs Coughing of Blood
sns.boxplot(x = "Level",
            y = "Coughing of Blood",
            hue = "Level",
            data = train_set);

# %%
# En esta variable si que parece tener algo más de relación con el target

# %%
# Target vs Fatigue
sns.boxplot(x = "Level",
            y = "Fatigue",
            hue = "Level",
            data = train_set);

# %%
# La fatiga si que parece tener una relación directa con la gravedad del daño. A mayor daño, mayor fatiga.

# %%
# Target vs Weight Loos
sns.boxplot(x = "Level",
            y = "Weight Loss",
            hue = "Level",
            data = train_set);

# %%
# No parecen tener mucha relación, al menos directa

# %%
# Target vs Shortness of Breathe
sns.boxplot(x = "Level",
            y = "Shortness of Breath",
            hue = "Level",
            data = train_set);

# %%
# La disnea o dificultad respiratoria si que tiene relación directa con el grado de daño

# %%
# Target vs Wheezing
sns.boxplot(x = "Level",
            y = "Wheezing",
            hue = "Level",
            data = train_set);

# %%
# La sibilación ( que suele estar relacionada con el asma), no parece tener tanta relación con el grado de daño en este cáncer

# %%
# Target vs Swallowing Difficulty
sns.boxplot(x = "Level",
            y = "Swallowing Difficulty",
            hue = "Level",
            data = train_set);

# %%
# Aquí tampoco veo una relación como tal. Todos los grados de daño se ven afectados de manera similar por la disfagia.

# %%
# Target vs Clubbing of Finger Nails
sns.boxplot(x = "Level",
            y = "Clubbing of Finger Nails",
            hue = "Level",
            data = train_set);

# %%
# Los dedos en palillo de tambor (que al parecer puede ser un signo de diagnóstico en emfermedades pulmonares o cardiacas entre otros), en este caso no parece tener una relación directa. Parece que afecta algo más a los casos de daño medio, pero los de bajo daño y alto daño también lo tienen.

# %%
# Target vs Frequent Cold
sns.boxplot(x = "Level",
            y = "Frequent Cold",
            hue = "Level",
            data = train_set);

# %%
# En esta variable, la frecuencia de padecer catarros aparentemente no tiene una relación muy directa con los grados de daño del cáncer.

# %%
# Target vs Dry Cough
sns.boxplot(x = "Level",
            y = "Dry Cough",
            hue = "Level",
            data = train_set);

# %%
# En cuanto a la tos seca, parece que si hay una relación con la gravedad del daño, aunque puede ser discreta.

# %%
# Target vs Snoring
sns.boxplot(x = "Level",
            y = "Snoring",
            hue = "Level",
            data = train_set);

# %%
# En relación a los ronquidos, podría intuirse una ligera relación, pero no me queda del todo clara.

# %%
# Debido a que el análisis visual de todas las variables frente al target, en algunos casos no deja clara esa posible relación, voy a realizar análisis matemáticos para poder ver con datos numéricos esa posible relación.

# %%
# Nuestras variables son categóricas aunque su dtype sea int, se podrían tratar como variables numéricas, y por los datos que tenemos y la presentación de los mismos, podría inferir que son numéricas contínuas. 
# Sin embargo, voy a tratarlas como categóricas y realizar test Chi cuadrado con nuestra target para ver la posible relación entre variables y target.
# Primero creo una lista con las variables categoricas
features_cat = train_set.columns.to_list()
features_cat.remove(target) # quito la target
features_cat.remove('Age') # quito la única numérica que tenemos
features_cat
# Out:
# ['Gender',
#  'Air Pollution',
#  'Alcohol use',
#  'Dust Allergy',
#  'OccuPational Hazards',
#  'Genetic Risk',
#  'chronic Lung Disease',
#  'Balanced Diet',
#  'Obesity',
#  'Smoking',
#  'Passive Smoker',
#  'Chest Pain',
#  'Coughing of Blood',
#  'Fatigue',
#  'Weight Loss',
#  'Shortness of Breath',
#  'Wheezing',
#  'Swallowing Difficulty',
#  'Clubbing of Finger Nails',
#  'Frequent Cold',
#  'Dry Cough',
#  'Snoring']

# %%
# Nuestra una feature numérica es edad
feature_num = train_set['Age']

# %%
# Ahora hago la prueba de chi-cuadrado para las variables categóricas y ver qué correlación tienen
from scipy.stats import chi2_contingency

target_col = train_set[target] # asigno nuestra target
p_value = 0.05 # asigno el valor de p_value para aceptar o rechazar la hipótesis nula
listado_features = [] # lista vacío dónde iré añadiendo las features que tengan releción con mi target 
listado_p_value = []
for col in train_set[features_cat].columns:
            tabla = pd.crosstab (train_set[col], target_col) 
            resultado_test = chi2_contingency(tabla)
            if resultado_test[1] < p_value:
                listado_features.append(col)
                listado_p_value.append(resultado_test[1])

# %%
# Ya tengo guardadas las features relacionadas con la target y sus p_value (features categoricas)

# %%
# Hacemos un test ANOVA para la edad
from scipy import stats
#target_cat = 'Level'
level_cat = train_set[target].unique()  # Obtener los valores únicos de la columna categórica,
age_for_level = [train_set[train_set[target] == categoria]['Age'] for categoria in level_cat] # obtenemos la edad por cada nivel de daño y los incluimos en una lista

# %%
f_val, p_val = stats.f_oneway(*age_for_level) 
print("Valor F:", f_val)
print("Valor p:", p_val)
# Out:
# Valor F: 6.111818745192272
# Valor p: 0.0023021749243392767

# %%
# Añadimos la edad a nuestro listado, puesto que p_val es < que p_value y hacemos un dataframe
listado_features.append('Age')
listado_p_value.append(p_val)
stadistic_df = pd.DataFrame( {'Features': listado_features, 'p_value': listado_p_value})
stadistic_df = stadistic_df.sort_values(by='p_value').reset_index(drop=True) # ordeno de mayor a menor importancia las features
print(stadistic_df)
# Out:
#                     Features        p_value
# 0          Coughing of Blood  3.811491e-206
# 1                    Obesity  1.043678e-196
# 2             Passive Smoker  6.402755e-195
# 3                   Wheezing  2.551694e-176
# 4                 Chest Pain  3.808708e-173
# 5                Alcohol use  4.148720e-173
# 6        Shortness of Breath  4.408441e-163
# 7              Balanced Diet  4.102820e-156
# 8               Dust Allergy  1.436697e-143
# 9       OccuPational Hazards  6.009067e-137
# 10                   Smoking  1.458214e-134
# 11                   Fatigue  2.310933e-130
# 12             Air Pollution  3.487271e-129
# 13              Genetic Risk  1.958855e-124
# 14      chronic Lung Disease  3.991984e-114
# 15             Frequent Cold   3.397731e-91
# 16  Clubbing of Finger Nails   2.306454e-86
# 17                 Dry Cough   1.251395e-78
# 18               Weight Loss   1.191414e-67
# 19     Swallowing Difficulty   1.059162e-44
# 20                   Snoring   8.841331e-34
# 21                    Gender   1.728489e-06
# 22                       Age   2.302175e-03

# %%
# Según la prueba de chi-cuadrado y el ANOVA parece que todas las variables tienen algo de relación con el target
# Voy a sacar listado
features_stad = stadistic_df['Features'].to_list()
features_stad
# Out:
# ['Coughing of Blood',
#  'Obesity',
#  'Passive Smoker',
#  'Wheezing',
#  'Chest Pain',
#  'Alcohol use',
#  'Shortness of Breath',
#  'Balanced Diet',
#  'Dust Allergy',
#  'OccuPational Hazards',
#  'Smoking',
#  'Fatigue',
#  'Air Pollution',
#  'Genetic Risk',
#  'chronic Lung Disease',
#  'Frequent Cold',
#  'Clubbing of Finger Nails',
#  'Dry Cough',
#  'Weight Loss',
#  'Swallowing Difficulty',
#  'Snoring',
#  'Gender',
#  'Age']

# %%
# Por lo tanto iré con todas las features de primeras y luego veré si puedo hacer una selección más pequeña

# %%
# No obstante voy a dejar hecho el mutual information clasificación para ver todas las relaciones

from sklearn.feature_selection import mutual_info_classif

listado_features = train_set.columns.to_list()
listado_features.remove(target) # quitamos el target de la lista de features

mi = mutual_info_classif(train_set[listado_features], train_set[target]) # valor obtenido por el mutual information
mi_df = pd.DataFrame({'Feature': train_set[listado_features].columns, 'Mutual Information': mi}) # creo un dataframe con los resultados de mutual information
mi_df = mi_df.sort_values(by='Mutual Information', ascending=False).reset_index(drop=True) # ordeno de mayor a menor importancia las features
print(mi_df)
# Out:
#                      Feature  Mutual Information
# 0             Passive Smoker            0.604717
# 1          Coughing of Blood            0.566786
# 2                    Obesity            0.549355
# 3                Alcohol use            0.540055
# 4                   Wheezing            0.515230
# 5                 Chest Pain            0.505531
# 6              Balanced Diet            0.476912
# 7               Dust Allergy            0.444843
# 8                    Smoking            0.435095
# 9       OccuPational Hazards            0.409418
# 10       Shortness of Breath            0.408450
# 11             Air Pollution            0.400087
# 12              Genetic Risk            0.397171
# 13                   Fatigue            0.373518
# 14                       Age            0.367074
# 15      chronic Lung Disease            0.350915
# 16  Clubbing of Finger Nails            0.288656
# 17             Frequent Cold            0.270946
# 18               Weight Loss            0.229558
# 19                 Dry Cough            0.218886
# 20                   Snoring            0.133836
# 21     Swallowing Difficulty            0.129785
# 22                    Gender            0.056521

# %%
# Voy a ponerlo graficamente
plt.figure(figsize=(10,6))
sns.barplot(x='Mutual Information',y='Feature', data=mi_df)
plt.title('Mutual Information of Features for Classification')
plt.xlabel('Mutual Information')
plt.ylabel('Features')
plt.show()

# %%
# Según el mutual information, la única variable que no tendría relación es el género. Aunque se puede poner un límite en valores < 0,1
# Voy a crear un listado de las variables seleccionadas por el mutual information
condicion = mi_df['Mutual Information'] > 0.1
features_mi = mi_df.loc[condicion, 'Feature'].to_list()
features_mi
# Out:
# ['Passive Smoker',
#  'Coughing of Blood',
#  'Obesity',
#  'Alcohol use',
#  'Wheezing',
#  'Chest Pain',
#  'Balanced Diet',
#  'Dust Allergy',
#  'Smoking',
#  'OccuPational Hazards',
#  'Shortness of Breath',
#  'Air Pollution',
#  'Genetic Risk',
#  'Fatigue',
#  'Age',
#  'chronic Lung Disease',
#  'Clubbing of Finger Nails',
#  'Frequent Cold',
#  'Weight Loss',
#  'Dry Cough',
#  'Snoring',
#  'Swallowing Difficulty']

# %%
# Voy a usar la seleccion de features por modelo. 
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

rf_selector = RandomForestClassifier(random_state= 42, class_weight= "balanced") #

selector_modelo = SelectFromModel(estimator = rf_selector, threshold="median") # Nos quedamos con la mitad

selector_modelo.fit(train_set[listado_features], train_set[target]) 
features_modelo = list(selector_modelo.get_feature_names_out())
features_modelo
# Out:
# ['Alcohol use',
#  'Dust Allergy',
#  'Balanced Diet',
#  'Obesity',
#  'Smoking',
#  'Passive Smoker',
#  'Chest Pain',
#  'Coughing of Blood',
#  'Fatigue',
#  'Wheezing',
#  'Swallowing Difficulty',
#  'Clubbing of Finger Nails']

# %%
# De forma manual
rf_check = RandomForestClassifier(random_state= 42, class_weight= "balanced")

rf_check.fit(train_set[listado_features], train_set[target])

df_importance= pd.DataFrame(rf_check.feature_importances_, columns = ["importance"], index = listado_features).sort_values("importance",ascending = False)
df_importance
# Out:
#                           importance
# Coughing of Blood           0.099784
# Obesity                     0.098918
# Wheezing                    0.094752
# Passive Smoker              0.078466
# Chest Pain                  0.052965
# Fatigue                     0.051520
# Balanced Diet               0.045328
# Alcohol use                 0.044283
# Swallowing Difficulty       0.044089
# Smoking                     0.043334
# Dust Allergy                0.041295
# Clubbing of Finger Nails    0.038880
# OccuPational Hazards        0.038780
# Shortness of Breath         0.036123
# Snoring                     0.034247
# Air Pollution               0.033057
# Genetic Risk                0.032036
# Frequent Cold               0.031338
# Weight Loss                 0.026486
# chronic Lung Disease        0.015084
# Dry Cough                   0.013800
# Age                         0.005286
# Gender                      0.000148

# %%
# Cortamos por la mediana
df_importance.importance.median()
# Out:
# np.float64(0.03888029181211212)

# %%
df_importance[df_importance.importance > df_importance.importance.median()]
# Out:
#                        importance
# Coughing of Blood        0.099784
# Obesity                  0.098918
# Wheezing                 0.094752
# Passive Smoker           0.078466
# Chest Pain               0.052965
# Fatigue                  0.051520
# Balanced Diet            0.045328
# Alcohol use              0.044283
# Swallowing Difficulty    0.044089
# Smoking                  0.043334
# Dust Allergy             0.041295

# %%
# Hacemos listado de features modelo manual
features_manual = df_importance[df_importance.importance > df_importance.importance.median()].index.to_list()
features_manual
# Out:
# ['Coughing of Blood',
#  'Obesity',
#  'Wheezing',
#  'Passive Smoker',
#  'Chest Pain',
#  'Fatigue',
#  'Balanced Diet',
#  'Alcohol use',
#  'Swallowing Difficulty',
#  'Smoking',
#  'Dust Allergy']

# %%
# Voy a probar con RFE, me quedaré con 12 features, que son la mitad de las que tengo
from sklearn.feature_selection import  RFE, SequentialFeatureSelector

rf_RFE = RandomForestClassifier(random_state= 42, class_weight= "balanced")

rfe = RFE(estimator = rf_RFE,
          n_features_to_select= 12, # Iterará hasta quedarse con 12
          step = 1)


rfe.fit(train_set[listado_features], train_set[target])
# Out:
# RFE(estimator=RandomForestClassifier(class_weight='balanced', random_state=42),
#     n_features_to_select=12)

# %%
features_RFE = list(rfe.get_feature_names_out())
features_RFE
# Out:
# ['Air Pollution',
#  'Alcohol use',
#  'Dust Allergy',
#  'Balanced Diet',
#  'Obesity',
#  'Smoking',
#  'Passive Smoker',
#  'Coughing of Blood',
#  'Fatigue',
#  'Wheezing',
#  'Clubbing of Finger Nails',
#  'Snoring']

# %%
# Ahora voy a probar con SFS, también escogeré 12

rf_SFS = RandomForestClassifier(class_weight= "balanced", random_state = 42)

sfs_forward = SequentialFeatureSelector(rf_SFS,
                                        n_features_to_select = 12, # número de features a escoger
                                        cv = 4,
                                        scoring = "balanced_accuracy", 
                                        n_jobs = -1)

sfs_forward.fit(train_set[listado_features], train_set[target])
# Out:
# 348419.76s - Error patching args (debugger not attached to subprocess).
# Traceback (most recent call last):
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py", line 541, in patch_args
#     new_args.append(_get_python_c_args(host, port, code, unquoted_args, SetupHolder.setup))
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py", line 193, in _get_python_c_args
#     if "__future__" in code:
#        ^^^^^^^^^^^^^^^^^^^^
# TypeError: a bytes-like object is required, not 'str'
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# SequentialFeatureSelector(cv=4,
#                           estimator=RandomForestClassifier(class_weight='balanced',
#                                                            random_state=42),
#                           n_features_to_select=12, n_jobs=-1,
#                           scoring='balanced_accuracy')

# %%
features_SFS = list(sfs_forward.get_feature_names_out())
features_SFS
# Out:
# ['Age',
#  'Gender',
#  'Air Pollution',
#  'Alcohol use',
#  'Dust Allergy',
#  'OccuPational Hazards',
#  'Genetic Risk',
#  'chronic Lung Disease',
#  'Balanced Diet',
#  'Obesity',
#  'Coughing of Blood',
#  'Wheezing']

# %%
# Curioso, ya que la edad en la mayoria de seleccion de features está descartada, al igual que el género , que aparentemente tienen menos peso

# %%
# Finalmente voy a hacer un hard-voting, escogiendo las 12 features más votadas, por reducir a la mitad las features seleccionadas, veamos que sale
from collections import Counter

lista_total = features_stad + features_mi + features_manual + features_modelo + features_RFE + features_SFS
votaciones = Counter(lista_total)
votaciones
# Out:
# Counter({'Coughing of Blood': 6,
#          'Obesity': 6,
#          'Wheezing': 6,
#          'Alcohol use': 6,
#          'Balanced Diet': 6,
#          'Dust Allergy': 6,
#          'Passive Smoker': 5,
#          'Smoking': 5,
#          'Fatigue': 5,
#          'Chest Pain': 4,
#          'Air Pollution': 4,
#          'Clubbing of Finger Nails': 4,
#          'Swallowing Difficulty': 4,
#          'OccuPational Hazards': 3,
#          'Genetic Risk': 3,
#          'chronic Lung Disease': 3,
#          'Snoring': 3,
#          'Age': 3,
#          'Shortness of Breath': 2,
#          'Frequent Cold': 2,
#          'Dry Cough': 2,
#          'Weight Loss': 2,
#          'Gender': 2})

# %%
# Ganadores del hard-voting
escrutinio = pd.DataFrame(votaciones.values(), columns = ["Votos"], index = votaciones.keys()).sort_values("Votos", ascending = False)
escrutinio
# Out:
#                           Votos
# Coughing of Blood             6
# Obesity                       6
# Wheezing                      6
# Alcohol use                   6
# Balanced Diet                 6
# Dust Allergy                  6
# Passive Smoker                5
# Smoking                       5
# Fatigue                       5
# Air Pollution                 4
# Chest Pain                    4
# Swallowing Difficulty         4
# Clubbing of Finger Nails      4
# chronic Lung Disease          3
# OccuPational Hazards          3
# Snoring                       3
# Genetic Risk                  3
# Age                           3
# Shortness of Breath           2
# Weight Loss                   2
# Dry Cough                     2
# Frequent Cold                 2
# Gender                        2

# %%
features_hard_voting = escrutinio["Votos"].nlargest(12).index.to_list()
features_hard_voting
# Out:
# ['Coughing of Blood',
#  'Obesity',
#  'Wheezing',
#  'Alcohol use',
#  'Balanced Diet',
#  'Dust Allergy',
#  'Passive Smoker',
#  'Smoking',
#  'Fatigue',
#  'Air Pollution',
#  'Chest Pain',
#  'Swallowing Difficulty']

# %%
# Voy a hacer los splits
X_train = train_set[listado_features]
y_train = train_set[target]

X_test = test_set[listado_features]
y_test = test_set [target]

# %%
# Pasamos al modelado

# Importo las librerias que voy a necesitar

from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV,cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix
from sklearn.svm import SVC
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
# Ojo, para la regresión lineal y para SVC necesitamos scalar las varibles
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(train_set[listado_features]) # Adaptamos el StandarScaler al Train, pero luego usamos el mismo en el test (porque ya la media y la desviación son las del train)
X_train_scalado = pd.DataFrame(scaler.transform(train_set[listado_features]), columns = listado_features)
X_test_scalado = pd.DataFrame(scaler.transform(test_set[listado_features]), columns= listado_features)
X_train_scalado.describe()
# Out:
#                 Age        Gender  Air Pollution   Alcohol use  Dust Allergy  \
# count  9.800000e+02  9.800000e+02   9.800000e+02  9.800000e+02  9.800000e+02
# mean   8.247371e-17  1.749168e-16   1.232574e-16  3.443957e-17 -1.622285e-16
# std    1.000511e+00  1.000511e+00   1.000511e+00  1.000511e+00  1.000511e+00
# min   -1.933838e+00 -8.164966e-01  -1.399085e+00 -1.362645e+00 -2.121869e+00
# 25%   -7.862922e-01 -8.164966e-01  -9.071209e-01 -9.812133e-01 -5.988477e-01
# 50%   -9.776492e-02 -8.164966e-01  -4.151571e-01  1.630815e-01  4.164996e-01
# 75%    6.533558e-01  1.224745e+00   1.060734e+00  9.259446e-01  9.241732e-01
# max    2.990176e+00  1.224745e+00   2.044661e+00  1.307376e+00  1.431847e+00
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count          9.800000e+02  9.800000e+02          9.800000e+02
# mean           5.165936e-17 -1.123818e-16         -3.081435e-17
# std            1.000511e+00  1.000511e+00          1.000511e+00
# min           -1.828445e+00 -1.690121e+00         -1.829155e+00
# 25%           -8.791068e-01 -7.484958e-01         -7.476637e-01
# 50%            7.023167e-02  1.931292e-01         -2.069180e-01
# 75%            1.019570e+00  1.134754e+00          8.745734e-01
# max            1.494239e+00  1.134754e+00          1.415319e+00
#
#        Balanced Diet       Obesity  ...  Coughing of Blood       Fatigue  \
# count   9.800000e+02  9.800000e+02  ...       9.800000e+02  9.800000e+02
# mean    9.788089e-17 -2.447022e-17  ...       1.450087e-17  1.232574e-16
# std     1.000511e+00  1.000511e+00  ...       1.000511e+00  1.000511e+00
# min    -1.637301e+00 -1.637426e+00  ...      -1.581522e+00 -1.271010e+00
# 25%    -1.169228e+00 -6.937754e-01  ...      -7.606051e-01 -8.247220e-01
# 50%    -2.330814e-01 -2.219504e-01  ...      -3.501464e-01 -3.784340e-01
# 75%     1.171138e+00  1.193525e+00  ...       8.812297e-01  5.141420e-01
# max     1.171138e+00  1.193525e+00  ...       1.702147e+00  2.299294e+00
#
#         Weight Loss  Shortness of Breath      Wheezing  Swallowing Difficulty  \
# count  9.800000e+02         9.800000e+02  9.800000e+02           9.800000e+02
# mean  -9.063045e-18        -1.087565e-16 -5.800349e-17          -5.437827e-18
# std    1.000511e+00         1.000511e+00  1.000511e+00           1.000511e+00
# min   -1.289456e+00        -1.423090e+00 -1.359062e+00          -1.203532e+00
# 25%   -8.363661e-01        -9.845278e-01 -8.688595e-01          -7.629412e-01
# 50%   -3.832767e-01        -1.074030e-01  1.115461e-01           1.182402e-01
# 75%    9.759917e-01         7.697217e-01  6.017489e-01           5.588309e-01
# max    1.882171e+00         2.085409e+00  2.072357e+00           1.880603e+00
#
#        Clubbing of Finger Nails  Frequent Cold     Dry Cough       Snoring
# count              9.800000e+02   9.800000e+02  9.800000e+02  9.800000e+02
# mean              -1.993870e-17  -1.468213e-16  5.687061e-17 -4.440892e-17
# std                1.000511e+00   1.000511e+00  1.000511e+00  1.000511e+00
# min               -1.227275e+00  -1.383836e+00 -1.396984e+00 -1.306084e+00
# 25%               -8.083515e-01  -8.378779e-01 -9.076898e-01 -6.295713e-01
# 50%                2.949564e-02  -2.919202e-01  7.089766e-02  4.694172e-02
# 75%                4.484192e-01   7.999952e-01  1.049485e+00  7.234547e-01
# max                2.124114e+00   1.891911e+00  1.538779e+00  2.752994e+00
#
# [8 rows x 23 columns]

# %%
# Aquí voy a ignorar la regresión lineal y el  SVC por el tema del escalado, luego haré similar con estos dos modelos 

nombres = [f"Seleccion {nombre}" for nombre in ["estadistico", "mutual information", "manual", "modelo", "rfe", "sfs", "voting"]]
model_names = ["Random Forest", "KNN", " Decission Tree", "AdaBoost", "LightGBM", "Catboost"]

rf_clf = RandomForestClassifier(class_weight= "balanced", random_state= 42)
knn_clf = KNeighborsClassifier(weights= "uniform", n_jobs= -1)
dt_clf = DecisionTreeClassifier(class_weight = "balanced", random_state = 42) 
ada_clf = AdaBoostClassifier(random_state = 42)
# xg_clf = XGBClassifier(random_state  = 42) necesita que la target sea numérica
lgb_clf = LGBMClassifier(class_weight= "balanced", random_state = 42, verbose = -100, n_jobs= -1)
cb_clf = CatBoostClassifier(random_state = 42)


models = [rf_clf, knn_clf, dt_clf, ada_clf, lgb_clf, cb_clf]
resultados = []

for indice, lista in enumerate([features_stad, features_mi, features_manual, features_modelo, features_RFE, features_SFS, features_hard_voting]):
    X_train = train_set[lista]
    y_train = train_set[target]
    
    for model_name, modelo in zip(model_names, models):
        metrica = np.mean(cross_val_score(modelo, X_train, y_train, cv = 5, scoring = "balanced_accuracy"))
        data = {
            "features_list": nombres[indice],
            "model": model_name,
            "avg. recall": metrica
        }
        print(data)
        resultados.append(data.copy())
df_resultados = pd.DataFrame(resultados)
df_resultados.sort_values("avg. recall", ascending = False)
# Out:
# {'features_list': 'Seleccion estadistico', 'model': 'Random Forest', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion estadistico', 'model': 'KNN', 'avg. recall': np.float64(0.9977401129943504)}
# {'features_list': 'Seleccion estadistico', 'model': ' Decission Tree', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion estadistico', 'model': 'AdaBoost', 'avg. recall': np.float64(0.9611806460959003)}
# {'features_list': 'Seleccion estadistico', 'model': 'LightGBM', 'avg. recall': np.float64(1.0)}
# Learning rate set to 0.078151
# 0:	learn: 0.9815316	total: 915us	remaining: 915ms
# 1:	learn: 0.8853657	total: 1.76ms	remaining: 877ms
# 2:	learn: 0.8033016	total: 2.38ms	remaining: 789ms
# 3:	learn: 0.7306817	total: 3.26ms	remaining: 811ms
# 4:	learn: 0.6681246	total: 4.09ms	remaining: 815ms
# 5:	learn: 0.6170800	total: 4.89ms	remaining: 810ms
# 6:	learn: 0.5664905	total: 5.65ms	remaining: 802ms
# 7:	learn: 0.5264849	total: 6.42ms	remaining: 796ms
# 8:	learn: 0.4901864	total: 7.28ms	remaining: 802ms
# 9:	learn: 0.4526404	total: 8.02ms	remaining: 794ms
# 10:	learn: 0.4203407	total: 8.77ms	remaining: 789ms
# 11:	learn: 0.3904184	total: 9.52ms	remaining: 784ms
# 12:	learn: 0.3632787	total: 10.3ms	remaining: 779ms
# 13:	learn: 0.3399330	total: 11ms	remaining: 775ms
# 14:	learn: 0.3177262	total: 11.7ms	remaining: 770ms
# 15:	learn: 0.2970067	total: 12.4ms	remaining: 762ms
# 16:	learn: 0.2756957	total: 13.1ms	remaining: 757ms
# 17:	learn: 0.2575019	total: 13.8ms	remaining: 755ms
# 18:	learn: 0.2411107	total: 14.7ms	remaining: 757ms
# 19:	learn: 0.2259236	total: 15.4ms	remaining: 755ms
# 20:	learn: 0.2125744	total: 16.1ms	remaining: 753ms
# 21:	learn: 0.2006989	total: 16.9ms	remaining: 753ms
# 22:	learn: 0.1900083	total: 17.7ms	remaining: 754ms
# 23:	learn: 0.1800811	total: 18.5ms	remaining: 753ms
# 24:	learn: 0.1702001	total: 19.2ms	remaining: 750ms
# 25:	learn: 0.1591614	total: 20ms	remaining: 748ms
# 26:	learn: 0.1496345	total: 20.8ms	remaining: 750ms
# 27:	learn: 0.1413562	total: 21.7ms	remaining: 753ms
# 28:	learn: 0.1333548	total: 22.5ms	remaining: 752ms
# 29:	learn: 0.1264149	total: 23.1ms	remaining: 747ms
# 30:	learn: 0.1200751	total: 24ms	remaining: 751ms
# 31:	learn: 0.1136871	total: 24.8ms	remaining: 749ms
# 32:	learn: 0.1081134	total: 25.5ms	remaining: 749ms
# 33:	learn: 0.1019186	total: 26.3ms	remaining: 746ms
# 34:	learn: 0.0964862	total: 27ms	remaining: 745ms
# 35:	learn: 0.0918261	total: 27.7ms	remaining: 742ms
# 36:	learn: 0.0874412	total: 28.4ms	remaining: 739ms
# 37:	learn: 0.0834563	total: 29.1ms	remaining: 737ms
# 38:	learn: 0.0795198	total: 29.8ms	remaining: 735ms
# 39:	learn: 0.0759942	total: 30.6ms	remaining: 735ms
# 40:	learn: 0.0726992	total: 31.4ms	remaining: 735ms
# 41:	learn: 0.0691079	total: 32.2ms	remaining: 734ms
# 42:	learn: 0.0660696	total: 32.9ms	remaining: 732ms
# 43:	learn: 0.0634355	total: 33.7ms	remaining: 732ms
# 44:	learn: 0.0608680	total: 34.4ms	remaining: 730ms
# 45:	learn: 0.0583271	total: 35.2ms	remaining: 730ms
# 46:	learn: 0.0559297	total: 35.9ms	remaining: 728ms
# 47:	learn: 0.0535360	total: 36.7ms	remaining: 727ms
# 48:	learn: 0.0515414	total: 37.5ms	remaining: 728ms
# 49:	learn: 0.0492575	total: 38.2ms	remaining: 726ms
# 50:	learn: 0.0473143	total: 39ms	remaining: 726ms
# 51:	learn: 0.0457608	total: 39.8ms	remaining: 725ms
# 52:	learn: 0.0443874	total: 40.5ms	remaining: 724ms
# 53:	learn: 0.0426157	total: 41.3ms	remaining: 723ms
# 54:	learn: 0.0408610	total: 42ms	remaining: 722ms
# 55:	learn: 0.0397465	total: 42.7ms	remaining: 720ms
# 56:	learn: 0.0385151	total: 43.5ms	remaining: 719ms
# 57:	learn: 0.0370664	total: 44.2ms	remaining: 718ms
# 58:	learn: 0.0360763	total: 45ms	remaining: 718ms
# 59:	learn: 0.0348777	total: 45.7ms	remaining: 717ms
# 60:	learn: 0.0338044	total: 46.5ms	remaining: 716ms
# 61:	learn: 0.0327135	total: 47.3ms	remaining: 716ms
# 62:	learn: 0.0316679	total: 48ms	remaining: 713ms
# 63:	learn: 0.0309027	total: 48.8ms	remaining: 714ms
# 64:	learn: 0.0299632	total: 49.6ms	remaining: 713ms
# 65:	learn: 0.0288848	total: 50.3ms	remaining: 712ms
# 66:	learn: 0.0281279	total: 51.1ms	remaining: 711ms
# 67:	learn: 0.0273207	total: 51.8ms	remaining: 710ms
# 68:	learn: 0.0264993	total: 52.6ms	remaining: 709ms
# 69:	learn: 0.0257324	total: 53.3ms	remaining: 708ms
# 70:	learn: 0.0249201	total: 54.1ms	remaining: 707ms
# 71:	learn: 0.0241539	total: 54.8ms	remaining: 707ms
# 72:	learn: 0.0235041	total: 55.5ms	remaining: 705ms
# 73:	learn: 0.0229117	total: 56.3ms	remaining: 704ms
# 74:	learn: 0.0223446	total: 57ms	remaining: 704ms
# 75:	learn: 0.0217686	total: 57.8ms	remaining: 703ms
# 76:	learn: 0.0213390	total: 58.6ms	remaining: 702ms
# 77:	learn: 0.0208532	total: 59.2ms	remaining: 700ms
# 78:	learn: 0.0203356	total: 60ms	remaining: 699ms
# 79:	learn: 0.0198286	total: 60.7ms	remaining: 698ms
# 80:	learn: 0.0193321	total: 61.4ms	remaining: 697ms
# 81:	learn: 0.0189630	total: 62.1ms	remaining: 696ms
# 82:	learn: 0.0184296	total: 62.9ms	remaining: 695ms
# 83:	learn: 0.0180684	total: 63.7ms	remaining: 695ms
# 84:	learn: 0.0176861	total: 64.5ms	remaining: 694ms
# 85:	learn: 0.0173393	total: 65.2ms	remaining: 693ms
# 86:	learn: 0.0170006	total: 66ms	remaining: 693ms
# 87:	learn: 0.0166135	total: 66.8ms	remaining: 692ms
# 88:	learn: 0.0162840	total: 67.5ms	remaining: 691ms
# 89:	learn: 0.0159863	total: 68.1ms	remaining: 689ms
# 90:	learn: 0.0155888	total: 69ms	remaining: 689ms
# 91:	learn: 0.0152745	total: 69.7ms	remaining: 688ms
# 92:	learn: 0.0149398	total: 70.5ms	remaining: 688ms
# 93:	learn: 0.0145748	total: 71.3ms	remaining: 687ms
# 94:	learn: 0.0143190	total: 72ms	remaining: 686ms
# 95:	learn: 0.0140544	total: 72.7ms	remaining: 685ms
# 96:	learn: 0.0138244	total: 73.4ms	remaining: 683ms
# 97:	learn: 0.0135052	total: 74.2ms	remaining: 683ms
# 98:	learn: 0.0132641	total: 74.9ms	remaining: 682ms
# 99:	learn: 0.0130550	total: 75.7ms	remaining: 682ms
# 100:	learn: 0.0128251	total: 76.5ms	remaining: 681ms
# 101:	learn: 0.0126300	total: 77.2ms	remaining: 679ms
# 102:	learn: 0.0123566	total: 78ms	remaining: 679ms
# 103:	learn: 0.0120955	total: 78.7ms	remaining: 678ms
# 104:	learn: 0.0118685	total: 79.4ms	remaining: 677ms
# 105:	learn: 0.0116806	total: 80.2ms	remaining: 676ms
# 106:	learn: 0.0115224	total: 80.9ms	remaining: 675ms
# 107:	learn: 0.0112911	total: 81.6ms	remaining: 674ms
# 108:	learn: 0.0110969	total: 82.5ms	remaining: 674ms
# 109:	learn: 0.0108817	total: 83.2ms	remaining: 674ms
# 110:	learn: 0.0107482	total: 84ms	remaining: 673ms
# 111:	learn: 0.0105451	total: 84.8ms	remaining: 672ms
# 112:	learn: 0.0104023	total: 85.5ms	remaining: 671ms
# 113:	learn: 0.0102619	total: 86.3ms	remaining: 670ms
# 114:	learn: 0.0101064	total: 86.9ms	remaining: 669ms
# 115:	learn: 0.0099357	total: 87.6ms	remaining: 668ms
# 116:	learn: 0.0097926	total: 88.4ms	remaining: 667ms
# 117:	learn: 0.0096217	total: 89.1ms	remaining: 666ms
# 118:	learn: 0.0094900	total: 89.8ms	remaining: 665ms
# 119:	learn: 0.0093319	total: 90.6ms	remaining: 664ms
# 120:	learn: 0.0092067	total: 91.4ms	remaining: 664ms
# 121:	learn: 0.0090953	total: 92.2ms	remaining: 663ms
# 122:	learn: 0.0089702	total: 93.1ms	remaining: 664ms
# 123:	learn: 0.0088443	total: 93.8ms	remaining: 663ms
# 124:	learn: 0.0087219	total: 94.7ms	remaining: 663ms
# 125:	learn: 0.0086056	total: 95.5ms	remaining: 663ms
# 126:	learn: 0.0084897	total: 96.3ms	remaining: 662ms
# 127:	learn: 0.0083718	total: 97.1ms	remaining: 661ms
# 128:	learn: 0.0082621	total: 97.9ms	remaining: 661ms
# 129:	learn: 0.0081639	total: 98.8ms	remaining: 661ms
# 130:	learn: 0.0080595	total: 99.6ms	remaining: 661ms
# 131:	learn: 0.0079414	total: 100ms	remaining: 660ms
# 132:	learn: 0.0078426	total: 101ms	remaining: 659ms
# 133:	learn: 0.0077541	total: 102ms	remaining: 658ms
# 134:	learn: 0.0076598	total: 103ms	remaining: 658ms
# 135:	learn: 0.0075776	total: 103ms	remaining: 657ms
# 136:	learn: 0.0074873	total: 104ms	remaining: 656ms
# 137:	learn: 0.0073991	total: 105ms	remaining: 655ms
# 138:	learn: 0.0073255	total: 106ms	remaining: 654ms
# 139:	learn: 0.0072410	total: 106ms	remaining: 654ms
# 140:	learn: 0.0071585	total: 107ms	remaining: 653ms
# 141:	learn: 0.0070779	total: 108ms	remaining: 652ms
# 142:	learn: 0.0069991	total: 109ms	remaining: 651ms
# 143:	learn: 0.0069221	total: 109ms	remaining: 650ms
# 144:	learn: 0.0068562	total: 110ms	remaining: 649ms
# 145:	learn: 0.0067691	total: 111ms	remaining: 648ms
# 146:	learn: 0.0066842	total: 111ms	remaining: 647ms
# 147:	learn: 0.0066197	total: 112ms	remaining: 646ms
# 148:	learn: 0.0065550	total: 113ms	remaining: 646ms
# 149:	learn: 0.0064960	total: 114ms	remaining: 645ms
# 150:	learn: 0.0064254	total: 115ms	remaining: 644ms
# 151:	learn: 0.0063725	total: 115ms	remaining: 643ms
# 152:	learn: 0.0062964	total: 116ms	remaining: 643ms
# 153:	learn: 0.0062303	total: 117ms	remaining: 641ms
# 154:	learn: 0.0061574	total: 118ms	remaining: 641ms
# 155:	learn: 0.0060927	total: 118ms	remaining: 640ms
# 156:	learn: 0.0060335	total: 119ms	remaining: 639ms
# 157:	learn: 0.0059868	total: 120ms	remaining: 638ms
# 158:	learn: 0.0059255	total: 121ms	remaining: 637ms
# 159:	learn: 0.0058768	total: 121ms	remaining: 636ms
# 160:	learn: 0.0058215	total: 122ms	remaining: 636ms
# 161:	learn: 0.0057714	total: 123ms	remaining: 635ms
# 162:	learn: 0.0057085	total: 123ms	remaining: 634ms
# 163:	learn: 0.0056470	total: 124ms	remaining: 633ms
# 164:	learn: 0.0055869	total: 125ms	remaining: 632ms
# 165:	learn: 0.0055433	total: 126ms	remaining: 631ms
# 166:	learn: 0.0054941	total: 126ms	remaining: 631ms
# 167:	learn: 0.0054514	total: 127ms	remaining: 630ms
# 168:	learn: 0.0054027	total: 128ms	remaining: 629ms
# 169:	learn: 0.0053627	total: 129ms	remaining: 628ms
# 170:	learn: 0.0053254	total: 129ms	remaining: 627ms
# 171:	learn: 0.0052715	total: 130ms	remaining: 627ms
# 172:	learn: 0.0052316	total: 131ms	remaining: 626ms
# 173:	learn: 0.0051932	total: 132ms	remaining: 625ms
# 174:	learn: 0.0051497	total: 132ms	remaining: 624ms
# 175:	learn: 0.0051074	total: 133ms	remaining: 624ms
# 176:	learn: 0.0050702	total: 134ms	remaining: 623ms
# 177:	learn: 0.0050210	total: 135ms	remaining: 622ms
# 178:	learn: 0.0049804	total: 135ms	remaining: 621ms
# 179:	learn: 0.0049329	total: 136ms	remaining: 620ms
# 180:	learn: 0.0048916	total: 137ms	remaining: 620ms
# 181:	learn: 0.0048557	total: 138ms	remaining: 619ms
# 182:	learn: 0.0048221	total: 139ms	remaining: 619ms
# 183:	learn: 0.0047846	total: 139ms	remaining: 618ms
# 184:	learn: 0.0047515	total: 140ms	remaining: 617ms
# 185:	learn: 0.0047182	total: 141ms	remaining: 616ms
# 186:	learn: 0.0046822	total: 142ms	remaining: 616ms
# 187:	learn: 0.0046485	total: 142ms	remaining: 615ms
# 188:	learn: 0.0046103	total: 143ms	remaining: 615ms
# 189:	learn: 0.0045823	total: 144ms	remaining: 615ms
# 190:	learn: 0.0045419	total: 145ms	remaining: 614ms
# 191:	learn: 0.0045118	total: 146ms	remaining: 613ms
# 192:	learn: 0.0044860	total: 147ms	remaining: 613ms
# 193:	learn: 0.0044472	total: 147ms	remaining: 611ms
# 194:	learn: 0.0044151	total: 148ms	remaining: 611ms
# 195:	learn: 0.0043834	total: 149ms	remaining: 610ms
# 196:	learn: 0.0043553	total: 149ms	remaining: 609ms
# 197:	learn: 0.0043275	total: 150ms	remaining: 608ms
# 198:	learn: 0.0042949	total: 151ms	remaining: 607ms
# 199:	learn: 0.0042651	total: 152ms	remaining: 607ms
# 200:	learn: 0.0042298	total: 152ms	remaining: 606ms
# 201:	learn: 0.0042040	total: 153ms	remaining: 606ms
# 202:	learn: 0.0041726	total: 154ms	remaining: 605ms
# 203:	learn: 0.0041388	total: 155ms	remaining: 604ms
# 204:	learn: 0.0041128	total: 156ms	remaining: 603ms
# 205:	learn: 0.0040854	total: 157ms	remaining: 603ms
# 206:	learn: 0.0040557	total: 157ms	remaining: 603ms
# 207:	learn: 0.0040289	total: 158ms	remaining: 602ms
# 208:	learn: 0.0040026	total: 159ms	remaining: 601ms
# 209:	learn: 0.0039715	total: 159ms	remaining: 600ms
# 210:	learn: 0.0039472	total: 160ms	remaining: 600ms
# 211:	learn: 0.0039235	total: 161ms	remaining: 599ms
# 212:	learn: 0.0038970	total: 162ms	remaining: 598ms
# 213:	learn: 0.0038739	total: 163ms	remaining: 597ms
# 214:	learn: 0.0038494	total: 163ms	remaining: 596ms
# 215:	learn: 0.0038252	total: 164ms	remaining: 596ms
# 216:	learn: 0.0038065	total: 165ms	remaining: 595ms
# 217:	learn: 0.0037829	total: 166ms	remaining: 594ms
# 218:	learn: 0.0037550	total: 166ms	remaining: 593ms
# 219:	learn: 0.0037320	total: 167ms	remaining: 592ms
# 220:	learn: 0.0037112	total: 168ms	remaining: 591ms
# 221:	learn: 0.0036899	total: 168ms	remaining: 590ms
# 222:	learn: 0.0036724	total: 169ms	remaining: 590ms
# 223:	learn: 0.0036504	total: 170ms	remaining: 589ms
# 224:	learn: 0.0036286	total: 171ms	remaining: 589ms
# 225:	learn: 0.0036084	total: 172ms	remaining: 587ms
# 226:	learn: 0.0035829	total: 172ms	remaining: 586ms
# 227:	learn: 0.0035620	total: 173ms	remaining: 584ms
# 228:	learn: 0.0035391	total: 173ms	remaining: 583ms
# 229:	learn: 0.0035200	total: 174ms	remaining: 582ms
# 230:	learn: 0.0035015	total: 174ms	remaining: 581ms
# 231:	learn: 0.0034814	total: 175ms	remaining: 579ms
# 232:	learn: 0.0034650	total: 175ms	remaining: 578ms
# 233:	learn: 0.0034454	total: 177ms	remaining: 578ms
# 234:	learn: 0.0034259	total: 177ms	remaining: 578ms
# 235:	learn: 0.0034036	total: 178ms	remaining: 577ms
# 236:	learn: 0.0033847	total: 179ms	remaining: 575ms
# 237:	learn: 0.0033659	total: 179ms	remaining: 574ms
# 238:	learn: 0.0033474	total: 180ms	remaining: 573ms
# 239:	learn: 0.0033329	total: 181ms	remaining: 572ms
# 240:	learn: 0.0033133	total: 181ms	remaining: 571ms
# 241:	learn: 0.0032917	total: 182ms	remaining: 570ms
# 242:	learn: 0.0032704	total: 183ms	remaining: 569ms
# 243:	learn: 0.0032559	total: 183ms	remaining: 568ms
# 244:	learn: 0.0032418	total: 184ms	remaining: 567ms
# 245:	learn: 0.0032260	total: 185ms	remaining: 566ms
# 246:	learn: 0.0032089	total: 185ms	remaining: 565ms
# 247:	learn: 0.0031904	total: 186ms	remaining: 564ms
# 248:	learn: 0.0031703	total: 187ms	remaining: 563ms
# 249:	learn: 0.0031549	total: 187ms	remaining: 562ms
# 250:	learn: 0.0031385	total: 188ms	remaining: 561ms
# 251:	learn: 0.0031269	total: 189ms	remaining: 560ms
# 252:	learn: 0.0031121	total: 189ms	remaining: 559ms
# 253:	learn: 0.0030987	total: 190ms	remaining: 558ms
# 254:	learn: 0.0030796	total: 191ms	remaining: 557ms
# 255:	learn: 0.0030649	total: 191ms	remaining: 556ms
# 256:	learn: 0.0030494	total: 192ms	remaining: 555ms
# 257:	learn: 0.0030348	total: 192ms	remaining: 554ms
# 258:	learn: 0.0030230	total: 193ms	remaining: 553ms
# 259:	learn: 0.0030079	total: 194ms	remaining: 552ms
# 260:	learn: 0.0029930	total: 195ms	remaining: 551ms
# 261:	learn: 0.0029784	total: 195ms	remaining: 550ms
# 262:	learn: 0.0029608	total: 196ms	remaining: 549ms
# 263:	learn: 0.0029463	total: 197ms	remaining: 548ms
# 264:	learn: 0.0029335	total: 197ms	remaining: 548ms
# 265:	learn: 0.0029193	total: 198ms	remaining: 547ms
# 266:	learn: 0.0029059	total: 199ms	remaining: 546ms
# 267:	learn: 0.0028920	total: 200ms	remaining: 545ms
# 268:	learn: 0.0028791	total: 200ms	remaining: 544ms
# 269:	learn: 0.0028655	total: 201ms	remaining: 543ms
# 270:	learn: 0.0028519	total: 201ms	remaining: 541ms
# 271:	learn: 0.0028358	total: 202ms	remaining: 540ms
# 272:	learn: 0.0028238	total: 202ms	remaining: 539ms
# 273:	learn: 0.0028080	total: 203ms	remaining: 538ms
# 274:	learn: 0.0027950	total: 204ms	remaining: 537ms
# 275:	learn: 0.0027846	total: 204ms	remaining: 535ms
# 276:	learn: 0.0027691	total: 205ms	remaining: 534ms
# 277:	learn: 0.0027574	total: 205ms	remaining: 533ms
# 278:	learn: 0.0027448	total: 206ms	remaining: 532ms
# 279:	learn: 0.0027309	total: 206ms	remaining: 531ms
# 280:	learn: 0.0027186	total: 207ms	remaining: 530ms
# 281:	learn: 0.0027085	total: 208ms	remaining: 529ms
# 282:	learn: 0.0026971	total: 208ms	remaining: 527ms
# 283:	learn: 0.0026836	total: 209ms	remaining: 526ms
# 284:	learn: 0.0026692	total: 209ms	remaining: 525ms
# 285:	learn: 0.0026575	total: 210ms	remaining: 524ms
# 286:	learn: 0.0026467	total: 210ms	remaining: 523ms
# 287:	learn: 0.0026351	total: 211ms	remaining: 522ms
# 288:	learn: 0.0026250	total: 212ms	remaining: 521ms
# 289:	learn: 0.0026125	total: 212ms	remaining: 520ms
# 290:	learn: 0.0026013	total: 213ms	remaining: 518ms
# 291:	learn: 0.0025912	total: 213ms	remaining: 517ms
# 292:	learn: 0.0025805	total: 214ms	remaining: 516ms
# 293:	learn: 0.0025709	total: 215ms	remaining: 515ms
# 294:	learn: 0.0025618	total: 215ms	remaining: 514ms
# 295:	learn: 0.0025509	total: 216ms	remaining: 513ms
# 296:	learn: 0.0025407	total: 216ms	remaining: 512ms
# 297:	learn: 0.0025299	total: 217ms	remaining: 512ms
# 298:	learn: 0.0025208	total: 218ms	remaining: 511ms
# 299:	learn: 0.0025120	total: 218ms	remaining: 510ms
# 300:	learn: 0.0025006	total: 219ms	remaining: 508ms
# 301:	learn: 0.0024880	total: 219ms	remaining: 507ms
# 302:	learn: 0.0024777	total: 220ms	remaining: 506ms
# 303:	learn: 0.0024675	total: 221ms	remaining: 505ms
# 304:	learn: 0.0024596	total: 221ms	remaining: 504ms
# 305:	learn: 0.0024496	total: 222ms	remaining: 503ms
# 306:	learn: 0.0024385	total: 222ms	remaining: 502ms
# 307:	learn: 0.0024286	total: 223ms	remaining: 501ms
# 308:	learn: 0.0024197	total: 223ms	remaining: 500ms
# 309:	learn: 0.0024104	total: 224ms	remaining: 498ms
# 310:	learn: 0.0024012	total: 224ms	remaining: 497ms
# 311:	learn: 0.0023920	total: 225ms	remaining: 496ms
# 312:	learn: 0.0023844	total: 226ms	remaining: 495ms
# 313:	learn: 0.0023749	total: 226ms	remaining: 494ms
# 314:	learn: 0.0023645	total: 227ms	remaining: 493ms
# 315:	learn: 0.0023557	total: 227ms	remaining: 492ms
# 316:	learn: 0.0023445	total: 228ms	remaining: 491ms
# 317:	learn: 0.0023361	total: 229ms	remaining: 490ms
# 318:	learn: 0.0023260	total: 229ms	remaining: 489ms
# 319:	learn: 0.0023183	total: 230ms	remaining: 488ms
# 320:	learn: 0.0023084	total: 230ms	remaining: 487ms
# 321:	learn: 0.0023008	total: 231ms	remaining: 486ms
# 322:	learn: 0.0022919	total: 231ms	remaining: 485ms
# 323:	learn: 0.0022831	total: 232ms	remaining: 484ms
# 324:	learn: 0.0022749	total: 232ms	remaining: 483ms
# 325:	learn: 0.0022682	total: 233ms	remaining: 482ms
# 326:	learn: 0.0022622	total: 234ms	remaining: 481ms
# 327:	learn: 0.0022543	total: 234ms	remaining: 480ms
# 328:	learn: 0.0022468	total: 235ms	remaining: 479ms
# 329:	learn: 0.0022391	total: 235ms	remaining: 477ms
# 330:	learn: 0.0022316	total: 236ms	remaining: 476ms
# 331:	learn: 0.0022224	total: 236ms	remaining: 475ms
# 332:	learn: 0.0022142	total: 237ms	remaining: 474ms
# 333:	learn: 0.0022062	total: 237ms	remaining: 473ms
# 334:	learn: 0.0021988	total: 238ms	remaining: 472ms
# 335:	learn: 0.0021889	total: 238ms	remaining: 471ms
# 336:	learn: 0.0021809	total: 239ms	remaining: 470ms
# 337:	learn: 0.0021743	total: 239ms	remaining: 469ms
# 338:	learn: 0.0021672	total: 240ms	remaining: 468ms
# 339:	learn: 0.0021593	total: 241ms	remaining: 467ms
# 340:	learn: 0.0021539	total: 241ms	remaining: 466ms
# 341:	learn: 0.0021468	total: 242ms	remaining: 465ms
# 342:	learn: 0.0021398	total: 242ms	remaining: 464ms
# 343:	learn: 0.0021329	total: 243ms	remaining: 463ms
# 344:	learn: 0.0021259	total: 244ms	remaining: 462ms
# 345:	learn: 0.0021177	total: 244ms	remaining: 461ms
# 346:	learn: 0.0021103	total: 245ms	remaining: 460ms
# 347:	learn: 0.0021028	total: 245ms	remaining: 459ms
# 348:	learn: 0.0020963	total: 246ms	remaining: 458ms
# 349:	learn: 0.0020873	total: 246ms	remaining: 457ms
# 350:	learn: 0.0020784	total: 247ms	remaining: 456ms
# 351:	learn: 0.0020718	total: 247ms	remaining: 455ms
# 352:	learn: 0.0020631	total: 248ms	remaining: 454ms
# 353:	learn: 0.0020559	total: 248ms	remaining: 453ms
# 354:	learn: 0.0020489	total: 249ms	remaining: 452ms
# 355:	learn: 0.0020418	total: 250ms	remaining: 451ms
# 356:	learn: 0.0020354	total: 250ms	remaining: 450ms
# 357:	learn: 0.0020277	total: 251ms	remaining: 449ms
# 358:	learn: 0.0020216	total: 251ms	remaining: 448ms
# 359:	learn: 0.0020151	total: 252ms	remaining: 447ms
# 360:	learn: 0.0020090	total: 252ms	remaining: 446ms
# 361:	learn: 0.0020028	total: 253ms	remaining: 446ms
# 362:	learn: 0.0019976	total: 253ms	remaining: 445ms
# 363:	learn: 0.0019921	total: 254ms	remaining: 444ms
# 364:	learn: 0.0019857	total: 254ms	remaining: 443ms
# 365:	learn: 0.0019797	total: 255ms	remaining: 442ms
# 366:	learn: 0.0019724	total: 256ms	remaining: 441ms
# 367:	learn: 0.0019652	total: 256ms	remaining: 440ms
# 368:	learn: 0.0019593	total: 257ms	remaining: 439ms
# 369:	learn: 0.0019522	total: 257ms	remaining: 438ms
# 370:	learn: 0.0019468	total: 258ms	remaining: 437ms
# 371:	learn: 0.0019411	total: 258ms	remaining: 436ms
# 372:	learn: 0.0019347	total: 259ms	remaining: 435ms
# 373:	learn: 0.0019278	total: 260ms	remaining: 434ms
# 374:	learn: 0.0019217	total: 260ms	remaining: 433ms
# 375:	learn: 0.0019155	total: 261ms	remaining: 433ms
# 376:	learn: 0.0019091	total: 261ms	remaining: 432ms
# 377:	learn: 0.0019046	total: 262ms	remaining: 431ms
# 378:	learn: 0.0018989	total: 262ms	remaining: 430ms
# 379:	learn: 0.0018940	total: 263ms	remaining: 429ms
# 380:	learn: 0.0018873	total: 264ms	remaining: 428ms
# 381:	learn: 0.0018819	total: 264ms	remaining: 427ms
# 382:	learn: 0.0018778	total: 265ms	remaining: 426ms
# 383:	learn: 0.0018713	total: 265ms	remaining: 425ms
# 384:	learn: 0.0018663	total: 266ms	remaining: 425ms
# 385:	learn: 0.0018608	total: 266ms	remaining: 424ms
# 386:	learn: 0.0018544	total: 267ms	remaining: 423ms
# 387:	learn: 0.0018489	total: 267ms	remaining: 422ms
# 388:	learn: 0.0018437	total: 268ms	remaining: 421ms
# 389:	learn: 0.0018392	total: 269ms	remaining: 420ms
# 390:	learn: 0.0018347	total: 269ms	remaining: 419ms
# 391:	learn: 0.0018297	total: 270ms	remaining: 418ms
# 392:	learn: 0.0018246	total: 270ms	remaining: 417ms
# 393:	learn: 0.0018184	total: 271ms	remaining: 416ms
# 394:	learn: 0.0018123	total: 271ms	remaining: 416ms
# 395:	learn: 0.0018062	total: 272ms	remaining: 415ms
# 396:	learn: 0.0017995	total: 273ms	remaining: 414ms
# 397:	learn: 0.0017947	total: 273ms	remaining: 413ms
# 398:	learn: 0.0017888	total: 274ms	remaining: 413ms
# 399:	learn: 0.0017843	total: 275ms	remaining: 412ms
# 400:	learn: 0.0017798	total: 275ms	remaining: 411ms
# 401:	learn: 0.0017740	total: 276ms	remaining: 410ms
# 402:	learn: 0.0017686	total: 276ms	remaining: 410ms
# 403:	learn: 0.0017650	total: 277ms	remaining: 409ms
# 404:	learn: 0.0017605	total: 278ms	remaining: 408ms
# 405:	learn: 0.0017548	total: 278ms	remaining: 407ms
# 406:	learn: 0.0017496	total: 279ms	remaining: 406ms
# 407:	learn: 0.0017449	total: 279ms	remaining: 405ms
# 408:	learn: 0.0017393	total: 280ms	remaining: 404ms
# 409:	learn: 0.0017345	total: 280ms	remaining: 404ms
# 410:	learn: 0.0017289	total: 281ms	remaining: 403ms
# 411:	learn: 0.0017239	total: 281ms	remaining: 402ms
# 412:	learn: 0.0017196	total: 282ms	remaining: 401ms
# 413:	learn: 0.0017152	total: 283ms	remaining: 400ms
# 414:	learn: 0.0017108	total: 283ms	remaining: 399ms
# 415:	learn: 0.0017072	total: 284ms	remaining: 398ms
# 416:	learn: 0.0017022	total: 284ms	remaining: 397ms
# 417:	learn: 0.0016969	total: 285ms	remaining: 396ms
# 418:	learn: 0.0016916	total: 285ms	remaining: 396ms
# 419:	learn: 0.0016873	total: 286ms	remaining: 395ms
# 420:	learn: 0.0016828	total: 287ms	remaining: 394ms
# 421:	learn: 0.0016789	total: 287ms	remaining: 393ms
# 422:	learn: 0.0016737	total: 288ms	remaining: 392ms
# 423:	learn: 0.0016699	total: 288ms	remaining: 392ms
# 424:	learn: 0.0016655	total: 289ms	remaining: 391ms
# 425:	learn: 0.0016602	total: 289ms	remaining: 390ms
# 426:	learn: 0.0016555	total: 290ms	remaining: 389ms
# 427:	learn: 0.0016519	total: 290ms	remaining: 388ms
# 428:	learn: 0.0016479	total: 291ms	remaining: 387ms
# 429:	learn: 0.0016435	total: 291ms	remaining: 386ms
# 430:	learn: 0.0016393	total: 292ms	remaining: 386ms
# 431:	learn: 0.0016347	total: 293ms	remaining: 385ms
# 432:	learn: 0.0016310	total: 293ms	remaining: 384ms
# 433:	learn: 0.0016261	total: 294ms	remaining: 383ms
# 434:	learn: 0.0016224	total: 294ms	remaining: 382ms
# 435:	learn: 0.0016184	total: 295ms	remaining: 381ms
# 436:	learn: 0.0016142	total: 295ms	remaining: 381ms
# 437:	learn: 0.0016103	total: 296ms	remaining: 380ms
# 438:	learn: 0.0016063	total: 297ms	remaining: 379ms
# 439:	learn: 0.0016016	total: 297ms	remaining: 378ms
# 440:	learn: 0.0015982	total: 298ms	remaining: 377ms
# 441:	learn: 0.0015940	total: 298ms	remaining: 376ms
# 442:	learn: 0.0015902	total: 299ms	remaining: 376ms
# 443:	learn: 0.0015862	total: 299ms	remaining: 375ms
# 444:	learn: 0.0015830	total: 300ms	remaining: 374ms
# 445:	learn: 0.0015788	total: 300ms	remaining: 373ms
# 446:	learn: 0.0015742	total: 301ms	remaining: 372ms
# 447:	learn: 0.0015703	total: 302ms	remaining: 372ms
# 448:	learn: 0.0015657	total: 302ms	remaining: 371ms
# 449:	learn: 0.0015625	total: 303ms	remaining: 370ms
# 450:	learn: 0.0015579	total: 303ms	remaining: 369ms
# 451:	learn: 0.0015537	total: 304ms	remaining: 368ms
# 452:	learn: 0.0015493	total: 304ms	remaining: 367ms
# 453:	learn: 0.0015449	total: 305ms	remaining: 367ms
# 454:	learn: 0.0015416	total: 305ms	remaining: 366ms
# 455:	learn: 0.0015372	total: 306ms	remaining: 365ms
# 456:	learn: 0.0015331	total: 306ms	remaining: 364ms
# 457:	learn: 0.0015288	total: 307ms	remaining: 363ms
# 458:	learn: 0.0015257	total: 308ms	remaining: 363ms
# 459:	learn: 0.0015214	total: 308ms	remaining: 362ms
# 460:	learn: 0.0015172	total: 309ms	remaining: 361ms
# 461:	learn: 0.0015140	total: 309ms	remaining: 360ms
# 462:	learn: 0.0015098	total: 310ms	remaining: 359ms
# 463:	learn: 0.0015063	total: 310ms	remaining: 359ms
# 464:	learn: 0.0015020	total: 311ms	remaining: 358ms
# 465:	learn: 0.0014986	total: 311ms	remaining: 357ms
# 466:	learn: 0.0014954	total: 312ms	remaining: 356ms
# 467:	learn: 0.0014920	total: 313ms	remaining: 355ms
# 468:	learn: 0.0014890	total: 313ms	remaining: 354ms
# 469:	learn: 0.0014856	total: 314ms	remaining: 354ms
# 470:	learn: 0.0014825	total: 314ms	remaining: 353ms
# 471:	learn: 0.0014795	total: 315ms	remaining: 352ms
# 472:	learn: 0.0014764	total: 315ms	remaining: 351ms
# 473:	learn: 0.0014735	total: 316ms	remaining: 351ms
# 474:	learn: 0.0014702	total: 317ms	remaining: 350ms
# 475:	learn: 0.0014667	total: 317ms	remaining: 349ms
# 476:	learn: 0.0014622	total: 318ms	remaining: 348ms
# 477:	learn: 0.0014583	total: 318ms	remaining: 348ms
# 478:	learn: 0.0014551	total: 319ms	remaining: 347ms
# 479:	learn: 0.0014516	total: 319ms	remaining: 346ms
# 480:	learn: 0.0014479	total: 320ms	remaining: 345ms
# 481:	learn: 0.0014441	total: 320ms	remaining: 344ms
# 482:	learn: 0.0014409	total: 321ms	remaining: 344ms
# 483:	learn: 0.0014371	total: 322ms	remaining: 343ms
# 484:	learn: 0.0014346	total: 322ms	remaining: 342ms
# 485:	learn: 0.0014310	total: 323ms	remaining: 341ms
# 486:	learn: 0.0014277	total: 323ms	remaining: 341ms
# 487:	learn: 0.0014240	total: 324ms	remaining: 340ms
# 488:	learn: 0.0014203	total: 324ms	remaining: 339ms
# 489:	learn: 0.0014162	total: 325ms	remaining: 338ms
# 490:	learn: 0.0014132	total: 326ms	remaining: 337ms
# 491:	learn: 0.0014100	total: 326ms	remaining: 337ms
# 492:	learn: 0.0014064	total: 327ms	remaining: 336ms
# 493:	learn: 0.0014032	total: 327ms	remaining: 335ms
# 494:	learn: 0.0014005	total: 328ms	remaining: 334ms
# 495:	learn: 0.0013974	total: 328ms	remaining: 334ms
# 496:	learn: 0.0013942	total: 329ms	remaining: 333ms
# 497:	learn: 0.0013911	total: 329ms	remaining: 332ms
# 498:	learn: 0.0013880	total: 330ms	remaining: 331ms
# 499:	learn: 0.0013853	total: 331ms	remaining: 331ms
# 500:	learn: 0.0013825	total: 331ms	remaining: 330ms
# 501:	learn: 0.0013794	total: 332ms	remaining: 329ms
# 502:	learn: 0.0013759	total: 332ms	remaining: 328ms
# 503:	learn: 0.0013724	total: 333ms	remaining: 328ms
# 504:	learn: 0.0013684	total: 333ms	remaining: 327ms
# 505:	learn: 0.0013653	total: 334ms	remaining: 326ms
# 506:	learn: 0.0013619	total: 334ms	remaining: 325ms
# 507:	learn: 0.0013593	total: 335ms	remaining: 324ms
# 508:	learn: 0.0013559	total: 336ms	remaining: 324ms
# 509:	learn: 0.0013532	total: 336ms	remaining: 323ms
# 510:	learn: 0.0013498	total: 337ms	remaining: 322ms
# 511:	learn: 0.0013470	total: 337ms	remaining: 321ms
# 512:	learn: 0.0013443	total: 338ms	remaining: 321ms
# 513:	learn: 0.0013410	total: 338ms	remaining: 320ms
# 514:	learn: 0.0013375	total: 339ms	remaining: 319ms
# 515:	learn: 0.0013345	total: 340ms	remaining: 318ms
# 516:	learn: 0.0013320	total: 340ms	remaining: 318ms
# 517:	learn: 0.0013293	total: 341ms	remaining: 317ms
# 518:	learn: 0.0013266	total: 341ms	remaining: 316ms
# 519:	learn: 0.0013234	total: 342ms	remaining: 315ms
# 520:	learn: 0.0013209	total: 342ms	remaining: 315ms
# 521:	learn: 0.0013183	total: 343ms	remaining: 314ms
# 522:	learn: 0.0013146	total: 343ms	remaining: 313ms
# 523:	learn: 0.0013119	total: 344ms	remaining: 312ms
# 524:	learn: 0.0013095	total: 344ms	remaining: 312ms
# 525:	learn: 0.0013071	total: 345ms	remaining: 311ms
# 526:	learn: 0.0013039	total: 346ms	remaining: 310ms
# 527:	learn: 0.0013010	total: 346ms	remaining: 310ms
# 528:	learn: 0.0012987	total: 347ms	remaining: 309ms
# 529:	learn: 0.0012959	total: 347ms	remaining: 308ms
# 530:	learn: 0.0012933	total: 348ms	remaining: 307ms
# 531:	learn: 0.0012910	total: 349ms	remaining: 307ms
# 532:	learn: 0.0012879	total: 349ms	remaining: 306ms
# 533:	learn: 0.0012854	total: 350ms	remaining: 305ms
# 534:	learn: 0.0012825	total: 350ms	remaining: 304ms
# 535:	learn: 0.0012794	total: 351ms	remaining: 304ms
# 536:	learn: 0.0012765	total: 351ms	remaining: 303ms
# 537:	learn: 0.0012735	total: 352ms	remaining: 302ms
# 538:	learn: 0.0012705	total: 353ms	remaining: 302ms
# 539:	learn: 0.0012678	total: 353ms	remaining: 301ms
# 540:	learn: 0.0012648	total: 354ms	remaining: 300ms
# 541:	learn: 0.0012622	total: 354ms	remaining: 299ms
# 542:	learn: 0.0012599	total: 355ms	remaining: 299ms
# 543:	learn: 0.0012564	total: 355ms	remaining: 298ms
# 544:	learn: 0.0012534	total: 356ms	remaining: 297ms
# 545:	learn: 0.0012511	total: 357ms	remaining: 297ms
# 546:	learn: 0.0012482	total: 358ms	remaining: 296ms
# 547:	learn: 0.0012456	total: 358ms	remaining: 296ms
# 548:	learn: 0.0012427	total: 359ms	remaining: 295ms
# 549:	learn: 0.0012407	total: 360ms	remaining: 294ms
# 550:	learn: 0.0012379	total: 360ms	remaining: 294ms
# 551:	learn: 0.0012354	total: 361ms	remaining: 293ms
# 552:	learn: 0.0012333	total: 362ms	remaining: 292ms
# 553:	learn: 0.0012310	total: 362ms	remaining: 292ms
# 554:	learn: 0.0012282	total: 363ms	remaining: 291ms
# 555:	learn: 0.0012260	total: 364ms	remaining: 291ms
# 556:	learn: 0.0012238	total: 364ms	remaining: 290ms
# 557:	learn: 0.0012218	total: 365ms	remaining: 289ms
# 558:	learn: 0.0012189	total: 366ms	remaining: 289ms
# 559:	learn: 0.0012166	total: 367ms	remaining: 288ms
# 560:	learn: 0.0012142	total: 367ms	remaining: 287ms
# 561:	learn: 0.0012115	total: 368ms	remaining: 287ms
# 562:	learn: 0.0012095	total: 369ms	remaining: 286ms
# 563:	learn: 0.0012068	total: 369ms	remaining: 285ms
# 564:	learn: 0.0012041	total: 370ms	remaining: 285ms
# 565:	learn: 0.0012020	total: 370ms	remaining: 284ms
# 566:	learn: 0.0011993	total: 371ms	remaining: 283ms
# 567:	learn: 0.0011967	total: 372ms	remaining: 283ms
# 568:	learn: 0.0011941	total: 372ms	remaining: 282ms
# 569:	learn: 0.0011914	total: 373ms	remaining: 281ms
# 570:	learn: 0.0011893	total: 374ms	remaining: 281ms
# 571:	learn: 0.0011866	total: 374ms	remaining: 280ms
# 572:	learn: 0.0011842	total: 375ms	remaining: 280ms
# 573:	learn: 0.0011821	total: 376ms	remaining: 279ms
# 574:	learn: 0.0011796	total: 377ms	remaining: 278ms
# 575:	learn: 0.0011773	total: 377ms	remaining: 278ms
# 576:	learn: 0.0011753	total: 378ms	remaining: 277ms
# 577:	learn: 0.0011734	total: 379ms	remaining: 276ms
# 578:	learn: 0.0011713	total: 379ms	remaining: 276ms
# 579:	learn: 0.0011694	total: 380ms	remaining: 275ms
# 580:	learn: 0.0011672	total: 380ms	remaining: 274ms
# 581:	learn: 0.0011653	total: 381ms	remaining: 274ms
# 582:	learn: 0.0011634	total: 382ms	remaining: 273ms
# 583:	learn: 0.0011609	total: 382ms	remaining: 272ms
# 584:	learn: 0.0011594	total: 383ms	remaining: 272ms
# 585:	learn: 0.0011575	total: 383ms	remaining: 271ms
# 586:	learn: 0.0011551	total: 384ms	remaining: 270ms
# 587:	learn: 0.0011530	total: 385ms	remaining: 269ms
# 588:	learn: 0.0011513	total: 385ms	remaining: 269ms
# 589:	learn: 0.0011489	total: 386ms	remaining: 268ms
# 590:	learn: 0.0011469	total: 386ms	remaining: 267ms
# 591:	learn: 0.0011448	total: 387ms	remaining: 267ms
# 592:	learn: 0.0011430	total: 387ms	remaining: 266ms
# 593:	learn: 0.0011410	total: 388ms	remaining: 265ms
# 594:	learn: 0.0011387	total: 389ms	remaining: 264ms
# 595:	learn: 0.0011367	total: 389ms	remaining: 264ms
# 596:	learn: 0.0011349	total: 390ms	remaining: 263ms
# 597:	learn: 0.0011329	total: 390ms	remaining: 262ms
# 598:	learn: 0.0011311	total: 391ms	remaining: 262ms
# 599:	learn: 0.0011287	total: 391ms	remaining: 261ms
# 600:	learn: 0.0011263	total: 392ms	remaining: 260ms
# 601:	learn: 0.0011240	total: 392ms	remaining: 259ms
# 602:	learn: 0.0011218	total: 393ms	remaining: 259ms
# 603:	learn: 0.0011198	total: 394ms	remaining: 258ms
# 604:	learn: 0.0011180	total: 394ms	remaining: 257ms
# 605:	learn: 0.0011159	total: 395ms	remaining: 257ms
# 606:	learn: 0.0011141	total: 395ms	remaining: 256ms
# 607:	learn: 0.0011118	total: 396ms	remaining: 255ms
# 608:	learn: 0.0011101	total: 396ms	remaining: 254ms
# 609:	learn: 0.0011075	total: 397ms	remaining: 254ms
# 610:	learn: 0.0011056	total: 398ms	remaining: 253ms
# 611:	learn: 0.0011037	total: 398ms	remaining: 252ms
# 612:	learn: 0.0011020	total: 399ms	remaining: 252ms
# 613:	learn: 0.0011001	total: 399ms	remaining: 251ms
# 614:	learn: 0.0010982	total: 400ms	remaining: 250ms
# 615:	learn: 0.0010963	total: 400ms	remaining: 250ms
# 616:	learn: 0.0010940	total: 401ms	remaining: 249ms
# 617:	learn: 0.0010918	total: 401ms	remaining: 248ms
# 618:	learn: 0.0010900	total: 402ms	remaining: 247ms
# 619:	learn: 0.0010881	total: 402ms	remaining: 247ms
# 620:	learn: 0.0010864	total: 403ms	remaining: 246ms
# 621:	learn: 0.0010847	total: 404ms	remaining: 245ms
# 622:	learn: 0.0010828	total: 404ms	remaining: 245ms
# 623:	learn: 0.0010807	total: 405ms	remaining: 244ms
# 624:	learn: 0.0010785	total: 405ms	remaining: 243ms
# 625:	learn: 0.0010764	total: 406ms	remaining: 243ms
# 626:	learn: 0.0010748	total: 407ms	remaining: 242ms
# 627:	learn: 0.0010732	total: 407ms	remaining: 241ms
# 628:	learn: 0.0010711	total: 408ms	remaining: 241ms
# 629:	learn: 0.0010695	total: 408ms	remaining: 240ms
# 630:	learn: 0.0010677	total: 409ms	remaining: 239ms
# 631:	learn: 0.0010656	total: 409ms	remaining: 238ms
# 632:	learn: 0.0010638	total: 410ms	remaining: 238ms
# 633:	learn: 0.0010623	total: 411ms	remaining: 237ms
# 634:	learn: 0.0010609	total: 411ms	remaining: 236ms
# 635:	learn: 0.0010591	total: 412ms	remaining: 236ms
# 636:	learn: 0.0010567	total: 412ms	remaining: 235ms
# 637:	learn: 0.0010551	total: 413ms	remaining: 234ms
# 638:	learn: 0.0010534	total: 413ms	remaining: 234ms
# 639:	learn: 0.0010514	total: 414ms	remaining: 233ms
# 640:	learn: 0.0010495	total: 414ms	remaining: 232ms
# 641:	learn: 0.0010475	total: 415ms	remaining: 231ms
# 642:	learn: 0.0010460	total: 416ms	remaining: 231ms
# 643:	learn: 0.0010440	total: 416ms	remaining: 230ms
# 644:	learn: 0.0010425	total: 417ms	remaining: 229ms
# 645:	learn: 0.0010407	total: 417ms	remaining: 229ms
# 646:	learn: 0.0010387	total: 418ms	remaining: 228ms
# 647:	learn: 0.0010370	total: 418ms	remaining: 227ms
# 648:	learn: 0.0010354	total: 419ms	remaining: 226ms
# 649:	learn: 0.0010335	total: 419ms	remaining: 226ms
# 650:	learn: 0.0010318	total: 420ms	remaining: 225ms
# 651:	learn: 0.0010299	total: 420ms	remaining: 224ms
# 652:	learn: 0.0010282	total: 421ms	remaining: 224ms
# 653:	learn: 0.0010264	total: 422ms	remaining: 223ms
# 654:	learn: 0.0010246	total: 422ms	remaining: 222ms
# 655:	learn: 0.0010233	total: 423ms	remaining: 222ms
# 656:	learn: 0.0010218	total: 423ms	remaining: 221ms
# 657:	learn: 0.0010199	total: 424ms	remaining: 220ms
# 658:	learn: 0.0010180	total: 424ms	remaining: 220ms
# 659:	learn: 0.0010165	total: 425ms	remaining: 219ms
# 660:	learn: 0.0010145	total: 425ms	remaining: 218ms
# 661:	learn: 0.0010130	total: 426ms	remaining: 217ms
# 662:	learn: 0.0010111	total: 427ms	remaining: 217ms
# 663:	learn: 0.0010095	total: 427ms	remaining: 216ms
# 664:	learn: 0.0010078	total: 428ms	remaining: 216ms
# 665:	learn: 0.0010059	total: 428ms	remaining: 215ms
# 666:	learn: 0.0010040	total: 429ms	remaining: 214ms
# 667:	learn: 0.0010026	total: 429ms	remaining: 213ms
# 668:	learn: 0.0010010	total: 430ms	remaining: 213ms
# 669:	learn: 0.0009996	total: 430ms	remaining: 212ms
# 670:	learn: 0.0009980	total: 431ms	remaining: 211ms
# 671:	learn: 0.0009965	total: 432ms	remaining: 211ms
# 672:	learn: 0.0009950	total: 432ms	remaining: 210ms
# 673:	learn: 0.0009934	total: 433ms	remaining: 209ms
# 674:	learn: 0.0009920	total: 433ms	remaining: 209ms
# 675:	learn: 0.0009905	total: 434ms	remaining: 208ms
# 676:	learn: 0.0009891	total: 434ms	remaining: 207ms
# 677:	learn: 0.0009875	total: 435ms	remaining: 207ms
# 678:	learn: 0.0009860	total: 435ms	remaining: 206ms
# 679:	learn: 0.0009846	total: 436ms	remaining: 205ms
# 680:	learn: 0.0009832	total: 437ms	remaining: 204ms
# 681:	learn: 0.0009818	total: 437ms	remaining: 204ms
# 682:	learn: 0.0009800	total: 438ms	remaining: 203ms
# 683:	learn: 0.0009785	total: 438ms	remaining: 202ms
# 684:	learn: 0.0009768	total: 439ms	remaining: 202ms
# 685:	learn: 0.0009755	total: 439ms	remaining: 201ms
# 686:	learn: 0.0009737	total: 440ms	remaining: 200ms
# 687:	learn: 0.0009720	total: 440ms	remaining: 200ms
# 688:	learn: 0.0009707	total: 441ms	remaining: 199ms
# 689:	learn: 0.0009693	total: 442ms	remaining: 198ms
# 690:	learn: 0.0009679	total: 442ms	remaining: 198ms
# 691:	learn: 0.0009665	total: 443ms	remaining: 197ms
# 692:	learn: 0.0009648	total: 443ms	remaining: 196ms
# 693:	learn: 0.0009636	total: 444ms	remaining: 196ms
# 694:	learn: 0.0009623	total: 445ms	remaining: 195ms
# 695:	learn: 0.0009610	total: 445ms	remaining: 194ms
# 696:	learn: 0.0009597	total: 446ms	remaining: 194ms
# 697:	learn: 0.0009584	total: 446ms	remaining: 193ms
# 698:	learn: 0.0009568	total: 447ms	remaining: 192ms
# 699:	learn: 0.0009554	total: 447ms	remaining: 192ms
# 700:	learn: 0.0009542	total: 448ms	remaining: 191ms
# 701:	learn: 0.0009525	total: 448ms	remaining: 190ms
# 702:	learn: 0.0009511	total: 449ms	remaining: 190ms
# 703:	learn: 0.0009494	total: 449ms	remaining: 189ms
# 704:	learn: 0.0009480	total: 450ms	remaining: 188ms
# 705:	learn: 0.0009468	total: 451ms	remaining: 188ms
# 706:	learn: 0.0009454	total: 451ms	remaining: 187ms
# 707:	learn: 0.0009437	total: 452ms	remaining: 186ms
# 708:	learn: 0.0009424	total: 452ms	remaining: 186ms
# 709:	learn: 0.0009410	total: 453ms	remaining: 185ms
# 710:	learn: 0.0009394	total: 454ms	remaining: 184ms
# 711:	learn: 0.0009381	total: 454ms	remaining: 184ms
# 712:	learn: 0.0009370	total: 455ms	remaining: 183ms
# 713:	learn: 0.0009357	total: 456ms	remaining: 182ms
# 714:	learn: 0.0009341	total: 456ms	remaining: 182ms
# 715:	learn: 0.0009325	total: 457ms	remaining: 181ms
# 716:	learn: 0.0009310	total: 457ms	remaining: 180ms
# 717:	learn: 0.0009298	total: 458ms	remaining: 180ms
# 718:	learn: 0.0009277	total: 459ms	remaining: 179ms
# 719:	learn: 0.0009261	total: 459ms	remaining: 179ms
# 720:	learn: 0.0009248	total: 460ms	remaining: 178ms
# 721:	learn: 0.0009235	total: 460ms	remaining: 177ms
# 722:	learn: 0.0009219	total: 461ms	remaining: 177ms
# 723:	learn: 0.0009206	total: 461ms	remaining: 176ms
# 724:	learn: 0.0009194	total: 462ms	remaining: 175ms
# 725:	learn: 0.0009182	total: 462ms	remaining: 175ms
# 726:	learn: 0.0009167	total: 463ms	remaining: 174ms
# 727:	learn: 0.0009155	total: 464ms	remaining: 173ms
# 728:	learn: 0.0009143	total: 464ms	remaining: 173ms
# 729:	learn: 0.0009130	total: 465ms	remaining: 172ms
# 730:	learn: 0.0009118	total: 465ms	remaining: 171ms
# 731:	learn: 0.0009107	total: 466ms	remaining: 171ms
# 732:	learn: 0.0009092	total: 467ms	remaining: 170ms
# 733:	learn: 0.0009080	total: 467ms	remaining: 169ms
# 734:	learn: 0.0009068	total: 468ms	remaining: 169ms
# 735:	learn: 0.0009055	total: 468ms	remaining: 168ms
# 736:	learn: 0.0009042	total: 469ms	remaining: 167ms
# 737:	learn: 0.0009031	total: 469ms	remaining: 167ms
# 738:	learn: 0.0009016	total: 470ms	remaining: 166ms
# 739:	learn: 0.0009004	total: 470ms	remaining: 165ms
# 740:	learn: 0.0008991	total: 471ms	remaining: 165ms
# 741:	learn: 0.0008978	total: 472ms	remaining: 164ms
# 742:	learn: 0.0008963	total: 472ms	remaining: 163ms
# 743:	learn: 0.0008948	total: 473ms	remaining: 163ms
# 744:	learn: 0.0008936	total: 473ms	remaining: 162ms
# 745:	learn: 0.0008923	total: 474ms	remaining: 161ms
# 746:	learn: 0.0008912	total: 474ms	remaining: 161ms
# 747:	learn: 0.0008900	total: 475ms	remaining: 160ms
# 748:	learn: 0.0008888	total: 475ms	remaining: 159ms
# 749:	learn: 0.0008876	total: 476ms	remaining: 159ms
# 750:	learn: 0.0008861	total: 477ms	remaining: 158ms
# 751:	learn: 0.0008849	total: 477ms	remaining: 157ms
# 752:	learn: 0.0008838	total: 478ms	remaining: 157ms
# 753:	learn: 0.0008826	total: 478ms	remaining: 156ms
# 754:	learn: 0.0008815	total: 479ms	remaining: 155ms
# 755:	learn: 0.0008805	total: 480ms	remaining: 155ms
# 756:	learn: 0.0008794	total: 480ms	remaining: 154ms
# 757:	learn: 0.0008784	total: 481ms	remaining: 153ms
# 758:	learn: 0.0008773	total: 481ms	remaining: 153ms
# 759:	learn: 0.0008761	total: 482ms	remaining: 152ms
# 760:	learn: 0.0008751	total: 482ms	remaining: 152ms
# 761:	learn: 0.0008734	total: 483ms	remaining: 151ms
# 762:	learn: 0.0008720	total: 483ms	remaining: 150ms
# 763:	learn: 0.0008708	total: 484ms	remaining: 150ms
# 764:	learn: 0.0008697	total: 485ms	remaining: 149ms
# 765:	learn: 0.0008686	total: 485ms	remaining: 148ms
# 766:	learn: 0.0008675	total: 486ms	remaining: 148ms
# 767:	learn: 0.0008662	total: 486ms	remaining: 147ms
# 768:	learn: 0.0008648	total: 487ms	remaining: 146ms
# 769:	learn: 0.0008637	total: 487ms	remaining: 146ms
# 770:	learn: 0.0008626	total: 488ms	remaining: 145ms
# 771:	learn: 0.0008616	total: 489ms	remaining: 144ms
# 772:	learn: 0.0008606	total: 489ms	remaining: 144ms
# 773:	learn: 0.0008595	total: 490ms	remaining: 143ms
# 774:	learn: 0.0008584	total: 490ms	remaining: 142ms
# 775:	learn: 0.0008571	total: 491ms	remaining: 142ms
# 776:	learn: 0.0008561	total: 491ms	remaining: 141ms
# 777:	learn: 0.0008550	total: 492ms	remaining: 140ms
# 778:	learn: 0.0008539	total: 492ms	remaining: 140ms
# 779:	learn: 0.0008528	total: 493ms	remaining: 139ms
# 780:	learn: 0.0008515	total: 493ms	remaining: 138ms
# 781:	learn: 0.0008503	total: 494ms	remaining: 138ms
# 782:	learn: 0.0008492	total: 495ms	remaining: 137ms
# 783:	learn: 0.0008480	total: 495ms	remaining: 136ms
# 784:	learn: 0.0008467	total: 496ms	remaining: 136ms
# 785:	learn: 0.0008454	total: 496ms	remaining: 135ms
# 786:	learn: 0.0008445	total: 497ms	remaining: 134ms
# 787:	learn: 0.0008435	total: 497ms	remaining: 134ms
# 788:	learn: 0.0008426	total: 498ms	remaining: 133ms
# 789:	learn: 0.0008416	total: 499ms	remaining: 133ms
# 790:	learn: 0.0008407	total: 499ms	remaining: 132ms
# 791:	learn: 0.0008396	total: 500ms	remaining: 131ms
# 792:	learn: 0.0008387	total: 500ms	remaining: 131ms
# 793:	learn: 0.0008374	total: 501ms	remaining: 130ms
# 794:	learn: 0.0008364	total: 502ms	remaining: 129ms
# 795:	learn: 0.0008354	total: 502ms	remaining: 129ms
# 796:	learn: 0.0008341	total: 503ms	remaining: 128ms
# 797:	learn: 0.0008329	total: 503ms	remaining: 127ms
# 798:	learn: 0.0008319	total: 504ms	remaining: 127ms
# 799:	learn: 0.0008309	total: 504ms	remaining: 126ms
# 800:	learn: 0.0008299	total: 505ms	remaining: 125ms
# 801:	learn: 0.0008288	total: 505ms	remaining: 125ms
# 802:	learn: 0.0008276	total: 506ms	remaining: 124ms
# 803:	learn: 0.0008260	total: 506ms	remaining: 123ms
# 804:	learn: 0.0008251	total: 507ms	remaining: 123ms
# 805:	learn: 0.0008239	total: 508ms	remaining: 122ms
# 806:	learn: 0.0008229	total: 508ms	remaining: 122ms
# 807:	learn: 0.0008216	total: 509ms	remaining: 121ms
# 808:	learn: 0.0008206	total: 509ms	remaining: 120ms
# 809:	learn: 0.0008195	total: 510ms	remaining: 120ms
# 810:	learn: 0.0008186	total: 510ms	remaining: 119ms
# 811:	learn: 0.0008177	total: 511ms	remaining: 118ms
# 812:	learn: 0.0008167	total: 511ms	remaining: 118ms
# 813:	learn: 0.0008157	total: 512ms	remaining: 117ms
# 814:	learn: 0.0008147	total: 512ms	remaining: 116ms
# 815:	learn: 0.0008137	total: 513ms	remaining: 116ms
# 816:	learn: 0.0008127	total: 514ms	remaining: 115ms
# 817:	learn: 0.0008118	total: 514ms	remaining: 114ms
# 818:	learn: 0.0008108	total: 515ms	remaining: 114ms
# 819:	learn: 0.0008098	total: 515ms	remaining: 113ms
# 820:	learn: 0.0008089	total: 516ms	remaining: 112ms
# 821:	learn: 0.0008080	total: 517ms	remaining: 112ms
# 822:	learn: 0.0008071	total: 517ms	remaining: 111ms
# 823:	learn: 0.0008062	total: 518ms	remaining: 111ms
# 824:	learn: 0.0008053	total: 518ms	remaining: 110ms
# 825:	learn: 0.0008043	total: 519ms	remaining: 109ms
# 826:	learn: 0.0008035	total: 519ms	remaining: 109ms
# 827:	learn: 0.0008025	total: 520ms	remaining: 108ms
# 828:	learn: 0.0008015	total: 520ms	remaining: 107ms
# 829:	learn: 0.0008005	total: 521ms	remaining: 107ms
# 830:	learn: 0.0007995	total: 521ms	remaining: 106ms
# 831:	learn: 0.0007986	total: 522ms	remaining: 105ms
# 832:	learn: 0.0007976	total: 523ms	remaining: 105ms
# 833:	learn: 0.0007964	total: 523ms	remaining: 104ms
# 834:	learn: 0.0007953	total: 524ms	remaining: 104ms
# 835:	learn: 0.0007941	total: 524ms	remaining: 103ms
# 836:	learn: 0.0007932	total: 525ms	remaining: 102ms
# 837:	learn: 0.0007923	total: 526ms	remaining: 102ms
# 838:	learn: 0.0007912	total: 526ms	remaining: 101ms
# 839:	learn: 0.0007901	total: 527ms	remaining: 100ms
# 840:	learn: 0.0007892	total: 527ms	remaining: 99.7ms
# 841:	learn: 0.0007880	total: 528ms	remaining: 99ms
# 842:	learn: 0.0007869	total: 528ms	remaining: 98.4ms
# 843:	learn: 0.0007860	total: 529ms	remaining: 97.7ms
# 844:	learn: 0.0007849	total: 529ms	remaining: 97.1ms
# 845:	learn: 0.0007838	total: 530ms	remaining: 96.5ms
# 846:	learn: 0.0007826	total: 531ms	remaining: 95.8ms
# 847:	learn: 0.0007815	total: 531ms	remaining: 95.2ms
# 848:	learn: 0.0007805	total: 532ms	remaining: 94.6ms
# 849:	learn: 0.0007796	total: 532ms	remaining: 93.9ms
# 850:	learn: 0.0007787	total: 533ms	remaining: 93.3ms
# 851:	learn: 0.0007778	total: 533ms	remaining: 92.6ms
# 852:	learn: 0.0007769	total: 534ms	remaining: 92ms
# 853:	learn: 0.0007760	total: 534ms	remaining: 91.4ms
# 854:	learn: 0.0007751	total: 535ms	remaining: 90.7ms
# 855:	learn: 0.0007743	total: 536ms	remaining: 90.1ms
# 856:	learn: 0.0007734	total: 536ms	remaining: 89.5ms
# 857:	learn: 0.0007725	total: 537ms	remaining: 88.9ms
# 858:	learn: 0.0007715	total: 538ms	remaining: 88.3ms
# 859:	learn: 0.0007706	total: 538ms	remaining: 87.6ms
# 860:	learn: 0.0007695	total: 539ms	remaining: 87ms
# 861:	learn: 0.0007686	total: 540ms	remaining: 86.4ms
# 862:	learn: 0.0007678	total: 540ms	remaining: 85.8ms
# 863:	learn: 0.0007669	total: 541ms	remaining: 85.2ms
# 864:	learn: 0.0007658	total: 542ms	remaining: 84.6ms
# 865:	learn: 0.0007647	total: 543ms	remaining: 84ms
# 866:	learn: 0.0007639	total: 543ms	remaining: 83.4ms
# 867:	learn: 0.0007630	total: 544ms	remaining: 82.8ms
# 868:	learn: 0.0007621	total: 545ms	remaining: 82.1ms
# 869:	learn: 0.0007613	total: 546ms	remaining: 81.5ms
# 870:	learn: 0.0007604	total: 546ms	remaining: 80.9ms
# 871:	learn: 0.0007597	total: 547ms	remaining: 80.3ms
# 872:	learn: 0.0007589	total: 548ms	remaining: 79.7ms
# 873:	learn: 0.0007581	total: 548ms	remaining: 79ms
# 874:	learn: 0.0007571	total: 549ms	remaining: 78.4ms
# 875:	learn: 0.0007562	total: 549ms	remaining: 77.8ms
# 876:	learn: 0.0007552	total: 550ms	remaining: 77.1ms
# 877:	learn: 0.0007539	total: 550ms	remaining: 76.5ms
# 878:	learn: 0.0007531	total: 551ms	remaining: 75.8ms
# 879:	learn: 0.0007524	total: 551ms	remaining: 75.2ms
# 880:	learn: 0.0007515	total: 552ms	remaining: 74.6ms
# 881:	learn: 0.0007505	total: 553ms	remaining: 74ms
# 882:	learn: 0.0007495	total: 554ms	remaining: 73.4ms
# 883:	learn: 0.0007486	total: 554ms	remaining: 72.7ms
# 884:	learn: 0.0007478	total: 555ms	remaining: 72.1ms
# 885:	learn: 0.0007470	total: 556ms	remaining: 71.5ms
# 886:	learn: 0.0007460	total: 556ms	remaining: 70.9ms
# 887:	learn: 0.0007450	total: 557ms	remaining: 70.3ms
# 888:	learn: 0.0007442	total: 558ms	remaining: 69.6ms
# 889:	learn: 0.0007432	total: 558ms	remaining: 69ms
# 890:	learn: 0.0007424	total: 559ms	remaining: 68.4ms
# 891:	learn: 0.0007415	total: 559ms	remaining: 67.7ms
# 892:	learn: 0.0007407	total: 560ms	remaining: 67.1ms
# 893:	learn: 0.0007399	total: 561ms	remaining: 66.5ms
# 894:	learn: 0.0007389	total: 561ms	remaining: 65.9ms
# 895:	learn: 0.0007381	total: 562ms	remaining: 65.2ms
# 896:	learn: 0.0007374	total: 563ms	remaining: 64.6ms
# 897:	learn: 0.0007366	total: 563ms	remaining: 64ms
# 898:	learn: 0.0007358	total: 564ms	remaining: 63.3ms
# 899:	learn: 0.0007351	total: 564ms	remaining: 62.7ms
# 900:	learn: 0.0007343	total: 565ms	remaining: 62ms
# 901:	learn: 0.0007333	total: 565ms	remaining: 61.4ms
# 902:	learn: 0.0007326	total: 566ms	remaining: 60.8ms
# 903:	learn: 0.0007316	total: 566ms	remaining: 60.1ms
# 904:	learn: 0.0007309	total: 567ms	remaining: 59.5ms
# 905:	learn: 0.0007301	total: 567ms	remaining: 58.9ms
# 906:	learn: 0.0007293	total: 568ms	remaining: 58.2ms
# 907:	learn: 0.0007285	total: 569ms	remaining: 57.6ms
# 908:	learn: 0.0007278	total: 569ms	remaining: 57ms
# 909:	learn: 0.0007271	total: 570ms	remaining: 56.4ms
# 910:	learn: 0.0007262	total: 571ms	remaining: 55.7ms
# ...
# 748:	learn: 0.0008462	total: 636ms	remaining: 213ms
# 749:	learn: 0.0008450	total: 637ms	remaining: 212ms
# 750:	learn: 0.0008436	total: 638ms	remaining: 212ms
# 751:	learn: 0.0008424	total: 639ms	remaining: 211ms
# 752:	learn: 0.0008412	total: 640ms	remaining: 210ms
# 753:	learn: 0.0008401	total: 641ms	remaining: 209ms
# 754:	learn: 0.0008388	total: 642ms	remaining: 208ms
# 755:	learn: 0.0008377	total: 642ms	remaining: 207ms
# 756:	learn: 0.0008367	total: 643ms	remaining: 207ms
# 757:	learn: 0.0008356	total: 645ms	remaining: 206ms
# 758:	learn: 0.0008342	total: 648ms	remaining: 206ms
# 759:	learn: 0.0008331	total: 649ms	remaining: 205ms
# 760:	learn: 0.0008321	total: 650ms	remaining: 204ms
# 761:	learn: 0.0008308	total: 651ms	remaining: 203ms
# 762:	learn: 0.0008297	total: 652ms	remaining: 203ms
# 763:	learn: 0.0008286	total: 653ms	remaining: 202ms
# 764:	learn: 0.0008274	total: 655ms	remaining: 201ms
# 765:	learn: 0.0008261	total: 656ms	remaining: 200ms
# 766:	learn: 0.0008250	total: 658ms	remaining: 200ms
# 767:	learn: 0.0008238	total: 659ms	remaining: 199ms
# 768:	learn: 0.0008224	total: 660ms	remaining: 198ms
# 769:	learn: 0.0008210	total: 661ms	remaining: 197ms
# 770:	learn: 0.0008201	total: 662ms	remaining: 197ms
# 771:	learn: 0.0008190	total: 664ms	remaining: 196ms
# 772:	learn: 0.0008178	total: 665ms	remaining: 195ms
# 773:	learn: 0.0008165	total: 665ms	remaining: 194ms
# 774:	learn: 0.0008154	total: 666ms	remaining: 193ms
# 775:	learn: 0.0008143	total: 667ms	remaining: 192ms
# 776:	learn: 0.0008130	total: 667ms	remaining: 192ms
# 777:	learn: 0.0008120	total: 668ms	remaining: 191ms
# 778:	learn: 0.0008109	total: 669ms	remaining: 190ms
# 779:	learn: 0.0008097	total: 670ms	remaining: 189ms
# 780:	learn: 0.0008085	total: 671ms	remaining: 188ms
# 781:	learn: 0.0008074	total: 672ms	remaining: 187ms
# 782:	learn: 0.0008061	total: 673ms	remaining: 186ms
# 783:	learn: 0.0008049	total: 674ms	remaining: 186ms
# 784:	learn: 0.0008037	total: 675ms	remaining: 185ms
# 785:	learn: 0.0008021	total: 676ms	remaining: 184ms
# 786:	learn: 0.0008010	total: 677ms	remaining: 183ms
# 787:	learn: 0.0007999	total: 678ms	remaining: 182ms
# 788:	learn: 0.0007989	total: 679ms	remaining: 182ms
# 789:	learn: 0.0007978	total: 680ms	remaining: 181ms
# 790:	learn: 0.0007967	total: 681ms	remaining: 180ms
# 791:	learn: 0.0007956	total: 682ms	remaining: 179ms
# 792:	learn: 0.0007941	total: 683ms	remaining: 178ms
# 793:	learn: 0.0007932	total: 684ms	remaining: 178ms
# 794:	learn: 0.0007921	total: 685ms	remaining: 177ms
# 795:	learn: 0.0007909	total: 686ms	remaining: 176ms
# 796:	learn: 0.0007896	total: 687ms	remaining: 175ms
# 797:	learn: 0.0007885	total: 688ms	remaining: 174ms
# 798:	learn: 0.0007872	total: 689ms	remaining: 173ms
# 799:	learn: 0.0007863	total: 690ms	remaining: 173ms
# 800:	learn: 0.0007854	total: 691ms	remaining: 172ms
# 801:	learn: 0.0007846	total: 692ms	remaining: 171ms
# 802:	learn: 0.0007837	total: 693ms	remaining: 170ms
# 803:	learn: 0.0007828	total: 695ms	remaining: 169ms
# 804:	learn: 0.0007818	total: 696ms	remaining: 169ms
# 805:	learn: 0.0007806	total: 698ms	remaining: 168ms
# 806:	learn: 0.0007796	total: 699ms	remaining: 167ms
# 807:	learn: 0.0007785	total: 701ms	remaining: 167ms
# 808:	learn: 0.0007775	total: 702ms	remaining: 166ms
# 809:	learn: 0.0007765	total: 706ms	remaining: 165ms
# 810:	learn: 0.0007751	total: 707ms	remaining: 165ms
# 811:	learn: 0.0007741	total: 708ms	remaining: 164ms
# 812:	learn: 0.0007733	total: 709ms	remaining: 163ms
# 813:	learn: 0.0007724	total: 710ms	remaining: 162ms
# 814:	learn: 0.0007714	total: 711ms	remaining: 161ms
# 815:	learn: 0.0007702	total: 712ms	remaining: 160ms
# 816:	learn: 0.0007693	total: 713ms	remaining: 160ms
# 817:	learn: 0.0007683	total: 714ms	remaining: 159ms
# 818:	learn: 0.0007674	total: 715ms	remaining: 158ms
# 819:	learn: 0.0007664	total: 716ms	remaining: 157ms
# 820:	learn: 0.0007655	total: 716ms	remaining: 156ms
# 821:	learn: 0.0007644	total: 717ms	remaining: 155ms
# 822:	learn: 0.0007634	total: 718ms	remaining: 154ms
# 823:	learn: 0.0007620	total: 719ms	remaining: 154ms
# 824:	learn: 0.0007609	total: 720ms	remaining: 153ms
# 825:	learn: 0.0007598	total: 721ms	remaining: 152ms
# 826:	learn: 0.0007588	total: 722ms	remaining: 151ms
# 827:	learn: 0.0007576	total: 722ms	remaining: 150ms
# 828:	learn: 0.0007568	total: 723ms	remaining: 149ms
# 829:	learn: 0.0007557	total: 724ms	remaining: 148ms
# 830:	learn: 0.0007549	total: 725ms	remaining: 147ms
# 831:	learn: 0.0007539	total: 726ms	remaining: 147ms
# 832:	learn: 0.0007529	total: 727ms	remaining: 146ms
# 833:	learn: 0.0007517	total: 728ms	remaining: 145ms
# 834:	learn: 0.0007507	total: 729ms	remaining: 144ms
# 835:	learn: 0.0007498	total: 729ms	remaining: 143ms
# 836:	learn: 0.0007488	total: 730ms	remaining: 142ms
# 837:	learn: 0.0007478	total: 731ms	remaining: 141ms
# 838:	learn: 0.0007469	total: 732ms	remaining: 140ms
# 839:	learn: 0.0007459	total: 733ms	remaining: 140ms
# 840:	learn: 0.0007449	total: 734ms	remaining: 139ms
# 841:	learn: 0.0007439	total: 735ms	remaining: 138ms
# 842:	learn: 0.0007431	total: 737ms	remaining: 137ms
# 843:	learn: 0.0007420	total: 737ms	remaining: 136ms
# 844:	learn: 0.0007411	total: 739ms	remaining: 135ms
# 845:	learn: 0.0007401	total: 740ms	remaining: 135ms
# 846:	learn: 0.0007391	total: 741ms	remaining: 134ms
# 847:	learn: 0.0007381	total: 743ms	remaining: 133ms
# 848:	learn: 0.0007372	total: 745ms	remaining: 132ms
# 849:	learn: 0.0007362	total: 746ms	remaining: 132ms
# 850:	learn: 0.0007348	total: 748ms	remaining: 131ms
# 851:	learn: 0.0007338	total: 749ms	remaining: 130ms
# 852:	learn: 0.0007326	total: 751ms	remaining: 129ms
# 853:	learn: 0.0007317	total: 752ms	remaining: 128ms
# 854:	learn: 0.0007309	total: 754ms	remaining: 128ms
# 855:	learn: 0.0007298	total: 755ms	remaining: 127ms
# 856:	learn: 0.0007288	total: 756ms	remaining: 126ms
# 857:	learn: 0.0007279	total: 757ms	remaining: 125ms
# 858:	learn: 0.0007271	total: 757ms	remaining: 124ms
# 859:	learn: 0.0007262	total: 758ms	remaining: 123ms
# 860:	learn: 0.0007254	total: 759ms	remaining: 123ms
# 861:	learn: 0.0007245	total: 760ms	remaining: 122ms
# 862:	learn: 0.0007234	total: 761ms	remaining: 121ms
# 863:	learn: 0.0007225	total: 762ms	remaining: 120ms
# 864:	learn: 0.0007214	total: 763ms	remaining: 119ms
# 865:	learn: 0.0007207	total: 764ms	remaining: 118ms
# 866:	learn: 0.0007198	total: 838ms	remaining: 129ms
# 867:	learn: 0.0007187	total: 839ms	remaining: 128ms
# 868:	learn: 0.0007176	total: 840ms	remaining: 127ms
# 869:	learn: 0.0007167	total: 840ms	remaining: 126ms
# 870:	learn: 0.0007158	total: 842ms	remaining: 125ms
# 871:	learn: 0.0007148	total: 843ms	remaining: 124ms
# 872:	learn: 0.0007140	total: 844ms	remaining: 123ms
# 873:	learn: 0.0007133	total: 844ms	remaining: 122ms
# 874:	learn: 0.0007124	total: 848ms	remaining: 121ms
# 875:	learn: 0.0007115	total: 849ms	remaining: 120ms
# 876:	learn: 0.0007107	total: 861ms	remaining: 121ms
# 877:	learn: 0.0007098	total: 862ms	remaining: 120ms
# 878:	learn: 0.0007091	total: 863ms	remaining: 119ms
# 879:	learn: 0.0007083	total: 865ms	remaining: 118ms
# 880:	learn: 0.0007075	total: 866ms	remaining: 117ms
# 881:	learn: 0.0007067	total: 867ms	remaining: 116ms
# 882:	learn: 0.0007059	total: 869ms	remaining: 115ms
# 883:	learn: 0.0007052	total: 870ms	remaining: 114ms
# 884:	learn: 0.0007043	total: 871ms	remaining: 113ms
# 885:	learn: 0.0007036	total: 873ms	remaining: 112ms
# 886:	learn: 0.0007026	total: 874ms	remaining: 111ms
# 887:	learn: 0.0007018	total: 875ms	remaining: 110ms
# 888:	learn: 0.0007008	total: 876ms	remaining: 109ms
# 889:	learn: 0.0006999	total: 878ms	remaining: 108ms
# 890:	learn: 0.0006991	total: 879ms	remaining: 108ms
# 891:	learn: 0.0006981	total: 880ms	remaining: 107ms
# 892:	learn: 0.0006974	total: 882ms	remaining: 106ms
# 893:	learn: 0.0006965	total: 883ms	remaining: 105ms
# 894:	learn: 0.0006956	total: 884ms	remaining: 104ms
# 895:	learn: 0.0006947	total: 885ms	remaining: 103ms
# 896:	learn: 0.0006940	total: 886ms	remaining: 102ms
# 897:	learn: 0.0006932	total: 887ms	remaining: 101ms
# 898:	learn: 0.0006922	total: 889ms	remaining: 99.8ms
# 899:	learn: 0.0006915	total: 890ms	remaining: 98.8ms
# 900:	learn: 0.0006905	total: 891ms	remaining: 97.9ms
# 901:	learn: 0.0006897	total: 892ms	remaining: 96.9ms
# 902:	learn: 0.0006888	total: 893ms	remaining: 95.9ms
# 903:	learn: 0.0006878	total: 894ms	remaining: 94.9ms
# 904:	learn: 0.0006869	total: 895ms	remaining: 93.9ms
# 905:	learn: 0.0006861	total: 895ms	remaining: 92.9ms
# 906:	learn: 0.0006854	total: 896ms	remaining: 91.9ms
# 907:	learn: 0.0006844	total: 897ms	remaining: 90.9ms
# 908:	learn: 0.0006837	total: 898ms	remaining: 89.9ms
# 909:	learn: 0.0006828	total: 898ms	remaining: 88.9ms
# 910:	learn: 0.0006819	total: 899ms	remaining: 87.8ms
# 911:	learn: 0.0006810	total: 900ms	remaining: 86.9ms
# 912:	learn: 0.0006802	total: 901ms	remaining: 85.9ms
# 913:	learn: 0.0006793	total: 902ms	remaining: 84.9ms
# 914:	learn: 0.0006785	total: 903ms	remaining: 83.9ms
# 915:	learn: 0.0006775	total: 905ms	remaining: 83ms
# 916:	learn: 0.0006769	total: 906ms	remaining: 82ms
# 917:	learn: 0.0006760	total: 907ms	remaining: 81ms
# 918:	learn: 0.0006752	total: 908ms	remaining: 80ms
# 919:	learn: 0.0006745	total: 909ms	remaining: 79.1ms
# 920:	learn: 0.0006737	total: 911ms	remaining: 78.1ms
# 921:	learn: 0.0006731	total: 912ms	remaining: 77.1ms
# 922:	learn: 0.0006723	total: 914ms	remaining: 76.3ms
# 923:	learn: 0.0006715	total: 916ms	remaining: 75.3ms
# 924:	learn: 0.0006707	total: 917ms	remaining: 74.4ms
# 925:	learn: 0.0006698	total: 918ms	remaining: 73.4ms
# 926:	learn: 0.0006690	total: 919ms	remaining: 72.4ms
# 927:	learn: 0.0006681	total: 920ms	remaining: 71.4ms
# 928:	learn: 0.0006673	total: 921ms	remaining: 70.4ms
# 929:	learn: 0.0006665	total: 922ms	remaining: 69.4ms
# 930:	learn: 0.0006657	total: 923ms	remaining: 68.4ms
# 931:	learn: 0.0006648	total: 924ms	remaining: 67.4ms
# 932:	learn: 0.0006641	total: 924ms	remaining: 66.4ms
# 933:	learn: 0.0006633	total: 925ms	remaining: 65.4ms
# 934:	learn: 0.0006623	total: 926ms	remaining: 64.4ms
# 935:	learn: 0.0006614	total: 927ms	remaining: 63.4ms
# 936:	learn: 0.0006607	total: 928ms	remaining: 62.4ms
# 937:	learn: 0.0006598	total: 929ms	remaining: 61.4ms
# 938:	learn: 0.0006591	total: 930ms	remaining: 60.4ms
# 939:	learn: 0.0006584	total: 931ms	remaining: 59.4ms
# 940:	learn: 0.0006576	total: 932ms	remaining: 58.4ms
# 941:	learn: 0.0006568	total: 933ms	remaining: 57.4ms
# 942:	learn: 0.0006562	total: 934ms	remaining: 56.5ms
# 943:	learn: 0.0006556	total: 935ms	remaining: 55.5ms
# 944:	learn: 0.0006547	total: 936ms	remaining: 54.5ms
# 945:	learn: 0.0006539	total: 937ms	remaining: 53.5ms
# 946:	learn: 0.0006531	total: 938ms	remaining: 52.5ms
# 947:	learn: 0.0006524	total: 939ms	remaining: 51.5ms
# 948:	learn: 0.0006516	total: 940ms	remaining: 50.5ms
# 949:	learn: 0.0006507	total: 941ms	remaining: 49.5ms
# 950:	learn: 0.0006500	total: 941ms	remaining: 48.5ms
# 951:	learn: 0.0006489	total: 943ms	remaining: 47.5ms
# 952:	learn: 0.0006483	total: 944ms	remaining: 46.5ms
# 953:	learn: 0.0006476	total: 945ms	remaining: 45.5ms
# 954:	learn: 0.0006468	total: 945ms	remaining: 44.5ms
# 955:	learn: 0.0006462	total: 947ms	remaining: 43.6ms
# 956:	learn: 0.0006454	total: 949ms	remaining: 42.6ms
# 957:	learn: 0.0006447	total: 950ms	remaining: 41.6ms
# 958:	learn: 0.0006440	total: 952ms	remaining: 40.7ms
# 959:	learn: 0.0006433	total: 954ms	remaining: 39.8ms
# 960:	learn: 0.0006426	total: 955ms	remaining: 38.8ms
# 961:	learn: 0.0006419	total: 958ms	remaining: 37.8ms
# 962:	learn: 0.0006411	total: 966ms	remaining: 37.1ms
# 963:	learn: 0.0006404	total: 969ms	remaining: 36.2ms
# 964:	learn: 0.0006397	total: 971ms	remaining: 35.2ms
# 965:	learn: 0.0006389	total: 972ms	remaining: 34.2ms
# 966:	learn: 0.0006381	total: 973ms	remaining: 33.2ms
# 967:	learn: 0.0006375	total: 974ms	remaining: 32.2ms
# 968:	learn: 0.0006368	total: 975ms	remaining: 31.2ms
# 969:	learn: 0.0006361	total: 976ms	remaining: 30.2ms
# 970:	learn: 0.0006354	total: 977ms	remaining: 29.2ms
# 971:	learn: 0.0006347	total: 977ms	remaining: 28.2ms
# 972:	learn: 0.0006341	total: 978ms	remaining: 27.1ms
# 973:	learn: 0.0006334	total: 980ms	remaining: 26.2ms
# 974:	learn: 0.0006327	total: 981ms	remaining: 25.2ms
# 975:	learn: 0.0006320	total: 982ms	remaining: 24.2ms
# 976:	learn: 0.0006314	total: 983ms	remaining: 23.1ms
# 977:	learn: 0.0006308	total: 984ms	remaining: 22.1ms
# 978:	learn: 0.0006300	total: 985ms	remaining: 21.1ms
# 979:	learn: 0.0006293	total: 986ms	remaining: 20.1ms
# 980:	learn: 0.0006287	total: 988ms	remaining: 19.1ms
# 981:	learn: 0.0006281	total: 989ms	remaining: 18.1ms
# 982:	learn: 0.0006274	total: 990ms	remaining: 17.1ms
# 983:	learn: 0.0006266	total: 991ms	remaining: 16.1ms
# 984:	learn: 0.0006261	total: 992ms	remaining: 15.1ms
# 985:	learn: 0.0006254	total: 994ms	remaining: 14.1ms
# 986:	learn: 0.0006245	total: 995ms	remaining: 13.1ms
# 987:	learn: 0.0006239	total: 996ms	remaining: 12.1ms
# 988:	learn: 0.0006233	total: 997ms	remaining: 11.1ms
# 989:	learn: 0.0006226	total: 998ms	remaining: 10.1ms
# 990:	learn: 0.0006219	total: 999ms	remaining: 9.07ms
# 991:	learn: 0.0006212	total: 999ms	remaining: 8.06ms
# 992:	learn: 0.0006204	total: 1s	remaining: 7.05ms
# 993:	learn: 0.0006198	total: 1s	remaining: 6.04ms
# 994:	learn: 0.0006190	total: 1s	remaining: 5.04ms
# 995:	learn: 0.0006185	total: 1s	remaining: 4.03ms
# 996:	learn: 0.0006178	total: 1s	remaining: 3.02ms
# 997:	learn: 0.0006171	total: 1s	remaining: 2.02ms
# 998:	learn: 0.0006164	total: 1.01s	remaining: 1.01ms
# 999:	learn: 0.0006158	total: 1.01s	remaining: 0us
# {'features_list': 'Seleccion voting', 'model': 'Catboost', 'avg. recall': np.float64(1.0)}
#                    features_list            model  avg. recall
# 0          Seleccion estadistico    Random Forest     1.000000
# 2          Seleccion estadistico   Decission Tree     1.000000
# 8   Seleccion mutual information   Decission Tree     1.000000
# 4          Seleccion estadistico         LightGBM     1.000000
# 5          Seleccion estadistico         Catboost     1.000000
# 6   Seleccion mutual information    Random Forest     1.000000
# 13              Seleccion manual              KNN     1.000000
# 12              Seleccion manual    Random Forest     1.000000
# 11  Seleccion mutual information         Catboost     1.000000
# 10  Seleccion mutual information         LightGBM     1.000000
# 41              Seleccion voting         Catboost     1.000000
# 40              Seleccion voting         LightGBM     1.000000
# 29                 Seleccion rfe         Catboost     1.000000
# 30                 Seleccion sfs    Random Forest     1.000000
# 14              Seleccion manual   Decission Tree     1.000000
# 16              Seleccion manual         LightGBM     1.000000
# 17              Seleccion manual         Catboost     1.000000
# 18              Seleccion modelo    Random Forest     1.000000
# 24                 Seleccion rfe    Random Forest     1.000000
# 19              Seleccion modelo              KNN     1.000000
# 20              Seleccion modelo   Decission Tree     1.000000
# 22              Seleccion modelo         LightGBM     1.000000
# 25                 Seleccion rfe              KNN     1.000000
# 23              Seleccion modelo         Catboost     1.000000
# 28                 Seleccion rfe         LightGBM     1.000000
# 26                 Seleccion rfe   Decission Tree     1.000000
# 38              Seleccion voting   Decission Tree     1.000000
# 37              Seleccion voting              KNN     1.000000
# 36              Seleccion voting    Random Forest     1.000000
# 35                 Seleccion sfs         Catboost     1.000000
# 32                 Seleccion sfs   Decission Tree     1.000000
# 34                 Seleccion sfs         LightGBM     0.998974
# 7   Seleccion mutual information              KNN     0.997740
# 1          Seleccion estadistico              KNN     0.997740
# 31                 Seleccion sfs              KNN     0.992509
# 15              Seleccion manual         AdaBoost     0.971352
# 21              Seleccion modelo         AdaBoost     0.971352
# 27                 Seleccion rfe         AdaBoost     0.970326
# 39              Seleccion voting         AdaBoost     0.970326
# 3          Seleccion estadistico         AdaBoost     0.961181
# 9   Seleccion mutual information         AdaBoost     0.961181
# 33                 Seleccion sfs         AdaBoost     0.951992

# %%
# Hay muchos que me dan 1, lo que me lleva a pensar que están sobreajustados, asi que voy a quedarme por ahora con lgbm y la seleccion de SFS, y también con KNN seleccion stadistica

# %%
# Voy a hacer el crossvalidation con la regresion lineal y el SVC

nombres = [f"Seleccion {nombre}" for nombre in ["estadistico", "mutual information", "manual", "modelo", "rfe", "sfs", "voting"]]
model_names_scaled = ["Logistic Regressor", "SVC"]

lr_clf = LogisticRegression(class_weight= "balanced", random_state= 42)
SVC_clf = SVC (class_weight = "balanced", random_state = 42)

models_scaled = [lr_clf, SVC_clf]
resultados_scaled = []

for indice, lista in enumerate([features_stad, features_mi, features_manual, features_modelo, features_RFE, features_SFS, features_hard_voting]):
    X_train = train_set[lista]
    y_train = train_set[target]
    
    for model_name_scaled, modelo in zip(model_names_scaled, models_scaled):
        metrica = np.mean(cross_val_score(modelo, X_train_scalado, y_train, cv = 5, scoring = "balanced_accuracy"))
        data = {
            "features_list": nombres[indice],
            "model": model_name_scaled,
            "avg. recall": metrica
        }
        print(data)
        resultados_scaled.append(data.copy())
df_resultados_scaled = pd.DataFrame(resultados_scaled)
df_resultados_scaled.sort_values("avg. recall", ascending = False)
# Out:
# {'features_list': 'Seleccion estadistico', 'model': 'Logistic Regressor', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion estadistico', 'model': 'SVC', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion mutual information', 'model': 'Logistic Regressor', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion mutual information', 'model': 'SVC', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion manual', 'model': 'Logistic Regressor', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion manual', 'model': 'SVC', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion modelo', 'model': 'Logistic Regressor', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion modelo', 'model': 'SVC', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion rfe', 'model': 'Logistic Regressor', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion rfe', 'model': 'SVC', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion sfs', 'model': 'Logistic Regressor', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion sfs', 'model': 'SVC', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion voting', 'model': 'Logistic Regressor', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion voting', 'model': 'SVC', 'avg. recall': np.float64(1.0)}
#                    features_list               model  avg. recall
# 0          Seleccion estadistico  Logistic Regressor          1.0
# 1          Seleccion estadistico                 SVC          1.0
# 2   Seleccion mutual information  Logistic Regressor          1.0
# 3   Seleccion mutual information                 SVC          1.0
# 4               Seleccion manual  Logistic Regressor          1.0
# 5               Seleccion manual                 SVC          1.0
# 6               Seleccion modelo  Logistic Regressor          1.0
# 7               Seleccion modelo                 SVC          1.0
# 8                  Seleccion rfe  Logistic Regressor          1.0
# 9                  Seleccion rfe                 SVC          1.0
# 10                 Seleccion sfs  Logistic Regressor          1.0
# 11                 Seleccion sfs                 SVC          1.0
# 12              Seleccion voting  Logistic Regressor          1.0
# 13              Seleccion voting                 SVC          1.0

# %%
# Con los escalados también me dan muy buenas métricas, estará sobre ajustado????

# %%
# Con cual quedarme?? Pues por simplicidad me deberia quedar con El randomm forest (selección estadictica), el regresor logístico (selección estadistica) y el deccison tree (selección estadistica)

# %%
# Ajustando los hiperparámetros
# Random forest

params={'criterion':['gini','entropy'],'min_samples_split':list(np.arange(2,41)),'min_samples_leaf':list(np.arange(2,41)),
        'max_features':['sqrt','log2',None],'n_estimators':[1000]}
rf_optimizado=RandomizedSearchCV(rf_clf, param_distributions = params,scoring = 'accuracy', random_state = 42, n_jobs = -1, cv = 10)
rf_optimizado.fit(train_set[features_stad],train_set[target])
print(rf_optimizado.best_params_)
print(rf_optimizado.best_score_)
nrf = rf_optimizado.best_estimator_
# Out:
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# {'n_estimators': 1000, 'min_samples_split': np.int64(6), 'min_samples_leaf': np.int64(18), 'max_features': 'sqrt', 'criterion': 'entropy'}
# 1.0

# %%
# Voy a optimizar el regresor lineal manualmente
dual=[True,False]
max_iter=[100,110,120,130,140]
param_grid = dict(dual=dual,max_iter=max_iter)

lr_clf_optimizado = GridSearchCV(estimator=lr_clf, param_grid=param_grid, cv = 10, n_jobs=-1)
grid_result = lr_clf_optimizado.fit(X_train_scalado[features_stad], train_set[target])

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 1.000000 using {'dual': False, 'max_iter': 100}
# /Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 50 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py", line 68, in _check_solver
#     raise ValueError(f"Solver {solver} supports only dual=False, got dual={dual}")
# ValueError: Solver lbfgs supports only dual=False, got dual=True
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan  1.  1.  1.  1.  1.]
#   warnings.warn(

# %%
# Voy a aoptimizrla de manera aleatoria
random = RandomizedSearchCV(estimator=lr_clf, param_distributions=param_grid, cv = 10, n_jobs=-1)

random_result = random.fit(X_train_scalado[features_stad], train_set[target])
print("Best: %f using %s" % (random_result.best_score_, random_result.best_params_))
# Out:
# Best: 1.000000 using {'max_iter': 100, 'dual': False}
# /Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 50 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py", line 68, in _check_solver
#     raise ValueError(f"Solver {solver} supports only dual=False, got dual={dual}")
# ValueError: Solver lbfgs supports only dual=False, got dual=True
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan  1.  1.  1.  1.  1.]
#   warnings.warn(

# %%
# Por últimoo voy a optimizar el Decission Tree
params={'criterion':['gini','entropy'],'min_samples_split':list(np.arange(2,51)),'min_samples_leaf':list(np.arange(2,51)),
        'max_features':['sqrt','log2',None]}
dt_optimizado = RandomizedSearchCV(dt_clf,param_distributions=params,scoring='accuracy',random_state=42,n_jobs=-1,cv=10)
dt_optimizado.fit(train_set[features_stad],train_set[target])
print(dt_optimizado.best_params_)
print(dt_optimizado.best_score_)
ndt=dt_optimizado.best_estimator_
# Out:
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# {'min_samples_split': np.int64(20), 'min_samples_leaf': np.int64(3), 'max_features': 'sqrt', 'criterion': 'entropy'}
# 1.0

# %%
# Voy a evaluar contra test
# Primero el Ramdom Forest
X_train = train_set[features_stad]
y_train = train_set[target]

X_test = test_set[features_stad]
y_test = test_set[target]

# %%
# Voy a guardar valores para luego hacer matrices de confusion
cm_t=[] # almacen para matriiz de confusion para training set
cm=[] # almacén para matriz de confusión para test set

# %%
pred_train = nrf.predict(X_train)
y_pred = nrf.predict(X_test)
print(classification_report(y_test, y_pred))

cmrf_t=confusion_matrix(y_train, pred_train)
cm_t.append(cmrf_t)
cmrf=confusion_matrix(y_test, y_pred)
cm.append(cmrf)
# Out:
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00         7
#          Low       1.00      1.00      1.00         6
#       Medium       1.00      1.00      1.00         7
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %%
# Sobre el regresor lineal 
pred_train_2 = grid_result.predict(X_train_scalado[features_stad])
y_pred_2 = grid_result.predict(X_test_scalado[features_stad])
print(classification_report(y_test, y_pred_2))

cmrf_t_2 = confusion_matrix(y_train, pred_train_2)
cm_t.append(cmrf_t_2)
cmrf_2=confusion_matrix(y_test, y_pred_2)
cm.append(cmrf_2)
# Out:
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00         7
#          Low       1.00      1.00      1.00         6
#       Medium       1.00      1.00      1.00         7
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %%
# Sobre regresor lineal aleatorio
pred_train_3 = random_result.predict(X_train_scalado[features_stad])
y_pred_3 = random_result.predict(X_test_scalado[features_stad])
print(classification_report(y_test, y_pred_3))

cmrf_t_3 = confusion_matrix(y_train, pred_train_3)
cm_t.append(cmrf_t_3)
cmrf_3=confusion_matrix(y_test, y_pred_3)
cm.append(cmrf_3)
# Out:
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00         7
#          Low       1.00      1.00      1.00         6
#       Medium       1.00      1.00      1.00         7
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %%
# Sobre Deccision Tree
pred_train_4 = ndt.predict(X_train)
y_pred_4 = ndt.predict(X_test)
print(classification_report(y_test, y_pred_4))

cmrf_t_4 = confusion_matrix(y_train, pred_train_4)
cm_t.append(cmrf_t_4)
cmrf_4 = confusion_matrix(y_test, y_pred_4)
cm.append(cmrf_4)
# Out:
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00         7
#          Low       1.00      1.00      1.00         6
#       Medium       1.00      1.00      1.00         7
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %%
# matrices de confusion para ls modelos de entrenamiento
modelos =['Random Forest Classifier', 'Logistic Regressor manual', 'Logistic Regressor random', 'Decision Tree Classifier']
labels=['Low','Medium','High']
fig,ax=plt.subplots(2,2,figsize=(15,5))
r=0
c=0
for i, model in enumerate(modelos):
    sns.heatmap(cm_t[i],annot=True,fmt='d',ax=ax[r][c],xticklabels=labels,yticklabels=labels)
    ax[r][c].set_title(model)
    c+=1
    if(c==2):
        r+=1
        c=0
plt.suptitle('Confusion Matrices for Models on Training Set')
plt.tight_layout()
plt.show()

# %%
# matrices de confusion para ls modelos de test
modelos =['Random Forest Classifier', 'Logistic Regressor manual', 'Logistic Regressor random', 'Decision Tree Classifier']
labels=['Low','Medium','High']
fig,ax=plt.subplots(2,2,figsize=(15,5))
r=0
c=0
for i, model in enumerate(modelos):
    sns.heatmap(cm[i],annot=True,fmt='d',ax=ax[r][c],xticklabels=labels,yticklabels=labels)
    ax[r][c].set_title(model)
    c+=1
    if(c==2):
        r+=1
        c=0
plt.suptitle('Confusion Matrices for Models on Test Set')
plt.tight_layout()
plt.show()

# %%
# Conclusiones: cualquiera de los tres modelos con sus hiperparámetros optimizados o incluso sin optimizar dar muy buenos resultados
