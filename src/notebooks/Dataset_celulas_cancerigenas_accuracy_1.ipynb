# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/lauragarcia/Projects/ML_Lung_Cancer_Prediction/src/data_sample/cancer patient data sets.csv')
df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                       4             3                     2  ...        3
# 1                       3             4                     2  ...        1
# 2                       5             5                     4  ...        8
# 3                       7             6                     7  ...        4
# 4                       7             7                     6  ...        3
# ..                    ...           ...                   ...  ...      ...
# 995                     7             7                     6  ...        5
# 996                     7             7                     6  ...        9
# 997                     5             5                     4  ...        8
# 998                     7             7                     6  ...        3
# 999                     5             5                     4  ...        8
#
#      Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0              4                    2         2                      3
# 1              3                    7         8                      6
# 2              7                    9         2                      1
# 3              2                    3         1                      4
# 4              2                    4         1                      4
# ..           ...                  ...       ...                    ...
# 995            3                    2         7                      8
# 996            6                    5         7                      2
# 997            7                    9         2                      1
# 998            2                    4         1                      4
# 999            7                    9         2                      1
#
#      Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                           1              2          3        4     Low
# 1                           2              1          7        2  Medium
# 2                           4              6          7        2    High
# 3                           5              6          7        5    High
# 4                           2              4          2        3    High
# ..                        ...            ...        ...      ...     ...
# 995                         2              4          5        3    High
# 996                         4              3          1        4    High
# 997                         4              6          7        2    High
# 998                         2              4          2        3    High
# 999                         4              6          7        2    High
#
# [1000 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1000 non-null   int64
#  1   Patient Id                1000 non-null   object
#  2   Age                       1000 non-null   int64
#  3   Gender                    1000 non-null   int64
#  4   Air Pollution             1000 non-null   int64
#  5   Alcohol use               1000 non-null   int64
#  6   Dust Allergy              1000 non-null   int64
#  7   OccuPational Hazards      1000 non-null   int64
#  8   Genetic Risk              1000 non-null   int64
#  9   chronic Lung Disease      1000 non-null   int64
#  10  Balanced Diet             1000 non-null   int64
#  11  Obesity                   1000 non-null   int64
#  12  Smoking                   1000 non-null   int64
#  13  Passive Smoker            1000 non-null   int64
#  14  Chest Pain                1000 non-null   int64
#  15  Coughing of Blood         1000 non-null   int64
#  16  Fatigue                   1000 non-null   int64
#  17  Weight Loss               1000 non-null   int64
#  18  Shortness of Breath       1000 non-null   int64
#  19  Wheezing                  1000 non-null   int64
#  20  Swallowing Difficulty     1000 non-null   int64
#  21  Clubbing of Finger Nails  1000 non-null   int64
#  22  Frequent Cold             1000 non-null   int64
#  23  Dry Cough                 1000 non-null   int64
#  24  Snoring                   1000 non-null   int64
#  25  Level                     1000 non-null   object
# dtypes: int64(24), object(2)
# memory usage: 203.3+ KB

# %%
df.describe().T
# Out:
#                            count     mean         std   min     25%    50%  \
# index                     1000.0  499.500  288.819436   0.0  249.75  499.5
# Age                       1000.0   37.174   12.005493  14.0   27.75   36.0
# Gender                    1000.0    1.402    0.490547   1.0    1.00    1.0
# Air Pollution             1000.0    3.840    2.030400   1.0    2.00    3.0
# Alcohol use               1000.0    4.563    2.620477   1.0    2.00    5.0
# Dust Allergy              1000.0    5.165    1.980833   1.0    4.00    6.0
# OccuPational Hazards      1000.0    4.840    2.107805   1.0    3.00    5.0
# Genetic Risk              1000.0    4.580    2.126999   1.0    2.00    5.0
# chronic Lung Disease      1000.0    4.380    1.848518   1.0    3.00    4.0
# Balanced Diet             1000.0    4.491    2.135528   1.0    2.00    4.0
# Obesity                   1000.0    4.465    2.124921   1.0    3.00    4.0
# Smoking                   1000.0    3.948    2.495902   1.0    2.00    3.0
# Passive Smoker            1000.0    4.195    2.311778   1.0    2.00    4.0
# Chest Pain                1000.0    4.438    2.280209   1.0    2.00    4.0
# Coughing of Blood         1000.0    4.859    2.427965   1.0    3.00    4.0
# Fatigue                   1000.0    3.856    2.244616   1.0    2.00    3.0
# Weight Loss               1000.0    3.855    2.206546   1.0    2.00    3.0
# Shortness of Breath       1000.0    4.240    2.285087   1.0    2.00    4.0
# Wheezing                  1000.0    3.777    2.041921   1.0    2.00    4.0
# Swallowing Difficulty     1000.0    3.746    2.270383   1.0    2.00    4.0
# Clubbing of Finger Nails  1000.0    3.923    2.388048   1.0    2.00    4.0
# Frequent Cold             1000.0    3.536    1.832502   1.0    2.00    3.0
# Dry Cough                 1000.0    3.853    2.039007   1.0    2.00    4.0
# Snoring                   1000.0    2.926    1.474686   1.0    2.00    3.0
#
#                              75%    max
# index                     749.25  999.0
# Age                        45.00   73.0
# Gender                      2.00    2.0
# Air Pollution               6.00    8.0
# Alcohol use                 7.00    8.0
# Dust Allergy                7.00    8.0
# OccuPational Hazards        7.00    8.0
# Genetic Risk                7.00    7.0
# chronic Lung Disease        6.00    7.0
# Balanced Diet               7.00    7.0
# Obesity                     7.00    7.0
# Smoking                     7.00    8.0
# Passive Smoker              7.00    8.0
# Chest Pain                  7.00    9.0
# Coughing of Blood           7.00    9.0
# Fatigue                     5.00    9.0
# Weight Loss                 6.00    8.0
# Shortness of Breath         6.00    9.0
# Wheezing                    5.00    8.0
# Swallowing Difficulty       5.00    8.0
# Clubbing of Finger Nails    5.00    9.0
# Frequent Cold               5.00    7.0
# Dry Cough                   6.00    7.0
# Snoring                     4.00    7.0

# %%
# Buscando valores nulos
df.isnull().sum()
# Out:
# index                       0
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
# Aparentemente no hay nulos y los datos están ya estandarizados, salvo la edad
# Voy a buscar información por si hubiera escalas a las que hace referencia esta standarización.
# Tras buscar datos de todas las varibles, no existe una ctegorización como tal de las mismas. De hecho la mayoría se categorizan como leve, moderada severa.
# Sólamente en riesgos laborales he encontrado una categorización en 7 riesgos, pero no creo que tenga mucho sentido, ya que son el tipo de riesgo y no una calificación de poco a mucho rriesgo que parece que es la tendecncia del resto de variables.
# En cuanto a la obesidad. Existen 4 grados junto al sobrepeso, si le añadimos las otras dos categorizaciones que hace la OMS, que son normopeso y bajo peso, tendríamos las 7. En este caso el 1 seria bajo peso y el 7 obesidad extrema.
# en cuanto al género, no he encontrado ninguna información, pero por otros datasets e informaciones leidas parece que 1 es mujer y 2 es hombre.

# %%
# Antes de nada voy a eiminar las columnas que no me sirven para nada como el index o el pacient Id
df.drop('index', axis= 1, inplace= True)
df.drop('Patient Id', axis= 1, inplace= True )
df
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# 2                       5             5                     4              6
# 3                       7             6                     7              7
# 4                       7             7                     6              7
# ..                    ...           ...                   ...            ...
# 995                     7             7                     6              7
# 996                     7             7                     6              7
# 997                     5             5                     4              6
# 998                     7             7                     6              7
# 999                     5             5                     4              6
#
#      Obesity  ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# 0          4  ...        3            4                    2         2
# 1          2  ...        1            3                    7         8
# 2          7  ...        8            7                    9         2
# 3          7  ...        4            2                    3         1
# 4          7  ...        3            2                    4         1
# ..       ...  ...      ...          ...                  ...       ...
# 995        7  ...        5            3                    2         7
# 996        7  ...        9            6                    5         7
# 997        7  ...        8            7                    9         2
# 998        7  ...        3            2                    4         1
# 999        7  ...        8            7                    9         2
#
#      Swallowing Difficulty  Clubbing of Finger Nails  Frequent Cold  \
# 0                        3                         1              2
# 1                        6                         2              1
# 2                        1                         4              6
# 3                        4                         5              6
# 4                        4                         2              4
# ..                     ...                       ...            ...
# 995                      8                         2              4
# 996                      2                         4              3
# 997                      1                         4              6
# 998                      4                         2              4
# 999                      1                         4              6
#
#      Dry Cough  Snoring   Level
# 0            3        4     Low
# 1            7        2  Medium
# 2            7        2    High
# 3            7        5    High
# 4            2        3    High
# ..         ...      ...     ...
# 995          5        3    High
# 996          1        4    High
# 997          7        2    High
# 998          2        3    High
# 999          7        2    High
#
# [1000 rows x 24 columns]

# %%
# Con la información preliminar que tenemos todas las variables son de tipo int, salvo Level que es de tipo object.

# %%
# El problema de negocio es intentar predecir a qué nivel o estadio de cáncer pertenece cada paciente con sus carácterísticas o síntomas clínicos.
# Es por tanto un problema de clasifficación. En este caso sería multiclase, ya que nuestra target seria Level y tiene tres valores : Low, Medium y High.
target = 'Level'

# %%
df[target].value_counts()
# Out:
# Level
# High      365
# Medium    332
# Low       303
# Name: count, dtype: int64

# %%
# Voy a ver cómo está distribuida la variable target
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,5))
sizes = df[target].value_counts()
labels = sizes.index
plt.pie(sizes.values,labels=labels,autopct='%.2f%%')
plt.legend(target)
plt.show()

# %%
# Parece que nuestra target está bastante balanceada, aspecto que es bastante bueno.
# Una vez visto esto, voy a hacer el train/test split estratificaré con la target para que estén distribuidas homogéneamente las 3 categorias

from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split( df, test_size = 20, stratify = df[target], random_state = 42)

# %%
# Valorar la opcion de hacer otra partición para tener validation

# %%
# Voy a comprobar si han quedado estratificadas similarmente
train_set[target].value_counts()/len(train_set) *100
# Out:
# Level
# High      36.530612
# Medium    33.163265
# Low       30.306122
# Name: count, dtype: float64

# %%
test_set[target].value_counts()/len(test_set) *100
# Out:
# Level
# Medium    35.0
# High      35.0
# Low       30.0
# Name: count, dtype: float64

# %%
# Están similares los balanceos

# %%
# Pasamos al mini EDA
# Voy a realizar un análisis visual de las posibles features frente a la target para determinar si existe relación con ella, o no. No voy a usar un pairplot porque son muchísimas variables. Asi que haré de manera individual (variable por variable contra target)
# Target vs genero
sns.catplot( x= "Level", 
            hue = "Gender",
            kind= "count", 
            edgecolor = ".6",
            orient = "v",
            data = train_set.sort_values("Level"));

# %%
# Salvo en los niveles altos, parece que el género no es un determinante

# %%
# Target vs age
sns.boxplot(x = "Level",
            y = "Age",
            hue = "Level",
            data = train_set);

# %%
# En cuanto a a la edad, las tres gráficas son similares, sí que se ve un outlier en el caso medio, habría que revisar si el dato está bien. Revisando las estadisticas la edad máxima del estudio son 73 años que se corresponde con este outlier

# %%
# Target vs Air Pollution
sns.boxplot(x = "Level",
            y = "Air Pollution",
            hue = "Level",
            data = train_set);

# %%
# En este caso ya observamos diferencias en relación a los tres niveles

# %%
# Target vs Alcohol use
sns.boxplot(x = "Level",
            y = "Alcohol use",
            hue = "Level",
            data = train_set);

# %%
# En esta vaiable podemmos observar que parece que salvo algunos outliers que hay porr ahí a mayor consumo de alcohol, mayor nivel de "daño"

# %%
#Target vs Dust Allergy
sns.boxplot(x = "Level",
            y = "Dust Allergy",
            hue = "Level",
            data = train_set);

# %%
# Aparentemente también existe una relación, a mayor nivel de alergía al polvo, más "daño"

# %%
# Target vs Occupational Hazzards
sns.boxplot(x = "Level",
            y = "OccuPational Hazards",
            hue = "Level",
            data = train_set);

# %%
# Distribución similar a la anterior

# %%
# Target vs Genetic risk
sns.boxplot(x = "Level",
            y = "Genetic Risk",
            hue = "Level",
            data = train_set);

# %%
# Parece que si hay relación, aunque el "daño meddio" afecta tanto a personas con bajo riesgo como de alto riesgo genético

# %%
# Target vs Chronic Lung Disease
sns.boxplot(x = "Level",
            y = "chronic Lung Disease",
            hue = "Level",
            data = train_set);

# %%
# Aparentemente pueden estar relacionadas

# %%
# Target vs Balanced Diet
sns.boxplot(x = "Level",
            y = "Balanced Diet",
            hue = "Level",
            data = train_set);

# %%
# De primeras parece que la dieta también influye en un mayor o menor grado de "daño", aunque hay de todo

# %%
# Target vs Obesity 
sns.boxplot(x = "Level",
            y = "Obesity",
            hue = "Level",
            data = train_set);

# %%
# Parece que tiene cierta relación

# %%
# Target vs Smoking
sns.boxplot(x = "Level",
            y = "Smoking",
            hue = "Level",
            data = train_set);

# %%
# Esta gráfica es más dispar. Parece que cuando el daño el elevado si que hay relación con el grado de tabaquismo, pero en el medio y bajo no afecta tanto (es interesante)

# %%
# Target vs Passive Smoker
sns.boxplot(x = "Level",
            y = "Passive Smoker",
            hue = "Level",
            data = train_set);

# %%
# Aquí la distribución también es curiosa, para fumadores pasivos muy expuestos, parece que su daño es más alto. En el caso de fumadores pasivos leves o medios, el daño es similar para medio y bajo

# %%
# Target vs Chest Pain
sns.boxplot(x = "Level",
            y = "Chest Pain",
            hue = "Level",
            data = train_set);

# %%
# Similar a la anterior

# %%
# Target vs Coughing of Blood
sns.boxplot(x = "Level",
            y = "Coughing of Blood",
            hue = "Level",
            data = train_set);

# %%
# En esta variable si que parece tener algo más de relación con el target

# %%
# Target vs Fatigue
sns.boxplot(x = "Level",
            y = "Fatigue",
            hue = "Level",
            data = train_set);

# %%
# La fatiga si que parece tener una relación directa con la gravedad del daño. A mayor daño, mayor fatiga.

# %%
# Target vs Weight Loos
sns.boxplot(x = "Level",
            y = "Weight Loss",
            hue = "Level",
            data = train_set);

# %%
# No parecen tener mucha relación, al menos directa

# %%
# Target vs Shortness of Breathe
sns.boxplot(x = "Level",
            y = "Shortness of Breath",
            hue = "Level",
            data = train_set);

# %%
# La disnea o dificultad respiratoria si que tiene relación directa con el grado de daño

# %%
# Target vs Wheezing
sns.boxplot(x = "Level",
            y = "Wheezing",
            hue = "Level",
            data = train_set);

# %%
# La sibilación ( que suele estar relacionada con el asma), no parece tener tanta relación con el grado de daño en este cáncer

# %%
# Target vs Swallowing Difficulty
sns.boxplot(x = "Level",
            y = "Swallowing Difficulty",
            hue = "Level",
            data = train_set);

# %%
# Aquí tampoco veo una relación como tal. Todos los grados de daño se ven afectados de manera similar por la disfagia.

# %%
# Target vs Clubbing of Finger Nails
sns.boxplot(x = "Level",
            y = "Clubbing of Finger Nails",
            hue = "Level",
            data = train_set);

# %%
# Los dedos en palillo de tambor (que al parecer puede ser un signo de diagnóstico en emfermedades pulmonares o cardiacas entre otros), en este caso no parece tener una relación directa. Parece que afecta algo más a los casos de daño medio, pero los de bajo daño y alto daño también lo tienen.

# %%
# Target vs Frequent Cold
sns.boxplot(x = "Level",
            y = "Frequent Cold",
            hue = "Level",
            data = train_set);

# %%
# En esta variable, la frecuencia de padecer catarros aparentemente no tiene una relación muy directa con los grados de daño del cáncer.

# %%
# Target vs Dry Cough
sns.boxplot(x = "Level",
            y = "Dry Cough",
            hue = "Level",
            data = train_set);

# %%
# En cuanto a la tos seca, parece que si hay una relación con la gravedad del daño, aunque puede ser discreta.

# %%
# Target vs Snoring
sns.boxplot(x = "Level",
            y = "Snoring",
            hue = "Level",
            data = train_set);

# %%
# En relación a los ronquidos, podría intuirse una ligera relación, pero no me queda del todo clara.

# %%
# Debido a que el análisis visual de todas las variables frente al target, en algunos casos no deja clara esa posible relación, voy a realizar análisis matemáticos para poder ver con datos numéricos esa posible relación.

# %%
# Nuestras variables son categóricas aunque su dtype sea int, se podrían tratar como variables numéricas, y por los datos que tenemos y la presentación de los mismos, podría inferir que son numéricas contínuas. 
# Sin embargo, voy a tratarlas como categóricas y realizar test Chi cuadrado con nuestra target para ver la posible relación entre variables y target.
# Primero creo una lista con las variables categoricas
features_cat = train_set.columns.to_list()
features_cat.remove(target) # quito la target
features_cat.remove('Age') # quito la única numérica que tenemos
features_cat
# Out:
# ['Gender',
#  'Air Pollution',
#  'Alcohol use',
#  'Dust Allergy',
#  'OccuPational Hazards',
#  'Genetic Risk',
#  'chronic Lung Disease',
#  'Balanced Diet',
#  'Obesity',
#  'Smoking',
#  'Passive Smoker',
#  'Chest Pain',
#  'Coughing of Blood',
#  'Fatigue',
#  'Weight Loss',
#  'Shortness of Breath',
#  'Wheezing',
#  'Swallowing Difficulty',
#  'Clubbing of Finger Nails',
#  'Frequent Cold',
#  'Dry Cough',
#  'Snoring']

# %%
# Nuestra una feature numérica es edad
feature_num = train_set['Age']

# %%
# Ahora hago la prueba de chi-cuadrado para las variables categóricas y ver qué correlación tienen
from scipy.stats import chi2_contingency

target_col = train_set[target] # asigno nuestra target
p_value = 0.05 # asigno el valor de p_value para aceptar o rechazar la hipótesis nula
listado_features = [] # lista vacío dónde iré añadiendo las features que tengan releción con mi target 
listado_p_value = []
for col in train_set[features_cat].columns:
            tabla = pd.crosstab (train_set[col], target_col) 
            resultado_test = chi2_contingency(tabla)
            if resultado_test[1] < p_value:
                listado_features.append(col)
                listado_p_value.append(resultado_test[1])

# %%
# Ya tengo guardadas las features relacionadas con la target y sus p_value (features categoricas)

# %%
# Hacemos un test ANOVA para la edad
from scipy import stats
#target_cat = 'Level'
level_cat = train_set[target].unique()  # Obtener los valores únicos de la columna categórica,
age_for_level = [train_set[train_set[target] == categoria]['Age'] for categoria in level_cat] # obtenemos la edad por cada nivel de daño y los incluimos en una lista

# %%
f_val, p_val = stats.f_oneway(*age_for_level) 
print("Valor F:", f_val)
print("Valor p:", p_val)
# Out:
# Valor F: 6.111818745192272
# Valor p: 0.0023021749243392767

# %%
# Añadimos la edad a nuestro listado, puesto que p_val es < que p_value y hacemos un dataframe
listado_features.append('Age')
listado_p_value.append(p_val)
stadistic_df = pd.DataFrame( {'Features': listado_features, 'p_value': listado_p_value})
stadistic_df = stadistic_df.sort_values(by='p_value').reset_index(drop=True) # ordeno de mayor a menor importancia las features
print(stadistic_df)
# Out:
#                     Features        p_value
# 0          Coughing of Blood  3.811491e-206
# 1                    Obesity  1.043678e-196
# 2             Passive Smoker  6.402755e-195
# 3                   Wheezing  2.551694e-176
# 4                 Chest Pain  3.808708e-173
# 5                Alcohol use  4.148720e-173
# 6        Shortness of Breath  4.408441e-163
# 7              Balanced Diet  4.102820e-156
# 8               Dust Allergy  1.436697e-143
# 9       OccuPational Hazards  6.009067e-137
# 10                   Smoking  1.458214e-134
# 11                   Fatigue  2.310933e-130
# 12             Air Pollution  3.487271e-129
# 13              Genetic Risk  1.958855e-124
# 14      chronic Lung Disease  3.991984e-114
# 15             Frequent Cold   3.397731e-91
# 16  Clubbing of Finger Nails   2.306454e-86
# 17                 Dry Cough   1.251395e-78
# 18               Weight Loss   1.191414e-67
# 19     Swallowing Difficulty   1.059162e-44
# 20                   Snoring   8.841331e-34
# 21                    Gender   1.728489e-06
# 22                       Age   2.302175e-03

# %%
# Según la prueba de chi-cuadrado y el ANOVA parece que todas las variables tienen algo de relación con el target
# Voy a sacar listado
features_stad = stadistic_df['Features'].to_list()
features_stad
# Out:
# ['Coughing of Blood',
#  'Obesity',
#  'Passive Smoker',
#  'Wheezing',
#  'Chest Pain',
#  'Alcohol use',
#  'Shortness of Breath',
#  'Balanced Diet',
#  'Dust Allergy',
#  'OccuPational Hazards',
#  'Smoking',
#  'Fatigue',
#  'Air Pollution',
#  'Genetic Risk',
#  'chronic Lung Disease',
#  'Frequent Cold',
#  'Clubbing of Finger Nails',
#  'Dry Cough',
#  'Weight Loss',
#  'Swallowing Difficulty',
#  'Snoring',
#  'Gender',
#  'Age']

# %%
# Por lo tanto iré con todas las features de primeras y luego veré si puedo hacer una selección más pequeña

# %%
# No obstante voy a dejar hecho el mutual information clasificación para ver todas las relaciones

from sklearn.feature_selection import mutual_info_classif

listado_features = train_set.columns.to_list()
listado_features.remove(target) # quitamos el target de la lista de features

mi = mutual_info_classif(train_set[listado_features], train_set[target]) # valor obtenido por el mutual information
mi_df = pd.DataFrame({'Feature': train_set[listado_features].columns, 'Mutual Information': mi}) # creo un dataframe con los resultados de mutual information
mi_df = mi_df.sort_values(by='Mutual Information', ascending=False).reset_index(drop=True) # ordeno de mayor a menor importancia las features
print(mi_df)
# Out:
#                      Feature  Mutual Information
# 0             Passive Smoker            0.596237
# 1          Coughing of Blood            0.586554
# 2                    Obesity            0.527391
# 3                Alcohol use            0.525049
# 4                 Chest Pain            0.523217
# 5                   Wheezing            0.511944
# 6              Balanced Diet            0.498523
# 7               Dust Allergy            0.470575
# 8                    Smoking            0.424507
# 9        Shortness of Breath            0.406513
# 10              Genetic Risk            0.403832
# 11      OccuPational Hazards            0.385721
# 12                   Fatigue            0.372619
# 13             Air Pollution            0.371173
# 14      chronic Lung Disease            0.367832
# 15                       Age            0.355962
# 16  Clubbing of Finger Nails            0.294432
# 17                 Dry Cough            0.267176
# 18             Frequent Cold            0.257259
# 19               Weight Loss            0.240490
# 20     Swallowing Difficulty            0.134245
# 21                   Snoring            0.090864
# 22                    Gender            0.000000

# %%
# Voy a ponerlo graficamente
plt.figure(figsize=(10,6))
sns.barplot(x='Mutual Information',y='Feature', data=mi_df)
plt.title('Mutual Information of Features for Classification')
plt.xlabel('Mutual Information')
plt.ylabel('Features')
plt.show()

# %%
# Según el mutual information, la única variable que no tendría relación es el género. Aunque se puede poner un límite en valores < 0,1
# Voy a crear un listado de las variables seleccionadas por el mutual information
condicion = mi_df['Mutual Information'] > 0.1
features_mi = mi_df.loc[condicion, 'Feature'].to_list()
features_mi
# Out:
# ['Passive Smoker',
#  'Coughing of Blood',
#  'Obesity',
#  'Alcohol use',
#  'Chest Pain',
#  'Wheezing',
#  'Balanced Diet',
#  'Dust Allergy',
#  'Smoking',
#  'Shortness of Breath',
#  'Genetic Risk',
#  'OccuPational Hazards',
#  'Fatigue',
#  'Air Pollution',
#  'chronic Lung Disease',
#  'Age',
#  'Clubbing of Finger Nails',
#  'Dry Cough',
#  'Frequent Cold',
#  'Weight Loss',
#  'Swallowing Difficulty']

# %%
# Voy a usar la seleccion de features por modelo. 
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

rf_selector = RandomForestClassifier(random_state= 42, class_weight= "balanced") #

selector_modelo = SelectFromModel(estimator = rf_selector, threshold="median") # Nos quedamos con la mitad

selector_modelo.fit(train_set[listado_features], train_set[target]) 
features_modelo = list(selector_modelo.get_feature_names_out())
features_modelo
# Out:
# ['Alcohol use',
#  'Dust Allergy',
#  'Balanced Diet',
#  'Obesity',
#  'Smoking',
#  'Passive Smoker',
#  'Chest Pain',
#  'Coughing of Blood',
#  'Fatigue',
#  'Wheezing',
#  'Swallowing Difficulty',
#  'Clubbing of Finger Nails']

# %%
# De forma manual
rf_check = RandomForestClassifier(random_state= 42, class_weight= "balanced")

rf_check.fit(train_set[listado_features], train_set[target])

df_importance= pd.DataFrame(rf_check.feature_importances_, columns = ["importance"], index = listado_features).sort_values("importance",ascending = False)
df_importance
# Out:
#                           importance
# Coughing of Blood           0.099784
# Obesity                     0.098918
# Wheezing                    0.094752
# Passive Smoker              0.078466
# Chest Pain                  0.052965
# Fatigue                     0.051520
# Balanced Diet               0.045328
# Alcohol use                 0.044283
# Swallowing Difficulty       0.044089
# Smoking                     0.043334
# Dust Allergy                0.041295
# Clubbing of Finger Nails    0.038880
# OccuPational Hazards        0.038780
# Shortness of Breath         0.036123
# Snoring                     0.034247
# Air Pollution               0.033057
# Genetic Risk                0.032036
# Frequent Cold               0.031338
# Weight Loss                 0.026486
# chronic Lung Disease        0.015084
# Dry Cough                   0.013800
# Age                         0.005286
# Gender                      0.000148

# %%
# Cortamos por la mediana
df_importance.importance.median()
# Out:
# np.float64(0.03888029181211212)

# %%
df_importance[df_importance.importance > df_importance.importance.median()]
# Out:
#                        importance
# Coughing of Blood        0.099784
# Obesity                  0.098918
# Wheezing                 0.094752
# Passive Smoker           0.078466
# Chest Pain               0.052965
# Fatigue                  0.051520
# Balanced Diet            0.045328
# Alcohol use              0.044283
# Swallowing Difficulty    0.044089
# Smoking                  0.043334
# Dust Allergy             0.041295

# %%
# Hacemos listado de features modelo manual
features_manual = df_importance[df_importance.importance > df_importance.importance.median()].index.to_list()
features_manual
# Out:
# ['Coughing of Blood',
#  'Obesity',
#  'Wheezing',
#  'Passive Smoker',
#  'Chest Pain',
#  'Fatigue',
#  'Balanced Diet',
#  'Alcohol use',
#  'Swallowing Difficulty',
#  'Smoking',
#  'Dust Allergy']

# %%
# Voy a probar con RFE, me quedaré con 12 features, que son la mitad de las que tengo
from sklearn.feature_selection import  RFE, SequentialFeatureSelector

rf_RFE = RandomForestClassifier(random_state= 42, class_weight= "balanced")

rfe = RFE(estimator = rf_RFE,
          n_features_to_select= 12, # Iterará hasta quedarse con 12
          step = 1)


rfe.fit(train_set[listado_features], train_set[target])
# Out:
# RFE(estimator=RandomForestClassifier(class_weight='balanced', random_state=42),
#     n_features_to_select=12)

# %%
features_RFE = list(rfe.get_feature_names_out())
features_RFE
# Out:
# ['Air Pollution',
#  'Alcohol use',
#  'Dust Allergy',
#  'Balanced Diet',
#  'Obesity',
#  'Smoking',
#  'Passive Smoker',
#  'Coughing of Blood',
#  'Fatigue',
#  'Wheezing',
#  'Clubbing of Finger Nails',
#  'Snoring']

# %%
# Ahora voy a probar con SFS, también escogeré 12

rf_SFS = RandomForestClassifier(class_weight= "balanced", random_state = 42)

sfs_forward = SequentialFeatureSelector(rf_SFS,
                                        n_features_to_select = 12, # número de features a escoger
                                        cv = 4,
                                        scoring = "balanced_accuracy", 
                                        n_jobs = -1)

sfs_forward.fit(train_set[listado_features], train_set[target])
# Out:
# SequentialFeatureSelector(cv=4,
#                           estimator=RandomForestClassifier(class_weight='balanced',
#                                                            random_state=42),
#                           n_features_to_select=12, n_jobs=-1,
#                           scoring='balanced_accuracy')

# %%
features_SFS = list(sfs_forward.get_feature_names_out())
features_SFS
# Out:
# ['Age',
#  'Gender',
#  'Air Pollution',
#  'Alcohol use',
#  'Dust Allergy',
#  'OccuPational Hazards',
#  'Genetic Risk',
#  'chronic Lung Disease',
#  'Balanced Diet',
#  'Obesity',
#  'Coughing of Blood',
#  'Wheezing']

# %%
# Curioso, ya que la edad en la mayoria de seleccion de features está descartada, al igual que el género , que aparentemente tienen menos peso

# %%
# Finalmente voy a hacer un hard-voting, escogiendo las 12 features más votadas, por reducir a la mitad las features seleccionadas, veamos que sale
from collections import Counter

lista_total = features_stad + features_mi + features_manual + features_modelo + features_RFE + features_SFS
votaciones = Counter(lista_total)
votaciones
# Out:
# Counter({'Coughing of Blood': 6,
#          'Obesity': 6,
#          'Wheezing': 6,
#          'Alcohol use': 6,
#          'Balanced Diet': 6,
#          'Dust Allergy': 6,
#          'Passive Smoker': 5,
#          'Smoking': 5,
#          'Fatigue': 5,
#          'Chest Pain': 4,
#          'Air Pollution': 4,
#          'Clubbing of Finger Nails': 4,
#          'Swallowing Difficulty': 4,
#          'OccuPational Hazards': 3,
#          'Genetic Risk': 3,
#          'chronic Lung Disease': 3,
#          'Age': 3,
#          'Shortness of Breath': 2,
#          'Frequent Cold': 2,
#          'Dry Cough': 2,
#          'Weight Loss': 2,
#          'Snoring': 2,
#          'Gender': 2})

# %%
# Ganadores del hard-voting
escrutinio = pd.DataFrame(votaciones.values(), columns = ["Votos"], index = votaciones.keys()).sort_values("Votos", ascending = False)
escrutinio
# Out:
#                           Votos
# Coughing of Blood             6
# Obesity                       6
# Wheezing                      6
# Alcohol use                   6
# Balanced Diet                 6
# Dust Allergy                  6
# Passive Smoker                5
# Smoking                       5
# Fatigue                       5
# Air Pollution                 4
# Chest Pain                    4
# Swallowing Difficulty         4
# Clubbing of Finger Nails      4
# chronic Lung Disease          3
# OccuPational Hazards          3
# Age                           3
# Genetic Risk                  3
# Shortness of Breath           2
# Frequent Cold                 2
# Weight Loss                   2
# Dry Cough                     2
# Snoring                       2
# Gender                        2

# %%
features_hard_voting = escrutinio["Votos"].nlargest(12).index.to_list()
features_hard_voting
# Out:
# ['Coughing of Blood',
#  'Obesity',
#  'Wheezing',
#  'Alcohol use',
#  'Balanced Diet',
#  'Dust Allergy',
#  'Passive Smoker',
#  'Smoking',
#  'Fatigue',
#  'Air Pollution',
#  'Chest Pain',
#  'Swallowing Difficulty']

# %%
# Voy a hacer los splits
X_train = train_set[listado_features]
y_train = train_set[target]

X_test = test_set[listado_features]
y_test = test_set [target]

# %%
# Pasamos al modelado

# Importo las librerias que voy a necesitar

from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV,cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix
from sklearn.svm import SVC
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
# Ojo, para la regresión lineal y para SVC necesitamos scalar las varibles
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(train_set[listado_features]) # Adaptamos el StandarScaler al Train, pero luego usamos el mismo en el test (porque ya la media y la desviación son las del train)
X_train_scalado = pd.DataFrame(scaler.transform(train_set[listado_features]), columns = listado_features)
X_test_scalado = pd.DataFrame(scaler.transform(test_set[listado_features]), columns= listado_features)
X_train_scalado.describe()
# Out:
#                 Age        Gender  Air Pollution   Alcohol use  Dust Allergy  \
# count  9.800000e+02  9.800000e+02   9.800000e+02  9.800000e+02  9.800000e+02
# mean   8.247371e-17  1.749168e-16   1.232574e-16  3.443957e-17 -1.622285e-16
# std    1.000511e+00  1.000511e+00   1.000511e+00  1.000511e+00  1.000511e+00
# min   -1.933838e+00 -8.164966e-01  -1.399085e+00 -1.362645e+00 -2.121869e+00
# 25%   -7.862922e-01 -8.164966e-01  -9.071209e-01 -9.812133e-01 -5.988477e-01
# 50%   -9.776492e-02 -8.164966e-01  -4.151571e-01  1.630815e-01  4.164996e-01
# 75%    6.533558e-01  1.224745e+00   1.060734e+00  9.259446e-01  9.241732e-01
# max    2.990176e+00  1.224745e+00   2.044661e+00  1.307376e+00  1.431847e+00
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count          9.800000e+02  9.800000e+02          9.800000e+02
# mean           5.165936e-17 -1.123818e-16         -3.081435e-17
# std            1.000511e+00  1.000511e+00          1.000511e+00
# min           -1.828445e+00 -1.690121e+00         -1.829155e+00
# 25%           -8.791068e-01 -7.484958e-01         -7.476637e-01
# 50%            7.023167e-02  1.931292e-01         -2.069180e-01
# 75%            1.019570e+00  1.134754e+00          8.745734e-01
# max            1.494239e+00  1.134754e+00          1.415319e+00
#
#        Balanced Diet       Obesity  ...  Coughing of Blood       Fatigue  \
# count   9.800000e+02  9.800000e+02  ...       9.800000e+02  9.800000e+02
# mean    9.788089e-17 -2.447022e-17  ...       1.450087e-17  1.232574e-16
# std     1.000511e+00  1.000511e+00  ...       1.000511e+00  1.000511e+00
# min    -1.637301e+00 -1.637426e+00  ...      -1.581522e+00 -1.271010e+00
# 25%    -1.169228e+00 -6.937754e-01  ...      -7.606051e-01 -8.247220e-01
# 50%    -2.330814e-01 -2.219504e-01  ...      -3.501464e-01 -3.784340e-01
# 75%     1.171138e+00  1.193525e+00  ...       8.812297e-01  5.141420e-01
# max     1.171138e+00  1.193525e+00  ...       1.702147e+00  2.299294e+00
#
#         Weight Loss  Shortness of Breath      Wheezing  Swallowing Difficulty  \
# count  9.800000e+02         9.800000e+02  9.800000e+02           9.800000e+02
# mean  -9.063045e-18        -1.087565e-16 -5.800349e-17          -5.437827e-18
# std    1.000511e+00         1.000511e+00  1.000511e+00           1.000511e+00
# min   -1.289456e+00        -1.423090e+00 -1.359062e+00          -1.203532e+00
# 25%   -8.363661e-01        -9.845278e-01 -8.688595e-01          -7.629412e-01
# 50%   -3.832767e-01        -1.074030e-01  1.115461e-01           1.182402e-01
# 75%    9.759917e-01         7.697217e-01  6.017489e-01           5.588309e-01
# max    1.882171e+00         2.085409e+00  2.072357e+00           1.880603e+00
#
#        Clubbing of Finger Nails  Frequent Cold     Dry Cough       Snoring
# count              9.800000e+02   9.800000e+02  9.800000e+02  9.800000e+02
# mean              -1.993870e-17  -1.468213e-16  5.687061e-17 -4.440892e-17
# std                1.000511e+00   1.000511e+00  1.000511e+00  1.000511e+00
# min               -1.227275e+00  -1.383836e+00 -1.396984e+00 -1.306084e+00
# 25%               -8.083515e-01  -8.378779e-01 -9.076898e-01 -6.295713e-01
# 50%                2.949564e-02  -2.919202e-01  7.089766e-02  4.694172e-02
# 75%                4.484192e-01   7.999952e-01  1.049485e+00  7.234547e-01
# max                2.124114e+00   1.891911e+00  1.538779e+00  2.752994e+00
#
# [8 rows x 23 columns]

# %%
# Aquí voy a ignorar la regresión lineal y el  SVC por el tema del escalado, luego haré similar con estos dos modelos 

nombres = [f"Seleccion {nombre}" for nombre in ["estadistico", "mutual information", "manual", "modelo", "rfe", "sfs", "voting"]]
model_names = ["Random Forest", "KNN", " Decission Tree", "AdaBoost", "LightGBM", "Catboost"]

rf_clf = RandomForestClassifier(class_weight= "balanced", random_state= 42)
knn_clf = KNeighborsClassifier(weights= "uniform", n_jobs= -1)
dt_clf = DecisionTreeClassifier(class_weight = "balanced", random_state = 42) 
ada_clf = AdaBoostClassifier(random_state = 42)
# xg_clf = XGBClassifier(random_state  = 42) necesita que la target sea numérica
lgb_clf = LGBMClassifier(class_weight= "balanced", random_state = 42, verbose = -100, n_jobs= -1)
cb_clf = CatBoostClassifier(random_state = 42)


models = [rf_clf, knn_clf, dt_clf, ada_clf, lgb_clf, cb_clf]
resultados = []

for indice, lista in enumerate([features_stad, features_mi, features_manual, features_modelo, features_RFE, features_SFS, features_hard_voting]):
    X_train_modelos = train_set[lista]
    y_train_modelos = train_set[target]
    
    for model_name, modelo in zip(model_names, models):
        metrica = np.mean(cross_val_score(modelo, X_train_modelos, y_train_modelos, cv = 5, scoring = "balanced_accuracy"))
        data = {
            "features_list": nombres[indice],
            "model": model_name,
            "avg. recall": metrica
        }
        print(data)
        resultados.append(data.copy())
df_resultados = pd.DataFrame(resultados)
df_resultados.sort_values("avg. recall", ascending = False)
# Out:
# {'features_list': 'Seleccion estadistico', 'model': 'Random Forest', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion estadistico', 'model': 'KNN', 'avg. recall': np.float64(0.9977401129943504)}
# {'features_list': 'Seleccion estadistico', 'model': ' Decission Tree', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion estadistico', 'model': 'AdaBoost', 'avg. recall': np.float64(0.9611806460959003)}
# {'features_list': 'Seleccion estadistico', 'model': 'LightGBM', 'avg. recall': np.float64(1.0)}
# Learning rate set to 0.078151
# 0:	learn: 0.9815316	total: 55.1ms	remaining: 55s
# 1:	learn: 0.8853657	total: 56ms	remaining: 27.9s
# 2:	learn: 0.8033016	total: 56.8ms	remaining: 18.9s
# 3:	learn: 0.7306817	total: 57.8ms	remaining: 14.4s
# 4:	learn: 0.6681246	total: 58.6ms	remaining: 11.7s
# 5:	learn: 0.6170800	total: 59.6ms	remaining: 9.88s
# 6:	learn: 0.5664905	total: 60.5ms	remaining: 8.59s
# 7:	learn: 0.5264849	total: 61.4ms	remaining: 7.62s
# 8:	learn: 0.4901864	total: 62.4ms	remaining: 6.87s
# 9:	learn: 0.4526404	total: 63.3ms	remaining: 6.27s
# 10:	learn: 0.4203407	total: 64.2ms	remaining: 5.78s
# 11:	learn: 0.3904184	total: 65.2ms	remaining: 5.37s
# 12:	learn: 0.3632787	total: 66.1ms	remaining: 5.02s
# 13:	learn: 0.3399330	total: 67.1ms	remaining: 4.73s
# 14:	learn: 0.3177262	total: 68.1ms	remaining: 4.47s
# 15:	learn: 0.2970067	total: 69.2ms	remaining: 4.25s
# 16:	learn: 0.2756957	total: 70.2ms	remaining: 4.06s
# 17:	learn: 0.2575019	total: 71.2ms	remaining: 3.89s
# 18:	learn: 0.2411107	total: 72.2ms	remaining: 3.73s
# 19:	learn: 0.2259236	total: 73.3ms	remaining: 3.59s
# 20:	learn: 0.2125744	total: 74.4ms	remaining: 3.47s
# 21:	learn: 0.2006989	total: 75.4ms	remaining: 3.35s
# 22:	learn: 0.1900083	total: 76.4ms	remaining: 3.25s
# 23:	learn: 0.1800811	total: 77.5ms	remaining: 3.15s
# 24:	learn: 0.1702001	total: 78.5ms	remaining: 3.06s
# 25:	learn: 0.1591614	total: 79.7ms	remaining: 2.99s
# 26:	learn: 0.1496345	total: 80.8ms	remaining: 2.91s
# 27:	learn: 0.1413562	total: 81.8ms	remaining: 2.84s
# 28:	learn: 0.1333548	total: 82.8ms	remaining: 2.77s
# 29:	learn: 0.1264149	total: 84ms	remaining: 2.72s
# 30:	learn: 0.1200751	total: 85ms	remaining: 2.65s
# 31:	learn: 0.1136871	total: 86.1ms	remaining: 2.6s
# 32:	learn: 0.1081134	total: 87.3ms	remaining: 2.56s
# 33:	learn: 0.1019186	total: 88.4ms	remaining: 2.51s
# 34:	learn: 0.0964862	total: 89.4ms	remaining: 2.46s
# 35:	learn: 0.0918261	total: 90.5ms	remaining: 2.42s
# 36:	learn: 0.0874412	total: 91.5ms	remaining: 2.38s
# 37:	learn: 0.0834563	total: 92.6ms	remaining: 2.34s
# 38:	learn: 0.0795198	total: 93.7ms	remaining: 2.31s
# 39:	learn: 0.0759942	total: 95.1ms	remaining: 2.28s
# 40:	learn: 0.0726992	total: 96.1ms	remaining: 2.25s
# 41:	learn: 0.0691079	total: 97.2ms	remaining: 2.22s
# 42:	learn: 0.0660696	total: 98.3ms	remaining: 2.19s
# 43:	learn: 0.0634355	total: 99.6ms	remaining: 2.16s
# 44:	learn: 0.0608680	total: 101ms	remaining: 2.13s
# 45:	learn: 0.0583271	total: 102ms	remaining: 2.11s
# 46:	learn: 0.0559297	total: 103ms	remaining: 2.08s
# 47:	learn: 0.0535360	total: 104ms	remaining: 2.06s
# 48:	learn: 0.0515414	total: 105ms	remaining: 2.04s
# 49:	learn: 0.0492575	total: 106ms	remaining: 2.02s
# 50:	learn: 0.0473143	total: 107ms	remaining: 2s
# 51:	learn: 0.0457608	total: 108ms	remaining: 1.98s
# 52:	learn: 0.0443874	total: 110ms	remaining: 1.96s
# 53:	learn: 0.0426157	total: 111ms	remaining: 1.94s
# 54:	learn: 0.0408610	total: 112ms	remaining: 1.92s
# 55:	learn: 0.0397465	total: 113ms	remaining: 1.9s
# 56:	learn: 0.0385151	total: 114ms	remaining: 1.88s
# 57:	learn: 0.0370664	total: 115ms	remaining: 1.86s
# 58:	learn: 0.0360763	total: 116ms	remaining: 1.85s
# 59:	learn: 0.0348777	total: 117ms	remaining: 1.83s
# 60:	learn: 0.0338044	total: 118ms	remaining: 1.82s
# 61:	learn: 0.0327135	total: 119ms	remaining: 1.8s
# 62:	learn: 0.0316679	total: 120ms	remaining: 1.78s
# 63:	learn: 0.0309027	total: 121ms	remaining: 1.77s
# 64:	learn: 0.0299632	total: 122ms	remaining: 1.75s
# 65:	learn: 0.0288848	total: 123ms	remaining: 1.74s
# 66:	learn: 0.0281279	total: 124ms	remaining: 1.73s
# 67:	learn: 0.0273207	total: 125ms	remaining: 1.72s
# 68:	learn: 0.0264993	total: 126ms	remaining: 1.7s
# 69:	learn: 0.0257324	total: 127ms	remaining: 1.69s
# 70:	learn: 0.0249201	total: 128ms	remaining: 1.68s
# 71:	learn: 0.0241539	total: 129ms	remaining: 1.67s
# 72:	learn: 0.0235041	total: 130ms	remaining: 1.66s
# 73:	learn: 0.0229117	total: 131ms	remaining: 1.64s
# 74:	learn: 0.0223446	total: 132ms	remaining: 1.63s
# 75:	learn: 0.0217686	total: 134ms	remaining: 1.62s
# 76:	learn: 0.0213390	total: 135ms	remaining: 1.61s
# 77:	learn: 0.0208532	total: 136ms	remaining: 1.61s
# 78:	learn: 0.0203356	total: 137ms	remaining: 1.6s
# 79:	learn: 0.0198286	total: 138ms	remaining: 1.59s
# 80:	learn: 0.0193321	total: 139ms	remaining: 1.58s
# 81:	learn: 0.0189630	total: 140ms	remaining: 1.57s
# 82:	learn: 0.0184296	total: 141ms	remaining: 1.56s
# 83:	learn: 0.0180684	total: 142ms	remaining: 1.55s
# 84:	learn: 0.0176861	total: 143ms	remaining: 1.54s
# 85:	learn: 0.0173393	total: 144ms	remaining: 1.53s
# 86:	learn: 0.0170006	total: 145ms	remaining: 1.53s
# 87:	learn: 0.0166135	total: 146ms	remaining: 1.52s
# 88:	learn: 0.0162840	total: 147ms	remaining: 1.51s
# 89:	learn: 0.0159863	total: 148ms	remaining: 1.5s
# 90:	learn: 0.0155888	total: 149ms	remaining: 1.49s
# 91:	learn: 0.0152745	total: 150ms	remaining: 1.49s
# 92:	learn: 0.0149398	total: 151ms	remaining: 1.48s
# 93:	learn: 0.0145748	total: 152ms	remaining: 1.47s
# 94:	learn: 0.0143190	total: 153ms	remaining: 1.46s
# 95:	learn: 0.0140544	total: 154ms	remaining: 1.45s
# 96:	learn: 0.0138244	total: 156ms	remaining: 1.45s
# 97:	learn: 0.0135052	total: 157ms	remaining: 1.44s
# 98:	learn: 0.0132641	total: 158ms	remaining: 1.44s
# 99:	learn: 0.0130550	total: 159ms	remaining: 1.43s
# 100:	learn: 0.0128251	total: 160ms	remaining: 1.42s
# 101:	learn: 0.0126300	total: 161ms	remaining: 1.42s
# 102:	learn: 0.0123566	total: 162ms	remaining: 1.41s
# 103:	learn: 0.0120955	total: 163ms	remaining: 1.4s
# 104:	learn: 0.0118685	total: 164ms	remaining: 1.4s
# 105:	learn: 0.0116806	total: 165ms	remaining: 1.39s
# 106:	learn: 0.0115224	total: 166ms	remaining: 1.39s
# 107:	learn: 0.0112911	total: 167ms	remaining: 1.38s
# 108:	learn: 0.0110969	total: 168ms	remaining: 1.37s
# 109:	learn: 0.0108817	total: 169ms	remaining: 1.37s
# 110:	learn: 0.0107482	total: 170ms	remaining: 1.36s
# 111:	learn: 0.0105451	total: 171ms	remaining: 1.35s
# 112:	learn: 0.0104023	total: 171ms	remaining: 1.34s
# 113:	learn: 0.0102619	total: 172ms	remaining: 1.34s
# 114:	learn: 0.0101064	total: 173ms	remaining: 1.33s
# 115:	learn: 0.0099357	total: 174ms	remaining: 1.32s
# 116:	learn: 0.0097926	total: 174ms	remaining: 1.31s
# 117:	learn: 0.0096217	total: 175ms	remaining: 1.31s
# 118:	learn: 0.0094900	total: 177ms	remaining: 1.31s
# 119:	learn: 0.0093319	total: 177ms	remaining: 1.3s
# 120:	learn: 0.0092067	total: 178ms	remaining: 1.29s
# 121:	learn: 0.0090953	total: 179ms	remaining: 1.29s
# 122:	learn: 0.0089702	total: 180ms	remaining: 1.28s
# 123:	learn: 0.0088443	total: 181ms	remaining: 1.28s
# 124:	learn: 0.0087219	total: 182ms	remaining: 1.27s
# 125:	learn: 0.0086056	total: 183ms	remaining: 1.27s
# 126:	learn: 0.0084897	total: 184ms	remaining: 1.26s
# 127:	learn: 0.0083718	total: 184ms	remaining: 1.26s
# 128:	learn: 0.0082621	total: 185ms	remaining: 1.25s
# 129:	learn: 0.0081639	total: 186ms	remaining: 1.25s
# 130:	learn: 0.0080595	total: 187ms	remaining: 1.24s
# 131:	learn: 0.0079414	total: 188ms	remaining: 1.23s
# 132:	learn: 0.0078426	total: 188ms	remaining: 1.23s
# 133:	learn: 0.0077541	total: 189ms	remaining: 1.22s
# 134:	learn: 0.0076598	total: 190ms	remaining: 1.22s
# 135:	learn: 0.0075776	total: 191ms	remaining: 1.21s
# 136:	learn: 0.0074873	total: 192ms	remaining: 1.21s
# 137:	learn: 0.0073991	total: 193ms	remaining: 1.2s
# 138:	learn: 0.0073255	total: 193ms	remaining: 1.2s
# 139:	learn: 0.0072410	total: 194ms	remaining: 1.19s
# 140:	learn: 0.0071585	total: 195ms	remaining: 1.19s
# 141:	learn: 0.0070779	total: 196ms	remaining: 1.18s
# 142:	learn: 0.0069991	total: 196ms	remaining: 1.18s
# 143:	learn: 0.0069221	total: 197ms	remaining: 1.17s
# 144:	learn: 0.0068562	total: 198ms	remaining: 1.17s
# 145:	learn: 0.0067691	total: 199ms	remaining: 1.16s
# 146:	learn: 0.0066842	total: 199ms	remaining: 1.16s
# 147:	learn: 0.0066197	total: 200ms	remaining: 1.15s
# 148:	learn: 0.0065550	total: 201ms	remaining: 1.15s
# 149:	learn: 0.0064960	total: 202ms	remaining: 1.14s
# 150:	learn: 0.0064254	total: 203ms	remaining: 1.14s
# 151:	learn: 0.0063725	total: 203ms	remaining: 1.13s
# 152:	learn: 0.0062964	total: 204ms	remaining: 1.13s
# 153:	learn: 0.0062303	total: 205ms	remaining: 1.12s
# 154:	learn: 0.0061574	total: 206ms	remaining: 1.12s
# 155:	learn: 0.0060927	total: 206ms	remaining: 1.12s
# 156:	learn: 0.0060335	total: 207ms	remaining: 1.11s
# 157:	learn: 0.0059868	total: 208ms	remaining: 1.11s
# 158:	learn: 0.0059255	total: 209ms	remaining: 1.1s
# 159:	learn: 0.0058768	total: 209ms	remaining: 1.1s
# 160:	learn: 0.0058215	total: 210ms	remaining: 1.09s
# 161:	learn: 0.0057714	total: 211ms	remaining: 1.09s
# 162:	learn: 0.0057085	total: 212ms	remaining: 1.09s
# 163:	learn: 0.0056470	total: 212ms	remaining: 1.08s
# 164:	learn: 0.0055869	total: 213ms	remaining: 1.08s
# 165:	learn: 0.0055433	total: 214ms	remaining: 1.07s
# 166:	learn: 0.0054941	total: 215ms	remaining: 1.07s
# 167:	learn: 0.0054514	total: 216ms	remaining: 1.07s
# 168:	learn: 0.0054027	total: 216ms	remaining: 1.06s
# 169:	learn: 0.0053627	total: 217ms	remaining: 1.06s
# 170:	learn: 0.0053254	total: 218ms	remaining: 1.06s
# 171:	learn: 0.0052715	total: 219ms	remaining: 1.05s
# 172:	learn: 0.0052316	total: 219ms	remaining: 1.05s
# 173:	learn: 0.0051932	total: 220ms	remaining: 1.04s
# 174:	learn: 0.0051497	total: 221ms	remaining: 1.04s
# 175:	learn: 0.0051074	total: 222ms	remaining: 1.04s
# 176:	learn: 0.0050702	total: 222ms	remaining: 1.03s
# 177:	learn: 0.0050210	total: 223ms	remaining: 1.03s
# 178:	learn: 0.0049804	total: 224ms	remaining: 1.03s
# 179:	learn: 0.0049329	total: 225ms	remaining: 1.02s
# 180:	learn: 0.0048916	total: 225ms	remaining: 1.02s
# 181:	learn: 0.0048557	total: 226ms	remaining: 1.02s
# 182:	learn: 0.0048221	total: 227ms	remaining: 1.01s
# 183:	learn: 0.0047846	total: 227ms	remaining: 1.01s
# 184:	learn: 0.0047515	total: 228ms	remaining: 1s
# 185:	learn: 0.0047182	total: 229ms	remaining: 1s
# 186:	learn: 0.0046822	total: 230ms	remaining: 999ms
# 187:	learn: 0.0046485	total: 231ms	remaining: 996ms
# 188:	learn: 0.0046103	total: 231ms	remaining: 992ms
# 189:	learn: 0.0045823	total: 232ms	remaining: 989ms
# 190:	learn: 0.0045419	total: 233ms	remaining: 986ms
# 191:	learn: 0.0045118	total: 233ms	remaining: 982ms
# 192:	learn: 0.0044860	total: 234ms	remaining: 979ms
# 193:	learn: 0.0044472	total: 235ms	remaining: 976ms
# 194:	learn: 0.0044151	total: 236ms	remaining: 973ms
# 195:	learn: 0.0043834	total: 237ms	remaining: 970ms
# 196:	learn: 0.0043553	total: 237ms	remaining: 967ms
# 197:	learn: 0.0043275	total: 238ms	remaining: 964ms
# 198:	learn: 0.0042949	total: 239ms	remaining: 961ms
# 199:	learn: 0.0042651	total: 239ms	remaining: 958ms
# 200:	learn: 0.0042298	total: 240ms	remaining: 954ms
# 201:	learn: 0.0042040	total: 241ms	remaining: 951ms
# 202:	learn: 0.0041726	total: 242ms	remaining: 948ms
# 203:	learn: 0.0041388	total: 242ms	remaining: 945ms
# 204:	learn: 0.0041128	total: 243ms	remaining: 942ms
# 205:	learn: 0.0040854	total: 244ms	remaining: 940ms
# 206:	learn: 0.0040557	total: 245ms	remaining: 937ms
# 207:	learn: 0.0040289	total: 246ms	remaining: 935ms
# 208:	learn: 0.0040026	total: 246ms	remaining: 932ms
# 209:	learn: 0.0039715	total: 247ms	remaining: 929ms
# 210:	learn: 0.0039472	total: 248ms	remaining: 926ms
# 211:	learn: 0.0039235	total: 248ms	remaining: 924ms
# 212:	learn: 0.0038970	total: 249ms	remaining: 921ms
# 213:	learn: 0.0038739	total: 250ms	remaining: 918ms
# 214:	learn: 0.0038494	total: 251ms	remaining: 916ms
# 215:	learn: 0.0038252	total: 252ms	remaining: 914ms
# 216:	learn: 0.0038065	total: 253ms	remaining: 911ms
# 217:	learn: 0.0037829	total: 253ms	remaining: 909ms
# 218:	learn: 0.0037550	total: 254ms	remaining: 906ms
# 219:	learn: 0.0037320	total: 255ms	remaining: 903ms
# 220:	learn: 0.0037112	total: 256ms	remaining: 901ms
# 221:	learn: 0.0036899	total: 256ms	remaining: 898ms
# 222:	learn: 0.0036724	total: 257ms	remaining: 896ms
# 223:	learn: 0.0036504	total: 258ms	remaining: 893ms
# 224:	learn: 0.0036286	total: 259ms	remaining: 891ms
# 225:	learn: 0.0036084	total: 259ms	remaining: 889ms
# 226:	learn: 0.0035829	total: 260ms	remaining: 886ms
# 227:	learn: 0.0035620	total: 261ms	remaining: 884ms
# 228:	learn: 0.0035391	total: 262ms	remaining: 882ms
# 229:	learn: 0.0035200	total: 263ms	remaining: 879ms
# 230:	learn: 0.0035015	total: 263ms	remaining: 877ms
# 231:	learn: 0.0034814	total: 264ms	remaining: 874ms
# 232:	learn: 0.0034650	total: 265ms	remaining: 872ms
# 233:	learn: 0.0034454	total: 266ms	remaining: 870ms
# 234:	learn: 0.0034259	total: 267ms	remaining: 868ms
# 235:	learn: 0.0034036	total: 267ms	remaining: 865ms
# 236:	learn: 0.0033847	total: 268ms	remaining: 863ms
# 237:	learn: 0.0033659	total: 269ms	remaining: 860ms
# 238:	learn: 0.0033474	total: 270ms	remaining: 858ms
# 239:	learn: 0.0033329	total: 270ms	remaining: 856ms
# 240:	learn: 0.0033133	total: 271ms	remaining: 853ms
# 241:	learn: 0.0032917	total: 272ms	remaining: 851ms
# 242:	learn: 0.0032704	total: 272ms	remaining: 848ms
# 243:	learn: 0.0032559	total: 273ms	remaining: 846ms
# 244:	learn: 0.0032418	total: 274ms	remaining: 844ms
# 245:	learn: 0.0032260	total: 275ms	remaining: 842ms
# 246:	learn: 0.0032089	total: 275ms	remaining: 840ms
# 247:	learn: 0.0031904	total: 276ms	remaining: 837ms
# 248:	learn: 0.0031703	total: 277ms	remaining: 835ms
# 249:	learn: 0.0031549	total: 278ms	remaining: 833ms
# 250:	learn: 0.0031385	total: 278ms	remaining: 831ms
# 251:	learn: 0.0031269	total: 279ms	remaining: 829ms
# 252:	learn: 0.0031121	total: 280ms	remaining: 827ms
# 253:	learn: 0.0030987	total: 281ms	remaining: 825ms
# 254:	learn: 0.0030796	total: 282ms	remaining: 823ms
# 255:	learn: 0.0030649	total: 282ms	remaining: 820ms
# 256:	learn: 0.0030494	total: 283ms	remaining: 818ms
# 257:	learn: 0.0030348	total: 284ms	remaining: 816ms
# 258:	learn: 0.0030230	total: 285ms	remaining: 814ms
# 259:	learn: 0.0030079	total: 285ms	remaining: 812ms
# 260:	learn: 0.0029930	total: 286ms	remaining: 810ms
# 261:	learn: 0.0029784	total: 287ms	remaining: 808ms
# 262:	learn: 0.0029608	total: 288ms	remaining: 806ms
# 263:	learn: 0.0029463	total: 288ms	remaining: 804ms
# 264:	learn: 0.0029335	total: 289ms	remaining: 802ms
# 265:	learn: 0.0029193	total: 290ms	remaining: 801ms
# 266:	learn: 0.0029059	total: 291ms	remaining: 799ms
# 267:	learn: 0.0028920	total: 292ms	remaining: 797ms
# 268:	learn: 0.0028791	total: 292ms	remaining: 795ms
# 269:	learn: 0.0028655	total: 293ms	remaining: 793ms
# 270:	learn: 0.0028519	total: 294ms	remaining: 791ms
# 271:	learn: 0.0028358	total: 295ms	remaining: 789ms
# 272:	learn: 0.0028238	total: 296ms	remaining: 787ms
# 273:	learn: 0.0028080	total: 296ms	remaining: 785ms
# 274:	learn: 0.0027950	total: 297ms	remaining: 783ms
# 275:	learn: 0.0027846	total: 298ms	remaining: 781ms
# 276:	learn: 0.0027691	total: 299ms	remaining: 779ms
# 277:	learn: 0.0027574	total: 299ms	remaining: 777ms
# 278:	learn: 0.0027448	total: 300ms	remaining: 775ms
# 279:	learn: 0.0027309	total: 301ms	remaining: 773ms
# 280:	learn: 0.0027186	total: 301ms	remaining: 771ms
# 281:	learn: 0.0027085	total: 302ms	remaining: 770ms
# 282:	learn: 0.0026971	total: 303ms	remaining: 768ms
# 283:	learn: 0.0026836	total: 304ms	remaining: 766ms
# 284:	learn: 0.0026692	total: 305ms	remaining: 764ms
# 285:	learn: 0.0026575	total: 305ms	remaining: 763ms
# 286:	learn: 0.0026467	total: 306ms	remaining: 761ms
# 287:	learn: 0.0026351	total: 307ms	remaining: 759ms
# 288:	learn: 0.0026250	total: 308ms	remaining: 757ms
# 289:	learn: 0.0026125	total: 309ms	remaining: 755ms
# 290:	learn: 0.0026013	total: 309ms	remaining: 754ms
# 291:	learn: 0.0025912	total: 310ms	remaining: 752ms
# 292:	learn: 0.0025805	total: 311ms	remaining: 750ms
# 293:	learn: 0.0025709	total: 312ms	remaining: 748ms
# 294:	learn: 0.0025618	total: 312ms	remaining: 746ms
# 295:	learn: 0.0025509	total: 313ms	remaining: 745ms
# 296:	learn: 0.0025407	total: 314ms	remaining: 743ms
# 297:	learn: 0.0025299	total: 315ms	remaining: 741ms
# 298:	learn: 0.0025208	total: 315ms	remaining: 739ms
# 299:	learn: 0.0025120	total: 316ms	remaining: 738ms
# 300:	learn: 0.0025006	total: 317ms	remaining: 736ms
# 301:	learn: 0.0024880	total: 318ms	remaining: 735ms
# 302:	learn: 0.0024777	total: 319ms	remaining: 733ms
# 303:	learn: 0.0024675	total: 319ms	remaining: 731ms
# 304:	learn: 0.0024596	total: 320ms	remaining: 730ms
# 305:	learn: 0.0024496	total: 321ms	remaining: 728ms
# 306:	learn: 0.0024385	total: 322ms	remaining: 727ms
# 307:	learn: 0.0024286	total: 323ms	remaining: 725ms
# 308:	learn: 0.0024197	total: 324ms	remaining: 724ms
# 309:	learn: 0.0024104	total: 324ms	remaining: 722ms
# 310:	learn: 0.0024012	total: 325ms	remaining: 721ms
# 311:	learn: 0.0023920	total: 326ms	remaining: 719ms
# 312:	learn: 0.0023844	total: 327ms	remaining: 717ms
# 313:	learn: 0.0023749	total: 327ms	remaining: 715ms
# 314:	learn: 0.0023645	total: 328ms	remaining: 714ms
# 315:	learn: 0.0023557	total: 329ms	remaining: 712ms
# 316:	learn: 0.0023445	total: 330ms	remaining: 710ms
# 317:	learn: 0.0023361	total: 330ms	remaining: 709ms
# 318:	learn: 0.0023260	total: 331ms	remaining: 707ms
# 319:	learn: 0.0023183	total: 332ms	remaining: 705ms
# 320:	learn: 0.0023084	total: 333ms	remaining: 703ms
# 321:	learn: 0.0023008	total: 333ms	remaining: 702ms
# 322:	learn: 0.0022919	total: 334ms	remaining: 700ms
# 323:	learn: 0.0022831	total: 335ms	remaining: 699ms
# 324:	learn: 0.0022749	total: 336ms	remaining: 697ms
# 325:	learn: 0.0022682	total: 336ms	remaining: 696ms
# 326:	learn: 0.0022622	total: 337ms	remaining: 694ms
# 327:	learn: 0.0022543	total: 338ms	remaining: 692ms
# 328:	learn: 0.0022468	total: 339ms	remaining: 691ms
# 329:	learn: 0.0022391	total: 339ms	remaining: 689ms
# 330:	learn: 0.0022316	total: 340ms	remaining: 688ms
# 331:	learn: 0.0022224	total: 341ms	remaining: 686ms
# 332:	learn: 0.0022142	total: 342ms	remaining: 684ms
# 333:	learn: 0.0022062	total: 342ms	remaining: 683ms
# 334:	learn: 0.0021988	total: 343ms	remaining: 681ms
# 335:	learn: 0.0021889	total: 344ms	remaining: 680ms
# 336:	learn: 0.0021809	total: 345ms	remaining: 678ms
# 337:	learn: 0.0021743	total: 345ms	remaining: 676ms
# 338:	learn: 0.0021672	total: 346ms	remaining: 675ms
# 339:	learn: 0.0021593	total: 347ms	remaining: 673ms
# 340:	learn: 0.0021539	total: 348ms	remaining: 672ms
# 341:	learn: 0.0021468	total: 348ms	remaining: 670ms
# 342:	learn: 0.0021398	total: 349ms	remaining: 669ms
# 343:	learn: 0.0021329	total: 350ms	remaining: 667ms
# 344:	learn: 0.0021259	total: 351ms	remaining: 666ms
# 345:	learn: 0.0021177	total: 351ms	remaining: 664ms
# 346:	learn: 0.0021103	total: 352ms	remaining: 663ms
# 347:	learn: 0.0021028	total: 353ms	remaining: 661ms
# 348:	learn: 0.0020963	total: 354ms	remaining: 660ms
# 349:	learn: 0.0020873	total: 354ms	remaining: 658ms
# 350:	learn: 0.0020784	total: 356ms	remaining: 657ms
# 351:	learn: 0.0020718	total: 357ms	remaining: 656ms
# 352:	learn: 0.0020631	total: 357ms	remaining: 655ms
# 353:	learn: 0.0020559	total: 358ms	remaining: 654ms
# 354:	learn: 0.0020489	total: 359ms	remaining: 652ms
# 355:	learn: 0.0020418	total: 360ms	remaining: 651ms
# 356:	learn: 0.0020354	total: 361ms	remaining: 650ms
# 357:	learn: 0.0020277	total: 362ms	remaining: 649ms
# 358:	learn: 0.0020216	total: 363ms	remaining: 648ms
# 359:	learn: 0.0020151	total: 364ms	remaining: 647ms
# 360:	learn: 0.0020090	total: 365ms	remaining: 646ms
# 361:	learn: 0.0020028	total: 366ms	remaining: 644ms
# 362:	learn: 0.0019976	total: 366ms	remaining: 643ms
# 363:	learn: 0.0019921	total: 367ms	remaining: 641ms
# 364:	learn: 0.0019857	total: 368ms	remaining: 640ms
# 365:	learn: 0.0019797	total: 369ms	remaining: 639ms
# 366:	learn: 0.0019724	total: 370ms	remaining: 638ms
# 367:	learn: 0.0019652	total: 370ms	remaining: 636ms
# 368:	learn: 0.0019593	total: 371ms	remaining: 635ms
# 369:	learn: 0.0019522	total: 372ms	remaining: 633ms
# 370:	learn: 0.0019468	total: 373ms	remaining: 632ms
# 371:	learn: 0.0019411	total: 374ms	remaining: 631ms
# 372:	learn: 0.0019347	total: 375ms	remaining: 630ms
# 373:	learn: 0.0019278	total: 375ms	remaining: 628ms
# 374:	learn: 0.0019217	total: 376ms	remaining: 627ms
# 375:	learn: 0.0019155	total: 377ms	remaining: 625ms
# 376:	learn: 0.0019091	total: 377ms	remaining: 624ms
# 377:	learn: 0.0019046	total: 378ms	remaining: 622ms
# 378:	learn: 0.0018989	total: 379ms	remaining: 621ms
# 379:	learn: 0.0018940	total: 380ms	remaining: 620ms
# 380:	learn: 0.0018873	total: 381ms	remaining: 618ms
# 381:	learn: 0.0018819	total: 381ms	remaining: 617ms
# 382:	learn: 0.0018778	total: 382ms	remaining: 615ms
# 383:	learn: 0.0018713	total: 383ms	remaining: 614ms
# 384:	learn: 0.0018663	total: 384ms	remaining: 613ms
# 385:	learn: 0.0018608	total: 384ms	remaining: 611ms
# 386:	learn: 0.0018544	total: 385ms	remaining: 610ms
# 387:	learn: 0.0018489	total: 386ms	remaining: 609ms
# 388:	learn: 0.0018437	total: 387ms	remaining: 607ms
# 389:	learn: 0.0018392	total: 387ms	remaining: 606ms
# 390:	learn: 0.0018347	total: 388ms	remaining: 604ms
# 391:	learn: 0.0018297	total: 389ms	remaining: 603ms
# 392:	learn: 0.0018246	total: 390ms	remaining: 602ms
# 393:	learn: 0.0018184	total: 390ms	remaining: 600ms
# 394:	learn: 0.0018123	total: 391ms	remaining: 599ms
# 395:	learn: 0.0018062	total: 392ms	remaining: 598ms
# 396:	learn: 0.0017995	total: 393ms	remaining: 596ms
# 397:	learn: 0.0017947	total: 393ms	remaining: 595ms
# 398:	learn: 0.0017888	total: 394ms	remaining: 594ms
# 399:	learn: 0.0017843	total: 395ms	remaining: 592ms
# 400:	learn: 0.0017798	total: 396ms	remaining: 591ms
# 401:	learn: 0.0017740	total: 396ms	remaining: 590ms
# 402:	learn: 0.0017686	total: 397ms	remaining: 588ms
# 403:	learn: 0.0017650	total: 398ms	remaining: 587ms
# 404:	learn: 0.0017605	total: 399ms	remaining: 586ms
# 405:	learn: 0.0017548	total: 400ms	remaining: 585ms
# 406:	learn: 0.0017496	total: 400ms	remaining: 583ms
# 407:	learn: 0.0017449	total: 401ms	remaining: 582ms
# 408:	learn: 0.0017393	total: 402ms	remaining: 581ms
# 409:	learn: 0.0017345	total: 403ms	remaining: 579ms
# 410:	learn: 0.0017289	total: 403ms	remaining: 578ms
# 411:	learn: 0.0017239	total: 404ms	remaining: 576ms
# 412:	learn: 0.0017196	total: 405ms	remaining: 575ms
# 413:	learn: 0.0017152	total: 405ms	remaining: 574ms
# 414:	learn: 0.0017108	total: 406ms	remaining: 572ms
# 415:	learn: 0.0017072	total: 407ms	remaining: 571ms
# 416:	learn: 0.0017022	total: 408ms	remaining: 570ms
# 417:	learn: 0.0016969	total: 408ms	remaining: 569ms
# 418:	learn: 0.0016916	total: 409ms	remaining: 567ms
# 419:	learn: 0.0016873	total: 410ms	remaining: 566ms
# 420:	learn: 0.0016828	total: 411ms	remaining: 565ms
# 421:	learn: 0.0016789	total: 411ms	remaining: 563ms
# 422:	learn: 0.0016737	total: 412ms	remaining: 562ms
# 423:	learn: 0.0016699	total: 413ms	remaining: 561ms
# 424:	learn: 0.0016655	total: 414ms	remaining: 560ms
# 425:	learn: 0.0016602	total: 414ms	remaining: 558ms
# 426:	learn: 0.0016555	total: 415ms	remaining: 557ms
# 427:	learn: 0.0016519	total: 416ms	remaining: 556ms
# 428:	learn: 0.0016479	total: 417ms	remaining: 555ms
# 429:	learn: 0.0016435	total: 417ms	remaining: 553ms
# 430:	learn: 0.0016393	total: 418ms	remaining: 552ms
# 431:	learn: 0.0016347	total: 419ms	remaining: 551ms
# 432:	learn: 0.0016310	total: 419ms	remaining: 549ms
# 433:	learn: 0.0016261	total: 420ms	remaining: 548ms
# 434:	learn: 0.0016224	total: 421ms	remaining: 547ms
# 435:	learn: 0.0016184	total: 422ms	remaining: 545ms
# 436:	learn: 0.0016142	total: 423ms	remaining: 544ms
# 437:	learn: 0.0016103	total: 423ms	remaining: 543ms
# 438:	learn: 0.0016063	total: 424ms	remaining: 542ms
# 439:	learn: 0.0016016	total: 425ms	remaining: 541ms
# 440:	learn: 0.0015982	total: 426ms	remaining: 539ms
# 441:	learn: 0.0015940	total: 426ms	remaining: 538ms
# 442:	learn: 0.0015902	total: 427ms	remaining: 537ms
# 443:	learn: 0.0015862	total: 428ms	remaining: 536ms
# 444:	learn: 0.0015830	total: 429ms	remaining: 535ms
# 445:	learn: 0.0015788	total: 429ms	remaining: 533ms
# 446:	learn: 0.0015742	total: 430ms	remaining: 532ms
# 447:	learn: 0.0015703	total: 431ms	remaining: 531ms
# 448:	learn: 0.0015657	total: 432ms	remaining: 530ms
# 449:	learn: 0.0015625	total: 432ms	remaining: 528ms
# 450:	learn: 0.0015579	total: 433ms	remaining: 527ms
# 451:	learn: 0.0015537	total: 434ms	remaining: 526ms
# 452:	learn: 0.0015493	total: 434ms	remaining: 525ms
# 453:	learn: 0.0015449	total: 435ms	remaining: 523ms
# 454:	learn: 0.0015416	total: 436ms	remaining: 522ms
# 455:	learn: 0.0015372	total: 437ms	remaining: 521ms
# 456:	learn: 0.0015331	total: 437ms	remaining: 520ms
# 457:	learn: 0.0015288	total: 438ms	remaining: 519ms
# 458:	learn: 0.0015257	total: 439ms	remaining: 517ms
# 459:	learn: 0.0015214	total: 440ms	remaining: 516ms
# 460:	learn: 0.0015172	total: 440ms	remaining: 515ms
# 461:	learn: 0.0015140	total: 441ms	remaining: 514ms
# 462:	learn: 0.0015098	total: 442ms	remaining: 513ms
# 463:	learn: 0.0015063	total: 443ms	remaining: 511ms
# 464:	learn: 0.0015020	total: 443ms	remaining: 510ms
# 465:	learn: 0.0014986	total: 444ms	remaining: 509ms
# 466:	learn: 0.0014954	total: 445ms	remaining: 508ms
# 467:	learn: 0.0014920	total: 446ms	remaining: 507ms
# 468:	learn: 0.0014890	total: 446ms	remaining: 505ms
# 469:	learn: 0.0014856	total: 447ms	remaining: 504ms
# 470:	learn: 0.0014825	total: 448ms	remaining: 503ms
# 471:	learn: 0.0014795	total: 449ms	remaining: 502ms
# 472:	learn: 0.0014764	total: 449ms	remaining: 501ms
# 473:	learn: 0.0014735	total: 450ms	remaining: 500ms
# 474:	learn: 0.0014702	total: 451ms	remaining: 498ms
# 475:	learn: 0.0014667	total: 452ms	remaining: 497ms
# 476:	learn: 0.0014622	total: 452ms	remaining: 496ms
# 477:	learn: 0.0014583	total: 453ms	remaining: 495ms
# 478:	learn: 0.0014551	total: 454ms	remaining: 494ms
# 479:	learn: 0.0014516	total: 455ms	remaining: 493ms
# 480:	learn: 0.0014479	total: 456ms	remaining: 491ms
# 481:	learn: 0.0014441	total: 456ms	remaining: 490ms
# 482:	learn: 0.0014409	total: 457ms	remaining: 489ms
# 483:	learn: 0.0014371	total: 458ms	remaining: 488ms
# 484:	learn: 0.0014346	total: 459ms	remaining: 487ms
# 485:	learn: 0.0014310	total: 459ms	remaining: 486ms
# 486:	learn: 0.0014277	total: 460ms	remaining: 485ms
# 487:	learn: 0.0014240	total: 461ms	remaining: 484ms
# 488:	learn: 0.0014203	total: 462ms	remaining: 483ms
# 489:	learn: 0.0014162	total: 463ms	remaining: 482ms
# 490:	learn: 0.0014132	total: 464ms	remaining: 481ms
# 491:	learn: 0.0014100	total: 465ms	remaining: 480ms
# 492:	learn: 0.0014064	total: 465ms	remaining: 479ms
# 493:	learn: 0.0014032	total: 466ms	remaining: 477ms
# 494:	learn: 0.0014005	total: 467ms	remaining: 476ms
# 495:	learn: 0.0013974	total: 468ms	remaining: 475ms
# 496:	learn: 0.0013942	total: 469ms	remaining: 474ms
# 497:	learn: 0.0013911	total: 469ms	remaining: 473ms
# 498:	learn: 0.0013880	total: 470ms	remaining: 472ms
# 499:	learn: 0.0013853	total: 471ms	remaining: 471ms
# 500:	learn: 0.0013825	total: 472ms	remaining: 470ms
# 501:	learn: 0.0013794	total: 472ms	remaining: 469ms
# 502:	learn: 0.0013759	total: 473ms	remaining: 468ms
# 503:	learn: 0.0013724	total: 474ms	remaining: 466ms
# 504:	learn: 0.0013684	total: 475ms	remaining: 465ms
# 505:	learn: 0.0013653	total: 475ms	remaining: 464ms
# 506:	learn: 0.0013619	total: 476ms	remaining: 463ms
# 507:	learn: 0.0013593	total: 477ms	remaining: 462ms
# 508:	learn: 0.0013559	total: 478ms	remaining: 461ms
# 509:	learn: 0.0013532	total: 478ms	remaining: 460ms
# 510:	learn: 0.0013498	total: 479ms	remaining: 458ms
# 511:	learn: 0.0013470	total: 480ms	remaining: 457ms
# 512:	learn: 0.0013443	total: 481ms	remaining: 456ms
# 513:	learn: 0.0013410	total: 481ms	remaining: 455ms
# 514:	learn: 0.0013375	total: 482ms	remaining: 454ms
# 515:	learn: 0.0013345	total: 483ms	remaining: 453ms
# 516:	learn: 0.0013320	total: 484ms	remaining: 452ms
# 517:	learn: 0.0013293	total: 485ms	remaining: 451ms
# 518:	learn: 0.0013266	total: 485ms	remaining: 450ms
# 519:	learn: 0.0013234	total: 486ms	remaining: 449ms
# 520:	learn: 0.0013209	total: 487ms	remaining: 448ms
# 521:	learn: 0.0013183	total: 488ms	remaining: 447ms
# 522:	learn: 0.0013146	total: 488ms	remaining: 446ms
# 523:	learn: 0.0013119	total: 489ms	remaining: 445ms
# 524:	learn: 0.0013095	total: 490ms	remaining: 443ms
# 525:	learn: 0.0013071	total: 491ms	remaining: 442ms
# 526:	learn: 0.0013039	total: 492ms	remaining: 441ms
# 527:	learn: 0.0013010	total: 492ms	remaining: 440ms
# 528:	learn: 0.0012987	total: 493ms	remaining: 439ms
# 529:	learn: 0.0012959	total: 494ms	remaining: 438ms
# 530:	learn: 0.0012933	total: 495ms	remaining: 437ms
# 531:	learn: 0.0012910	total: 495ms	remaining: 436ms
# 532:	learn: 0.0012879	total: 496ms	remaining: 435ms
# 533:	learn: 0.0012854	total: 497ms	remaining: 434ms
# 534:	learn: 0.0012825	total: 498ms	remaining: 433ms
# 535:	learn: 0.0012794	total: 499ms	remaining: 432ms
# 536:	learn: 0.0012765	total: 499ms	remaining: 431ms
# 537:	learn: 0.0012735	total: 500ms	remaining: 429ms
# 538:	learn: 0.0012705	total: 501ms	remaining: 428ms
# 539:	learn: 0.0012678	total: 502ms	remaining: 427ms
# 540:	learn: 0.0012648	total: 502ms	remaining: 426ms
# 541:	learn: 0.0012622	total: 503ms	remaining: 425ms
# 542:	learn: 0.0012599	total: 504ms	remaining: 424ms
# 543:	learn: 0.0012564	total: 505ms	remaining: 423ms
# 544:	learn: 0.0012534	total: 505ms	remaining: 422ms
# 545:	learn: 0.0012511	total: 506ms	remaining: 421ms
# 546:	learn: 0.0012482	total: 507ms	remaining: 420ms
# 547:	learn: 0.0012456	total: 507ms	remaining: 419ms
# 548:	learn: 0.0012427	total: 508ms	remaining: 417ms
# 549:	learn: 0.0012407	total: 509ms	remaining: 416ms
# 550:	learn: 0.0012379	total: 510ms	remaining: 415ms
# 551:	learn: 0.0012354	total: 510ms	remaining: 414ms
# 552:	learn: 0.0012333	total: 511ms	remaining: 413ms
# 553:	learn: 0.0012310	total: 512ms	remaining: 412ms
# 554:	learn: 0.0012282	total: 513ms	remaining: 411ms
# 555:	learn: 0.0012260	total: 514ms	remaining: 410ms
# 556:	learn: 0.0012238	total: 514ms	remaining: 409ms
# 557:	learn: 0.0012218	total: 515ms	remaining: 408ms
# 558:	learn: 0.0012189	total: 516ms	remaining: 407ms
# 559:	learn: 0.0012166	total: 516ms	remaining: 406ms
# 560:	learn: 0.0012142	total: 517ms	remaining: 405ms
# 561:	learn: 0.0012115	total: 518ms	remaining: 404ms
# 562:	learn: 0.0012095	total: 519ms	remaining: 403ms
# 563:	learn: 0.0012068	total: 520ms	remaining: 402ms
# 564:	learn: 0.0012041	total: 520ms	remaining: 401ms
# 565:	learn: 0.0012020	total: 521ms	remaining: 400ms
# 566:	learn: 0.0011993	total: 522ms	remaining: 399ms
# 567:	learn: 0.0011967	total: 523ms	remaining: 397ms
# 568:	learn: 0.0011941	total: 523ms	remaining: 396ms
# 569:	learn: 0.0011914	total: 524ms	remaining: 395ms
# 570:	learn: 0.0011893	total: 525ms	remaining: 394ms
# 571:	learn: 0.0011866	total: 525ms	remaining: 393ms
# 572:	learn: 0.0011842	total: 526ms	remaining: 392ms
# 573:	learn: 0.0011821	total: 527ms	remaining: 391ms
# 574:	learn: 0.0011796	total: 528ms	remaining: 390ms
# 575:	learn: 0.0011773	total: 528ms	remaining: 389ms
# 576:	learn: 0.0011753	total: 529ms	remaining: 388ms
# 577:	learn: 0.0011734	total: 530ms	remaining: 387ms
# 578:	learn: 0.0011713	total: 531ms	remaining: 386ms
# 579:	learn: 0.0011694	total: 531ms	remaining: 385ms
# 580:	learn: 0.0011672	total: 532ms	remaining: 384ms
# 581:	learn: 0.0011653	total: 533ms	remaining: 383ms
# 582:	learn: 0.0011634	total: 534ms	remaining: 382ms
# 583:	learn: 0.0011609	total: 535ms	remaining: 381ms
# 584:	learn: 0.0011594	total: 536ms	remaining: 380ms
# 585:	learn: 0.0011575	total: 537ms	remaining: 379ms
# 586:	learn: 0.0011551	total: 538ms	remaining: 378ms
# 587:	learn: 0.0011530	total: 539ms	remaining: 377ms
# 588:	learn: 0.0011513	total: 540ms	remaining: 377ms
# 589:	learn: 0.0011489	total: 540ms	remaining: 376ms
# 590:	learn: 0.0011469	total: 542ms	remaining: 375ms
# 591:	learn: 0.0011448	total: 543ms	remaining: 374ms
# 592:	learn: 0.0011430	total: 544ms	remaining: 373ms
# 593:	learn: 0.0011410	total: 544ms	remaining: 372ms
# 594:	learn: 0.0011387	total: 545ms	remaining: 371ms
# 595:	learn: 0.0011367	total: 546ms	remaining: 370ms
# 596:	learn: 0.0011349	total: 547ms	remaining: 369ms
# 597:	learn: 0.0011329	total: 548ms	remaining: 368ms
# 598:	learn: 0.0011311	total: 549ms	remaining: 367ms
# 599:	learn: 0.0011287	total: 549ms	remaining: 366ms
# 600:	learn: 0.0011263	total: 550ms	remaining: 365ms
# 601:	learn: 0.0011240	total: 551ms	remaining: 364ms
# 602:	learn: 0.0011218	total: 553ms	remaining: 364ms
# 603:	learn: 0.0011198	total: 554ms	remaining: 363ms
# 604:	learn: 0.0011180	total: 555ms	remaining: 362ms
# 605:	learn: 0.0011159	total: 556ms	remaining: 361ms
# 606:	learn: 0.0011141	total: 557ms	remaining: 360ms
# 607:	learn: 0.0011118	total: 557ms	remaining: 359ms
# 608:	learn: 0.0011101	total: 558ms	remaining: 358ms
# 609:	learn: 0.0011075	total: 559ms	remaining: 357ms
# 610:	learn: 0.0011056	total: 560ms	remaining: 356ms
# 611:	learn: 0.0011037	total: 560ms	remaining: 355ms
# 612:	learn: 0.0011020	total: 561ms	remaining: 354ms
# 613:	learn: 0.0011001	total: 562ms	remaining: 353ms
# 614:	learn: 0.0010982	total: 563ms	remaining: 352ms
# 615:	learn: 0.0010963	total: 564ms	remaining: 351ms
# 616:	learn: 0.0010940	total: 564ms	remaining: 350ms
# 617:	learn: 0.0010918	total: 565ms	remaining: 349ms
# 618:	learn: 0.0010900	total: 566ms	remaining: 348ms
# 619:	learn: 0.0010881	total: 567ms	remaining: 347ms
# 620:	learn: 0.0010864	total: 568ms	remaining: 346ms
# 621:	learn: 0.0010847	total: 568ms	remaining: 345ms
# 622:	learn: 0.0010828	total: 569ms	remaining: 344ms
# 623:	learn: 0.0010807	total: 571ms	remaining: 344ms
# 624:	learn: 0.0010785	total: 572ms	remaining: 343ms
# 625:	learn: 0.0010764	total: 573ms	remaining: 342ms
# 626:	learn: 0.0010748	total: 574ms	remaining: 341ms
# 627:	learn: 0.0010732	total: 574ms	remaining: 340ms
# 628:	learn: 0.0010711	total: 575ms	remaining: 339ms
# 629:	learn: 0.0010695	total: 576ms	remaining: 338ms
# 630:	learn: 0.0010677	total: 577ms	remaining: 337ms
# 631:	learn: 0.0010656	total: 578ms	remaining: 336ms
# 632:	learn: 0.0010638	total: 578ms	remaining: 335ms
# 633:	learn: 0.0010623	total: 579ms	remaining: 334ms
# 634:	learn: 0.0010609	total: 580ms	remaining: 333ms
# 635:	learn: 0.0010591	total: 581ms	remaining: 332ms
# 636:	learn: 0.0010567	total: 581ms	remaining: 331ms
# 637:	learn: 0.0010551	total: 582ms	remaining: 330ms
# 638:	learn: 0.0010534	total: 583ms	remaining: 329ms
# 639:	learn: 0.0010514	total: 584ms	remaining: 328ms
# 640:	learn: 0.0010495	total: 584ms	remaining: 327ms
# 641:	learn: 0.0010475	total: 585ms	remaining: 326ms
# 642:	learn: 0.0010460	total: 586ms	remaining: 325ms
# 643:	learn: 0.0010440	total: 587ms	remaining: 324ms
# 644:	learn: 0.0010425	total: 588ms	remaining: 323ms
# 645:	learn: 0.0010407	total: 588ms	remaining: 322ms
# 646:	learn: 0.0010387	total: 589ms	remaining: 321ms
# 647:	learn: 0.0010370	total: 590ms	remaining: 320ms
# 648:	learn: 0.0010354	total: 591ms	remaining: 319ms
# 649:	learn: 0.0010335	total: 591ms	remaining: 318ms
# 650:	learn: 0.0010318	total: 592ms	remaining: 318ms
# 651:	learn: 0.0010299	total: 593ms	remaining: 317ms
# 652:	learn: 0.0010282	total: 594ms	remaining: 316ms
# 653:	learn: 0.0010264	total: 595ms	remaining: 315ms
# 654:	learn: 0.0010246	total: 595ms	remaining: 314ms
# 655:	learn: 0.0010233	total: 596ms	remaining: 313ms
# 656:	learn: 0.0010218	total: 597ms	remaining: 312ms
# 657:	learn: 0.0010199	total: 598ms	remaining: 311ms
# 658:	learn: 0.0010180	total: 598ms	remaining: 310ms
# 659:	learn: 0.0010165	total: 599ms	remaining: 309ms
# 660:	learn: 0.0010145	total: 600ms	remaining: 307ms
# 661:	learn: 0.0010130	total: 600ms	remaining: 307ms
# 662:	learn: 0.0010111	total: 601ms	remaining: 306ms
# 663:	learn: 0.0010095	total: 602ms	remaining: 305ms
# 664:	learn: 0.0010078	total: 603ms	remaining: 304ms
# 665:	learn: 0.0010059	total: 603ms	remaining: 303ms
# 666:	learn: 0.0010040	total: 604ms	remaining: 302ms
# 667:	learn: 0.0010026	total: 605ms	remaining: 301ms
# 668:	learn: 0.0010010	total: 606ms	remaining: 300ms
# 669:	learn: 0.0009996	total: 606ms	remaining: 299ms
# 670:	learn: 0.0009980	total: 607ms	remaining: 298ms
# 671:	learn: 0.0009965	total: 608ms	remaining: 297ms
# 672:	learn: 0.0009950	total: 609ms	remaining: 296ms
# 673:	learn: 0.0009934	total: 610ms	remaining: 295ms
# 674:	learn: 0.0009920	total: 610ms	remaining: 294ms
# 675:	learn: 0.0009905	total: 611ms	remaining: 293ms
# 676:	learn: 0.0009891	total: 612ms	remaining: 292ms
# 677:	learn: 0.0009875	total: 613ms	remaining: 291ms
# 678:	learn: 0.0009860	total: 613ms	remaining: 290ms
# 679:	learn: 0.0009846	total: 614ms	remaining: 289ms
# 680:	learn: 0.0009832	total: 615ms	remaining: 288ms
# 681:	learn: 0.0009818	total: 616ms	remaining: 287ms
# 682:	learn: 0.0009800	total: 616ms	remaining: 286ms
# 683:	learn: 0.0009785	total: 617ms	remaining: 285ms
# 684:	learn: 0.0009768	total: 618ms	remaining: 284ms
# 685:	learn: 0.0009755	total: 619ms	remaining: 283ms
# 686:	learn: 0.0009737	total: 619ms	remaining: 282ms
# 687:	learn: 0.0009720	total: 620ms	remaining: 281ms
# 688:	learn: 0.0009707	total: 621ms	remaining: 280ms
# 689:	learn: 0.0009693	total: 622ms	remaining: 279ms
# 690:	learn: 0.0009679	total: 623ms	remaining: 278ms
# 691:	learn: 0.0009665	total: 623ms	remaining: 277ms
# 692:	learn: 0.0009648	total: 624ms	remaining: 276ms
# 693:	learn: 0.0009636	total: 625ms	remaining: 275ms
# 694:	learn: 0.0009623	total: 626ms	remaining: 275ms
# 695:	learn: 0.0009610	total: 626ms	remaining: 274ms
# 696:	learn: 0.0009597	total: 627ms	remaining: 273ms
# 697:	learn: 0.0009584	total: 628ms	remaining: 272ms
# 698:	learn: 0.0009568	total: 629ms	remaining: 271ms
# 699:	learn: 0.0009554	total: 629ms	remaining: 270ms
# 700:	learn: 0.0009542	total: 630ms	remaining: 269ms
# 701:	learn: 0.0009525	total: 631ms	remaining: 268ms
# 702:	learn: 0.0009511	total: 632ms	remaining: 267ms
# 703:	learn: 0.0009494	total: 632ms	remaining: 266ms
# 704:	learn: 0.0009480	total: 633ms	remaining: 265ms
# 705:	learn: 0.0009468	total: 634ms	remaining: 264ms
# 706:	learn: 0.0009454	total: 635ms	remaining: 263ms
# 707:	learn: 0.0009437	total: 635ms	remaining: 262ms
# 708:	learn: 0.0009424	total: 636ms	remaining: 261ms
# 709:	learn: 0.0009410	total: 637ms	remaining: 260ms
# 710:	learn: 0.0009394	total: 638ms	remaining: 259ms
# 711:	learn: 0.0009381	total: 638ms	remaining: 258ms
# 712:	learn: 0.0009370	total: 639ms	remaining: 257ms
# 713:	learn: 0.0009357	total: 640ms	remaining: 256ms
# 714:	learn: 0.0009341	total: 641ms	remaining: 255ms
# 715:	learn: 0.0009325	total: 641ms	remaining: 254ms
# 716:	learn: 0.0009310	total: 642ms	remaining: 253ms
# 717:	learn: 0.0009298	total: 643ms	remaining: 253ms
# 718:	learn: 0.0009277	total: 644ms	remaining: 252ms
# 719:	learn: 0.0009261	total: 644ms	remaining: 251ms
# 720:	learn: 0.0009248	total: 645ms	remaining: 250ms
# 721:	learn: 0.0009235	total: 646ms	remaining: 249ms
# 722:	learn: 0.0009219	total: 647ms	remaining: 248ms
# 723:	learn: 0.0009206	total: 648ms	remaining: 247ms
# 724:	learn: 0.0009194	total: 649ms	remaining: 246ms
# 725:	learn: 0.0009182	total: 649ms	remaining: 245ms
# 726:	learn: 0.0009167	total: 650ms	remaining: 244ms
# 727:	learn: 0.0009155	total: 651ms	remaining: 243ms
# 728:	learn: 0.0009143	total: 652ms	remaining: 242ms
# 729:	learn: 0.0009130	total: 653ms	remaining: 241ms
# 730:	learn: 0.0009118	total: 653ms	remaining: 240ms
# 731:	learn: 0.0009107	total: 654ms	remaining: 240ms
# 732:	learn: 0.0009092	total: 655ms	remaining: 239ms
# 733:	learn: 0.0009080	total: 656ms	remaining: 238ms
# 734:	learn: 0.0009068	total: 657ms	remaining: 237ms
# 735:	learn: 0.0009055	total: 657ms	remaining: 236ms
# 736:	learn: 0.0009042	total: 658ms	remaining: 235ms
# 737:	learn: 0.0009031	total: 659ms	remaining: 234ms
# 738:	learn: 0.0009016	total: 660ms	remaining: 233ms
# 739:	learn: 0.0009004	total: 661ms	remaining: 232ms
# 740:	learn: 0.0008991	total: 662ms	remaining: 231ms
# 741:	learn: 0.0008978	total: 662ms	remaining: 230ms
# 742:	learn: 0.0008963	total: 663ms	remaining: 229ms
# 743:	learn: 0.0008948	total: 664ms	remaining: 228ms
# 744:	learn: 0.0008936	total: 665ms	remaining: 228ms
# 745:	learn: 0.0008923	total: 665ms	remaining: 227ms
# 746:	learn: 0.0008912	total: 666ms	remaining: 226ms
# 747:	learn: 0.0008900	total: 667ms	remaining: 225ms
# 748:	learn: 0.0008888	total: 668ms	remaining: 224ms
# 749:	learn: 0.0008876	total: 669ms	remaining: 223ms
# 750:	learn: 0.0008861	total: 669ms	remaining: 222ms
# 751:	learn: 0.0008849	total: 670ms	remaining: 221ms
# 752:	learn: 0.0008838	total: 671ms	remaining: 220ms
# 753:	learn: 0.0008826	total: 672ms	remaining: 219ms
# 754:	learn: 0.0008815	total: 672ms	remaining: 218ms
# 755:	learn: 0.0008805	total: 673ms	remaining: 217ms
# 756:	learn: 0.0008794	total: 674ms	remaining: 216ms
# 757:	learn: 0.0008784	total: 674ms	remaining: 215ms
# 758:	learn: 0.0008773	total: 675ms	remaining: 214ms
# 759:	learn: 0.0008761	total: 676ms	remaining: 213ms
# 760:	learn: 0.0008751	total: 677ms	remaining: 213ms
# 761:	learn: 0.0008734	total: 678ms	remaining: 212ms
# 762:	learn: 0.0008720	total: 678ms	remaining: 211ms
# 763:	learn: 0.0008708	total: 679ms	remaining: 210ms
# 764:	learn: 0.0008697	total: 680ms	remaining: 209ms
# 765:	learn: 0.0008686	total: 680ms	remaining: 208ms
# 766:	learn: 0.0008675	total: 681ms	remaining: 207ms
# 767:	learn: 0.0008662	total: 682ms	remaining: 206ms
# 768:	learn: 0.0008648	total: 683ms	remaining: 205ms
# 769:	learn: 0.0008637	total: 684ms	remaining: 204ms
# 770:	learn: 0.0008626	total: 684ms	remaining: 203ms
# 771:	learn: 0.0008616	total: 685ms	remaining: 202ms
# 772:	learn: 0.0008606	total: 686ms	remaining: 201ms
# 773:	learn: 0.0008595	total: 686ms	remaining: 200ms
# 774:	learn: 0.0008584	total: 687ms	remaining: 200ms
# 775:	learn: 0.0008571	total: 688ms	remaining: 199ms
# 776:	learn: 0.0008561	total: 689ms	remaining: 198ms
# 777:	learn: 0.0008550	total: 689ms	remaining: 197ms
# 778:	learn: 0.0008539	total: 690ms	remaining: 196ms
# 779:	learn: 0.0008528	total: 691ms	remaining: 195ms
# 780:	learn: 0.0008515	total: 692ms	remaining: 194ms
# 781:	learn: 0.0008503	total: 693ms	remaining: 193ms
# 782:	learn: 0.0008492	total: 693ms	remaining: 192ms
# 783:	learn: 0.0008480	total: 694ms	remaining: 191ms
# 784:	learn: 0.0008467	total: 695ms	remaining: 190ms
# 785:	learn: 0.0008454	total: 696ms	remaining: 189ms
# 786:	learn: 0.0008445	total: 697ms	remaining: 189ms
# 787:	learn: 0.0008435	total: 697ms	remaining: 188ms
# 788:	learn: 0.0008426	total: 698ms	remaining: 187ms
# 789:	learn: 0.0008416	total: 699ms	remaining: 186ms
# 790:	learn: 0.0008407	total: 700ms	remaining: 185ms
# 791:	learn: 0.0008396	total: 700ms	remaining: 184ms
# 792:	learn: 0.0008387	total: 701ms	remaining: 183ms
# 793:	learn: 0.0008374	total: 702ms	remaining: 182ms
# 794:	learn: 0.0008364	total: 702ms	remaining: 181ms
# 795:	learn: 0.0008354	total: 703ms	remaining: 180ms
# 796:	learn: 0.0008341	total: 704ms	remaining: 179ms
# 797:	learn: 0.0008329	total: 705ms	remaining: 178ms
# 798:	learn: 0.0008319	total: 706ms	remaining: 177ms
# 799:	learn: 0.0008309	total: 706ms	remaining: 177ms
# 800:	learn: 0.0008299	total: 707ms	remaining: 176ms
# 801:	learn: 0.0008288	total: 708ms	remaining: 175ms
# 802:	learn: 0.0008276	total: 709ms	remaining: 174ms
# 803:	learn: 0.0008260	total: 709ms	remaining: 173ms
# 804:	learn: 0.0008251	total: 710ms	remaining: 172ms
# 805:	learn: 0.0008239	total: 711ms	remaining: 171ms
# 806:	learn: 0.0008229	total: 712ms	remaining: 170ms
# 807:	learn: 0.0008216	total: 713ms	remaining: 169ms
# 808:	learn: 0.0008206	total: 713ms	remaining: 168ms
# 809:	learn: 0.0008195	total: 714ms	remaining: 167ms
# 810:	learn: 0.0008186	total: 715ms	remaining: 167ms
# 811:	learn: 0.0008177	total: 716ms	remaining: 166ms
# 812:	learn: 0.0008167	total: 717ms	remaining: 165ms
# 813:	learn: 0.0008157	total: 718ms	remaining: 164ms
# 814:	learn: 0.0008147	total: 719ms	remaining: 163ms
# 815:	learn: 0.0008137	total: 720ms	remaining: 162ms
# 816:	learn: 0.0008127	total: 721ms	remaining: 162ms
# 817:	learn: 0.0008118	total: 722ms	remaining: 161ms
# 818:	learn: 0.0008108	total: 723ms	remaining: 160ms
# 819:	learn: 0.0008098	total: 724ms	remaining: 159ms
# 820:	learn: 0.0008089	total: 725ms	remaining: 158ms
# 821:	learn: 0.0008080	total: 726ms	remaining: 157ms
# 822:	learn: 0.0008071	total: 727ms	remaining: 156ms
# 823:	learn: 0.0008062	total: 728ms	remaining: 155ms
# 824:	learn: 0.0008053	total: 728ms	remaining: 154ms
# 825:	learn: 0.0008043	total: 729ms	remaining: 154ms
# 826:	learn: 0.0008035	total: 730ms	remaining: 153ms
# 827:	learn: 0.0008025	total: 731ms	remaining: 152ms
# 828:	learn: 0.0008015	total: 731ms	remaining: 151ms
# 829:	learn: 0.0008005	total: 732ms	remaining: 150ms
# 830:	learn: 0.0007995	total: 733ms	remaining: 149ms
# 831:	learn: 0.0007986	total: 734ms	remaining: 148ms
# 832:	learn: 0.0007976	total: 735ms	remaining: 147ms
# 833:	learn: 0.0007964	total: 736ms	remaining: 146ms
# 834:	learn: 0.0007953	total: 737ms	remaining: 146ms
# 835:	learn: 0.0007941	total: 737ms	remaining: 145ms
# 836:	learn: 0.0007932	total: 738ms	remaining: 144ms
# 837:	learn: 0.0007923	total: 739ms	remaining: 143ms
# 838:	learn: 0.0007912	total: 740ms	remaining: 142ms
# 839:	learn: 0.0007901	total: 741ms	remaining: 141ms
# 840:	learn: 0.0007892	total: 741ms	remaining: 140ms
# 841:	learn: 0.0007880	total: 742ms	remaining: 139ms
# 842:	learn: 0.0007869	total: 743ms	remaining: 138ms
# 843:	learn: 0.0007860	total: 744ms	remaining: 137ms
# 844:	learn: 0.0007849	total: 744ms	remaining: 137ms
# 845:	learn: 0.0007838	total: 745ms	remaining: 136ms
# 846:	learn: 0.0007826	total: 746ms	remaining: 135ms
# 847:	learn: 0.0007815	total: 747ms	remaining: 134ms
# 848:	learn: 0.0007805	total: 748ms	remaining: 133ms
# 849:	learn: 0.0007796	total: 748ms	remaining: 132ms
# 850:	learn: 0.0007787	total: 749ms	remaining: 131ms
# 851:	learn: 0.0007778	total: 750ms	remaining: 130ms
# 852:	learn: 0.0007769	total: 751ms	remaining: 129ms
# 853:	learn: 0.0007760	total: 752ms	remaining: 129ms
# 854:	learn: 0.0007751	total: 753ms	remaining: 128ms
# 855:	learn: 0.0007743	total: 753ms	remaining: 127ms
# 856:	learn: 0.0007734	total: 754ms	remaining: 126ms
# 857:	learn: 0.0007725	total: 755ms	remaining: 125ms
# 858:	learn: 0.0007715	total: 756ms	remaining: 124ms
# 859:	learn: 0.0007706	total: 757ms	remaining: 123ms
# 860:	learn: 0.0007695	total: 757ms	remaining: 122ms
# 861:	learn: 0.0007686	total: 758ms	remaining: 121ms
# 862:	learn: 0.0007678	total: 759ms	remaining: 120ms
# 863:	learn: 0.0007669	total: 760ms	remaining: 120ms
# 864:	learn: 0.0007658	total: 760ms	remaining: 119ms
# 865:	learn: 0.0007647	total: 761ms	remaining: 118ms
# 866:	learn: 0.0007639	total: 762ms	remaining: 117ms
# 867:	learn: 0.0007630	total: 762ms	remaining: 116ms
# 868:	learn: 0.0007621	total: 763ms	remaining: 115ms
# 869:	learn: 0.0007613	total: 764ms	remaining: 114ms
# 870:	learn: 0.0007604	total: 765ms	remaining: 113ms
# 871:	learn: 0.0007597	total: 766ms	remaining: 112ms
# 872:	learn: 0.0007589	total: 766ms	remaining: 111ms
# 873:	learn: 0.0007581	total: 767ms	remaining: 111ms
# 874:	learn: 0.0007571	total: 768ms	remaining: 110ms
# 875:	learn: 0.0007562	total: 769ms	remaining: 109ms
# 876:	learn: 0.0007552	total: 769ms	remaining: 108ms
# 877:	learn: 0.0007539	total: 770ms	remaining: 107ms
# 878:	learn: 0.0007531	total: 771ms	remaining: 106ms
# 879:	learn: 0.0007524	total: 772ms	remaining: 105ms
# 880:	learn: 0.0007515	total: 773ms	remaining: 104ms
# 881:	learn: 0.0007505	total: 773ms	remaining: 103ms
# 882:	learn: 0.0007495	total: 774ms	remaining: 103ms
# 883:	learn: 0.0007486	total: 775ms	remaining: 102ms
# 884:	learn: 0.0007478	total: 775ms	remaining: 101ms
# 885:	learn: 0.0007470	total: 776ms	remaining: 99.9ms
# 886:	learn: 0.0007460	total: 777ms	remaining: 99ms
# 887:	learn: 0.0007450	total: 778ms	remaining: 98.1ms
# 888:	learn: 0.0007442	total: 778ms	remaining: 97.2ms
# 889:	learn: 0.0007432	total: 779ms	remaining: 96.3ms
# 890:	learn: 0.0007424	total: 780ms	remaining: 95.4ms
# 891:	learn: 0.0007415	total: 781ms	remaining: 94.5ms
# 892:	learn: 0.0007407	total: 782ms	remaining: 93.6ms
# 893:	learn: 0.0007399	total: 782ms	remaining: 92.8ms
# 894:	learn: 0.0007389	total: 783ms	remaining: 91.9ms
# 895:	learn: 0.0007381	total: 784ms	remaining: 91ms
# 896:	learn: 0.0007374	total: 784ms	remaining: 90.1ms
# 897:	learn: 0.0007366	total: 785ms	remaining: 89.2ms
# 898:	learn: 0.0007358	total: 786ms	remaining: 88.3ms
# 899:	learn: 0.0007351	total: 787ms	remaining: 87.4ms
# 900:	learn: 0.0007343	total: 788ms	remaining: 86.6ms
# 901:	learn: 0.0007333	total: 788ms	remaining: 85.7ms
# 902:	learn: 0.0007326	total: 789ms	remaining: 84.8ms
# 903:	learn: 0.0007316	total: 790ms	remaining: 83.9ms
# 904:	learn: 0.0007309	total: 791ms	remaining: 83ms
# 905:	learn: 0.0007301	total: 791ms	remaining: 82.1ms
# 906:	learn: 0.0007293	total: 792ms	remaining: 81.2ms
# 907:	learn: 0.0007285	total: 793ms	remaining: 80.3ms
# 908:	learn: 0.0007278	total: 794ms	remaining: 79.5ms
# 909:	learn: 0.0007271	total: 794ms	remaining: 78.6ms
# 910:	learn: 0.0007262	total: 795ms	remaining: 77.7ms
# 911:	learn: 0.0007252	total: 796ms	remaining: 76.8ms
# 912:	learn: 0.0007245	total: 797ms	remaining: 76ms
# 913:	learn: 0.0007235	total: 798ms	remaining: 75.1ms
# ...
# 748:	learn: 0.0008462	total: 602ms	remaining: 202ms
# 749:	learn: 0.0008450	total: 603ms	remaining: 201ms
# 750:	learn: 0.0008436	total: 603ms	remaining: 200ms
# 751:	learn: 0.0008424	total: 604ms	remaining: 199ms
# 752:	learn: 0.0008412	total: 605ms	remaining: 198ms
# 753:	learn: 0.0008401	total: 605ms	remaining: 197ms
# 754:	learn: 0.0008388	total: 606ms	remaining: 197ms
# 755:	learn: 0.0008377	total: 606ms	remaining: 196ms
# 756:	learn: 0.0008367	total: 607ms	remaining: 195ms
# 757:	learn: 0.0008356	total: 608ms	remaining: 194ms
# 758:	learn: 0.0008342	total: 608ms	remaining: 193ms
# 759:	learn: 0.0008331	total: 609ms	remaining: 192ms
# 760:	learn: 0.0008321	total: 610ms	remaining: 192ms
# 761:	learn: 0.0008308	total: 611ms	remaining: 191ms
# 762:	learn: 0.0008297	total: 611ms	remaining: 190ms
# 763:	learn: 0.0008286	total: 612ms	remaining: 189ms
# 764:	learn: 0.0008274	total: 612ms	remaining: 188ms
# 765:	learn: 0.0008261	total: 613ms	remaining: 187ms
# 766:	learn: 0.0008250	total: 614ms	remaining: 186ms
# 767:	learn: 0.0008238	total: 614ms	remaining: 186ms
# 768:	learn: 0.0008224	total: 615ms	remaining: 185ms
# 769:	learn: 0.0008210	total: 616ms	remaining: 184ms
# 770:	learn: 0.0008201	total: 616ms	remaining: 183ms
# 771:	learn: 0.0008190	total: 617ms	remaining: 182ms
# 772:	learn: 0.0008178	total: 618ms	remaining: 181ms
# 773:	learn: 0.0008165	total: 618ms	remaining: 181ms
# 774:	learn: 0.0008154	total: 619ms	remaining: 180ms
# 775:	learn: 0.0008143	total: 620ms	remaining: 179ms
# 776:	learn: 0.0008130	total: 620ms	remaining: 178ms
# 777:	learn: 0.0008120	total: 621ms	remaining: 177ms
# 778:	learn: 0.0008109	total: 622ms	remaining: 176ms
# 779:	learn: 0.0008097	total: 622ms	remaining: 176ms
# 780:	learn: 0.0008085	total: 623ms	remaining: 175ms
# 781:	learn: 0.0008074	total: 624ms	remaining: 174ms
# 782:	learn: 0.0008061	total: 624ms	remaining: 173ms
# 783:	learn: 0.0008049	total: 625ms	remaining: 172ms
# 784:	learn: 0.0008037	total: 626ms	remaining: 171ms
# 785:	learn: 0.0008021	total: 626ms	remaining: 171ms
# 786:	learn: 0.0008010	total: 628ms	remaining: 170ms
# 787:	learn: 0.0007999	total: 629ms	remaining: 169ms
# 788:	learn: 0.0007989	total: 629ms	remaining: 168ms
# 789:	learn: 0.0007978	total: 630ms	remaining: 168ms
# 790:	learn: 0.0007967	total: 631ms	remaining: 167ms
# 791:	learn: 0.0007956	total: 632ms	remaining: 166ms
# 792:	learn: 0.0007941	total: 632ms	remaining: 165ms
# 793:	learn: 0.0007932	total: 633ms	remaining: 164ms
# 794:	learn: 0.0007921	total: 634ms	remaining: 164ms
# 795:	learn: 0.0007909	total: 635ms	remaining: 163ms
# 796:	learn: 0.0007896	total: 636ms	remaining: 162ms
# 797:	learn: 0.0007885	total: 636ms	remaining: 161ms
# 798:	learn: 0.0007872	total: 637ms	remaining: 160ms
# 799:	learn: 0.0007863	total: 638ms	remaining: 160ms
# 800:	learn: 0.0007854	total: 639ms	remaining: 159ms
# 801:	learn: 0.0007846	total: 640ms	remaining: 158ms
# 802:	learn: 0.0007837	total: 640ms	remaining: 157ms
# 803:	learn: 0.0007828	total: 641ms	remaining: 156ms
# 804:	learn: 0.0007818	total: 642ms	remaining: 155ms
# 805:	learn: 0.0007806	total: 642ms	remaining: 155ms
# 806:	learn: 0.0007796	total: 643ms	remaining: 154ms
# 807:	learn: 0.0007785	total: 644ms	remaining: 153ms
# 808:	learn: 0.0007775	total: 645ms	remaining: 152ms
# 809:	learn: 0.0007765	total: 645ms	remaining: 151ms
# 810:	learn: 0.0007751	total: 646ms	remaining: 151ms
# 811:	learn: 0.0007741	total: 647ms	remaining: 150ms
# 812:	learn: 0.0007733	total: 648ms	remaining: 149ms
# 813:	learn: 0.0007724	total: 649ms	remaining: 148ms
# 814:	learn: 0.0007714	total: 649ms	remaining: 147ms
# 815:	learn: 0.0007702	total: 650ms	remaining: 147ms
# 816:	learn: 0.0007693	total: 651ms	remaining: 146ms
# 817:	learn: 0.0007683	total: 651ms	remaining: 145ms
# 818:	learn: 0.0007674	total: 652ms	remaining: 144ms
# 819:	learn: 0.0007664	total: 653ms	remaining: 143ms
# 820:	learn: 0.0007655	total: 653ms	remaining: 142ms
# 821:	learn: 0.0007644	total: 654ms	remaining: 142ms
# 822:	learn: 0.0007634	total: 655ms	remaining: 141ms
# 823:	learn: 0.0007620	total: 655ms	remaining: 140ms
# 824:	learn: 0.0007609	total: 656ms	remaining: 139ms
# 825:	learn: 0.0007598	total: 657ms	remaining: 138ms
# 826:	learn: 0.0007588	total: 657ms	remaining: 137ms
# 827:	learn: 0.0007576	total: 658ms	remaining: 137ms
# 828:	learn: 0.0007568	total: 659ms	remaining: 136ms
# 829:	learn: 0.0007557	total: 659ms	remaining: 135ms
# 830:	learn: 0.0007549	total: 660ms	remaining: 134ms
# 831:	learn: 0.0007539	total: 661ms	remaining: 133ms
# 832:	learn: 0.0007529	total: 661ms	remaining: 133ms
# 833:	learn: 0.0007517	total: 662ms	remaining: 132ms
# 834:	learn: 0.0007507	total: 663ms	remaining: 131ms
# 835:	learn: 0.0007498	total: 663ms	remaining: 130ms
# 836:	learn: 0.0007488	total: 664ms	remaining: 129ms
# 837:	learn: 0.0007478	total: 665ms	remaining: 128ms
# 838:	learn: 0.0007469	total: 665ms	remaining: 128ms
# 839:	learn: 0.0007459	total: 666ms	remaining: 127ms
# 840:	learn: 0.0007449	total: 667ms	remaining: 126ms
# 841:	learn: 0.0007439	total: 667ms	remaining: 125ms
# 842:	learn: 0.0007431	total: 668ms	remaining: 124ms
# 843:	learn: 0.0007420	total: 669ms	remaining: 124ms
# 844:	learn: 0.0007411	total: 669ms	remaining: 123ms
# 845:	learn: 0.0007401	total: 670ms	remaining: 122ms
# 846:	learn: 0.0007391	total: 671ms	remaining: 121ms
# 847:	learn: 0.0007381	total: 671ms	remaining: 120ms
# 848:	learn: 0.0007372	total: 672ms	remaining: 120ms
# 849:	learn: 0.0007362	total: 673ms	remaining: 119ms
# 850:	learn: 0.0007348	total: 673ms	remaining: 118ms
# 851:	learn: 0.0007338	total: 674ms	remaining: 117ms
# 852:	learn: 0.0007326	total: 675ms	remaining: 116ms
# 853:	learn: 0.0007317	total: 675ms	remaining: 115ms
# 854:	learn: 0.0007309	total: 676ms	remaining: 115ms
# 855:	learn: 0.0007298	total: 677ms	remaining: 114ms
# 856:	learn: 0.0007288	total: 677ms	remaining: 113ms
# 857:	learn: 0.0007279	total: 678ms	remaining: 112ms
# 858:	learn: 0.0007271	total: 679ms	remaining: 111ms
# 859:	learn: 0.0007262	total: 679ms	remaining: 111ms
# 860:	learn: 0.0007254	total: 680ms	remaining: 110ms
# 861:	learn: 0.0007245	total: 681ms	remaining: 109ms
# 862:	learn: 0.0007234	total: 681ms	remaining: 108ms
# 863:	learn: 0.0007225	total: 682ms	remaining: 107ms
# 864:	learn: 0.0007214	total: 683ms	remaining: 107ms
# 865:	learn: 0.0007207	total: 683ms	remaining: 106ms
# 866:	learn: 0.0007198	total: 684ms	remaining: 105ms
# 867:	learn: 0.0007187	total: 685ms	remaining: 104ms
# 868:	learn: 0.0007176	total: 685ms	remaining: 103ms
# 869:	learn: 0.0007167	total: 686ms	remaining: 102ms
# 870:	learn: 0.0007158	total: 687ms	remaining: 102ms
# 871:	learn: 0.0007148	total: 687ms	remaining: 101ms
# 872:	learn: 0.0007140	total: 688ms	remaining: 100ms
# 873:	learn: 0.0007133	total: 689ms	remaining: 99.3ms
# 874:	learn: 0.0007124	total: 689ms	remaining: 98.5ms
# 875:	learn: 0.0007115	total: 690ms	remaining: 97.6ms
# 876:	learn: 0.0007107	total: 690ms	remaining: 96.8ms
# 877:	learn: 0.0007098	total: 691ms	remaining: 96ms
# 878:	learn: 0.0007091	total: 692ms	remaining: 95.2ms
# 879:	learn: 0.0007083	total: 692ms	remaining: 94.4ms
# 880:	learn: 0.0007075	total: 693ms	remaining: 93.6ms
# 881:	learn: 0.0007067	total: 694ms	remaining: 92.8ms
# 882:	learn: 0.0007059	total: 694ms	remaining: 92ms
# 883:	learn: 0.0007052	total: 695ms	remaining: 91.2ms
# 884:	learn: 0.0007043	total: 696ms	remaining: 90.4ms
# 885:	learn: 0.0007036	total: 696ms	remaining: 89.6ms
# 886:	learn: 0.0007026	total: 697ms	remaining: 88.8ms
# 887:	learn: 0.0007018	total: 698ms	remaining: 88ms
# 888:	learn: 0.0007008	total: 698ms	remaining: 87.2ms
# 889:	learn: 0.0006999	total: 699ms	remaining: 86.4ms
# 890:	learn: 0.0006991	total: 700ms	remaining: 85.6ms
# 891:	learn: 0.0006981	total: 700ms	remaining: 84.8ms
# 892:	learn: 0.0006974	total: 701ms	remaining: 84ms
# 893:	learn: 0.0006965	total: 702ms	remaining: 83.2ms
# 894:	learn: 0.0006956	total: 703ms	remaining: 82.4ms
# 895:	learn: 0.0006947	total: 703ms	remaining: 81.6ms
# 896:	learn: 0.0006940	total: 704ms	remaining: 80.8ms
# 897:	learn: 0.0006932	total: 704ms	remaining: 80ms
# 898:	learn: 0.0006922	total: 705ms	remaining: 79.2ms
# 899:	learn: 0.0006915	total: 706ms	remaining: 78.4ms
# 900:	learn: 0.0006905	total: 706ms	remaining: 77.6ms
# 901:	learn: 0.0006897	total: 707ms	remaining: 76.8ms
# 902:	learn: 0.0006888	total: 708ms	remaining: 76ms
# 903:	learn: 0.0006878	total: 708ms	remaining: 75.2ms
# 904:	learn: 0.0006869	total: 709ms	remaining: 74.4ms
# 905:	learn: 0.0006861	total: 710ms	remaining: 73.6ms
# 906:	learn: 0.0006854	total: 710ms	remaining: 72.8ms
# 907:	learn: 0.0006844	total: 711ms	remaining: 72ms
# 908:	learn: 0.0006837	total: 712ms	remaining: 71.3ms
# 909:	learn: 0.0006828	total: 712ms	remaining: 70.5ms
# 910:	learn: 0.0006819	total: 713ms	remaining: 69.7ms
# 911:	learn: 0.0006810	total: 714ms	remaining: 68.9ms
# 912:	learn: 0.0006802	total: 714ms	remaining: 68.1ms
# 913:	learn: 0.0006793	total: 715ms	remaining: 67.3ms
# 914:	learn: 0.0006785	total: 716ms	remaining: 66.5ms
# 915:	learn: 0.0006775	total: 716ms	remaining: 65.7ms
# 916:	learn: 0.0006769	total: 717ms	remaining: 64.9ms
# 917:	learn: 0.0006760	total: 718ms	remaining: 64.1ms
# 918:	learn: 0.0006752	total: 719ms	remaining: 63.3ms
# 919:	learn: 0.0006745	total: 719ms	remaining: 62.5ms
# 920:	learn: 0.0006737	total: 720ms	remaining: 61.7ms
# 921:	learn: 0.0006731	total: 720ms	remaining: 60.9ms
# 922:	learn: 0.0006723	total: 721ms	remaining: 60.2ms
# 923:	learn: 0.0006715	total: 722ms	remaining: 59.4ms
# 924:	learn: 0.0006707	total: 722ms	remaining: 58.6ms
# 925:	learn: 0.0006698	total: 723ms	remaining: 57.8ms
# 926:	learn: 0.0006690	total: 724ms	remaining: 57ms
# 927:	learn: 0.0006681	total: 724ms	remaining: 56.2ms
# 928:	learn: 0.0006673	total: 725ms	remaining: 55.4ms
# 929:	learn: 0.0006665	total: 726ms	remaining: 54.6ms
# 930:	learn: 0.0006657	total: 726ms	remaining: 53.8ms
# 931:	learn: 0.0006648	total: 727ms	remaining: 53ms
# 932:	learn: 0.0006641	total: 728ms	remaining: 52.3ms
# 933:	learn: 0.0006633	total: 728ms	remaining: 51.5ms
# 934:	learn: 0.0006623	total: 729ms	remaining: 50.7ms
# 935:	learn: 0.0006614	total: 730ms	remaining: 49.9ms
# 936:	learn: 0.0006607	total: 730ms	remaining: 49.1ms
# 937:	learn: 0.0006598	total: 731ms	remaining: 48.3ms
# 938:	learn: 0.0006591	total: 732ms	remaining: 47.5ms
# 939:	learn: 0.0006584	total: 732ms	remaining: 46.8ms
# 940:	learn: 0.0006576	total: 733ms	remaining: 46ms
# 941:	learn: 0.0006568	total: 734ms	remaining: 45.2ms
# 942:	learn: 0.0006562	total: 734ms	remaining: 44.4ms
# 943:	learn: 0.0006556	total: 735ms	remaining: 43.6ms
# 944:	learn: 0.0006547	total: 736ms	remaining: 42.8ms
# 945:	learn: 0.0006539	total: 736ms	remaining: 42ms
# 946:	learn: 0.0006531	total: 737ms	remaining: 41.2ms
# 947:	learn: 0.0006524	total: 738ms	remaining: 40.5ms
# 948:	learn: 0.0006516	total: 738ms	remaining: 39.7ms
# 949:	learn: 0.0006507	total: 739ms	remaining: 38.9ms
# 950:	learn: 0.0006500	total: 740ms	remaining: 38.1ms
# 951:	learn: 0.0006489	total: 740ms	remaining: 37.3ms
# 952:	learn: 0.0006483	total: 741ms	remaining: 36.5ms
# 953:	learn: 0.0006476	total: 742ms	remaining: 35.8ms
# 954:	learn: 0.0006468	total: 742ms	remaining: 35ms
# 955:	learn: 0.0006462	total: 743ms	remaining: 34.2ms
# 956:	learn: 0.0006454	total: 744ms	remaining: 33.4ms
# 957:	learn: 0.0006447	total: 744ms	remaining: 32.6ms
# 958:	learn: 0.0006440	total: 745ms	remaining: 31.8ms
# 959:	learn: 0.0006433	total: 746ms	remaining: 31.1ms
# 960:	learn: 0.0006426	total: 746ms	remaining: 30.3ms
# 961:	learn: 0.0006419	total: 747ms	remaining: 29.5ms
# 962:	learn: 0.0006411	total: 748ms	remaining: 28.7ms
# 963:	learn: 0.0006404	total: 748ms	remaining: 27.9ms
# 964:	learn: 0.0006397	total: 749ms	remaining: 27.2ms
# 965:	learn: 0.0006389	total: 750ms	remaining: 26.4ms
# 966:	learn: 0.0006381	total: 750ms	remaining: 25.6ms
# 967:	learn: 0.0006375	total: 751ms	remaining: 24.8ms
# 968:	learn: 0.0006368	total: 752ms	remaining: 24ms
# 969:	learn: 0.0006361	total: 752ms	remaining: 23.3ms
# 970:	learn: 0.0006354	total: 753ms	remaining: 22.5ms
# 971:	learn: 0.0006347	total: 754ms	remaining: 21.7ms
# 972:	learn: 0.0006341	total: 754ms	remaining: 20.9ms
# 973:	learn: 0.0006334	total: 755ms	remaining: 20.2ms
# 974:	learn: 0.0006327	total: 756ms	remaining: 19.4ms
# 975:	learn: 0.0006320	total: 756ms	remaining: 18.6ms
# 976:	learn: 0.0006314	total: 757ms	remaining: 17.8ms
# 977:	learn: 0.0006308	total: 758ms	remaining: 17ms
# 978:	learn: 0.0006300	total: 758ms	remaining: 16.3ms
# 979:	learn: 0.0006293	total: 759ms	remaining: 15.5ms
# 980:	learn: 0.0006287	total: 760ms	remaining: 14.7ms
# 981:	learn: 0.0006281	total: 760ms	remaining: 13.9ms
# 982:	learn: 0.0006274	total: 761ms	remaining: 13.2ms
# 983:	learn: 0.0006266	total: 762ms	remaining: 12.4ms
# 984:	learn: 0.0006261	total: 762ms	remaining: 11.6ms
# 985:	learn: 0.0006254	total: 763ms	remaining: 10.8ms
# 986:	learn: 0.0006245	total: 764ms	remaining: 10.1ms
# 987:	learn: 0.0006239	total: 764ms	remaining: 9.28ms
# 988:	learn: 0.0006233	total: 765ms	remaining: 8.51ms
# 989:	learn: 0.0006226	total: 766ms	remaining: 7.73ms
# 990:	learn: 0.0006219	total: 766ms	remaining: 6.96ms
# 991:	learn: 0.0006212	total: 767ms	remaining: 6.18ms
# 992:	learn: 0.0006204	total: 768ms	remaining: 5.41ms
# 993:	learn: 0.0006198	total: 768ms	remaining: 4.64ms
# 994:	learn: 0.0006190	total: 769ms	remaining: 3.86ms
# 995:	learn: 0.0006185	total: 770ms	remaining: 3.09ms
# 996:	learn: 0.0006178	total: 770ms	remaining: 2.32ms
# 997:	learn: 0.0006171	total: 771ms	remaining: 1.54ms
# 998:	learn: 0.0006164	total: 772ms	remaining: 772us
# 999:	learn: 0.0006158	total: 772ms	remaining: 0us
# {'features_list': 'Seleccion voting', 'model': 'Catboost', 'avg. recall': np.float64(1.0)}
#                    features_list            model  avg. recall
# 0          Seleccion estadistico    Random Forest     1.000000
# 2          Seleccion estadistico   Decission Tree     1.000000
# 8   Seleccion mutual information   Decission Tree     1.000000
# 4          Seleccion estadistico         LightGBM     1.000000
# 5          Seleccion estadistico         Catboost     1.000000
# 6   Seleccion mutual information    Random Forest     1.000000
# 13              Seleccion manual              KNN     1.000000
# 12              Seleccion manual    Random Forest     1.000000
# 11  Seleccion mutual information         Catboost     1.000000
# 10  Seleccion mutual information         LightGBM     1.000000
# 41              Seleccion voting         Catboost     1.000000
# 40              Seleccion voting         LightGBM     1.000000
# 29                 Seleccion rfe         Catboost     1.000000
# 30                 Seleccion sfs    Random Forest     1.000000
# 14              Seleccion manual   Decission Tree     1.000000
# 16              Seleccion manual         LightGBM     1.000000
# 17              Seleccion manual         Catboost     1.000000
# 18              Seleccion modelo    Random Forest     1.000000
# 24                 Seleccion rfe    Random Forest     1.000000
# 19              Seleccion modelo              KNN     1.000000
# 20              Seleccion modelo   Decission Tree     1.000000
# 22              Seleccion modelo         LightGBM     1.000000
# 25                 Seleccion rfe              KNN     1.000000
# 23              Seleccion modelo         Catboost     1.000000
# 28                 Seleccion rfe         LightGBM     1.000000
# 26                 Seleccion rfe   Decission Tree     1.000000
# 38              Seleccion voting   Decission Tree     1.000000
# 37              Seleccion voting              KNN     1.000000
# 36              Seleccion voting    Random Forest     1.000000
# 35                 Seleccion sfs         Catboost     1.000000
# 32                 Seleccion sfs   Decission Tree     1.000000
# 34                 Seleccion sfs         LightGBM     0.998974
# 1          Seleccion estadistico              KNN     0.997740
# 7   Seleccion mutual information              KNN     0.996610
# 31                 Seleccion sfs              KNN     0.992509
# 15              Seleccion manual         AdaBoost     0.971352
# 21              Seleccion modelo         AdaBoost     0.971352
# 9   Seleccion mutual information         AdaBoost     0.970753
# 39              Seleccion voting         AdaBoost     0.970326
# 27                 Seleccion rfe         AdaBoost     0.970326
# 3          Seleccion estadistico         AdaBoost     0.961181
# 33                 Seleccion sfs         AdaBoost     0.951992

# %%
# Hay muchos que me dan 1, lo que me lleva a pensar que están sobreajustados, asi que voy a quedarme por ahora con lgbm y la seleccion de SFS, y también con KNN seleccion stadistica

# %%
# Voy a hacer el crossvalidation con la regresion lineal y el SVC

nombres = [f"Seleccion {nombre}" for nombre in ["estadistico", "mutual information", "manual", "modelo", "rfe", "sfs", "voting"]]
model_names_scaled = ["Logistic Regressor", "SVC"]

lr_clf = LogisticRegression(class_weight= "balanced", random_state= 42)
SVC_clf = SVC (class_weight = "balanced", random_state = 42)

models_scaled = [lr_clf, SVC_clf]
resultados_scaled = []

for indice, lista in enumerate([features_stad, features_mi, features_manual, features_modelo, features_RFE, features_SFS, features_hard_voting]):
    X_train_modelos_2 = X_train_scalado[lista]
    y_train_modelos_2 = train_set[target]
    
    for model_name_scaled, modelo in zip(model_names_scaled, models_scaled):
        metrica = np.mean(cross_val_score(modelo, X_train_modelos_2, y_train_modelos_2, cv = 5, scoring = "balanced_accuracy"))
        data = {
            "features_list": nombres[indice],
            "model": model_name_scaled,
            "avg. recall": metrica
        }
        print(data)
        resultados_scaled.append(data.copy())
df_resultados_scaled = pd.DataFrame(resultados_scaled)
df_resultados_scaled.sort_values("avg. recall", ascending = False)
# Out:
# {'features_list': 'Seleccion estadistico', 'model': 'Logistic Regressor', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion estadistico', 'model': 'SVC', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion mutual information', 'model': 'Logistic Regressor', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion mutual information', 'model': 'SVC', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion manual', 'model': 'Logistic Regressor', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion manual', 'model': 'SVC', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion modelo', 'model': 'Logistic Regressor', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion modelo', 'model': 'SVC', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion rfe', 'model': 'Logistic Regressor', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion rfe', 'model': 'SVC', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion sfs', 'model': 'Logistic Regressor', 'avg. recall': np.float64(0.9585605224373428)}
# {'features_list': 'Seleccion sfs', 'model': 'SVC', 'avg. recall': np.float64(0.9907146583202922)}
# {'features_list': 'Seleccion voting', 'model': 'Logistic Regressor', 'avg. recall': np.float64(1.0)}
# {'features_list': 'Seleccion voting', 'model': 'SVC', 'avg. recall': np.float64(1.0)}
#                    features_list               model  avg. recall
# 0          Seleccion estadistico  Logistic Regressor     1.000000
# 1          Seleccion estadistico                 SVC     1.000000
# 2   Seleccion mutual information  Logistic Regressor     1.000000
# 3   Seleccion mutual information                 SVC     1.000000
# 4               Seleccion manual  Logistic Regressor     1.000000
# 5               Seleccion manual                 SVC     1.000000
# 6               Seleccion modelo  Logistic Regressor     1.000000
# 7               Seleccion modelo                 SVC     1.000000
# 8                  Seleccion rfe  Logistic Regressor     1.000000
# 9                  Seleccion rfe                 SVC     1.000000
# 13              Seleccion voting                 SVC     1.000000
# 12              Seleccion voting  Logistic Regressor     1.000000
# 11                 Seleccion sfs                 SVC     0.990715
# 10                 Seleccion sfs  Logistic Regressor     0.958561

# %%
# Con los escalados también me dan muy buenas métricas, estará sobre ajustado????

# %%
# Con cual quedarme?? Pues por simplicidad me deberia quedar con El randomm forest (selección estadictica), el regresor logístico (selección estadistica) y el deccison tree (selección estadistica)

# %%
# Ajustando los hiperparámetros
# Random forest

params={'criterion':['gini','entropy'],'min_samples_split':list(np.arange(2,41)),'min_samples_leaf':list(np.arange(2,41)),
        'max_features':['sqrt','log2',None],'n_estimators':[1000]}
rf_optimizado=RandomizedSearchCV(rf_clf, param_distributions = params,scoring = 'accuracy', random_state = 42, n_jobs = -1, cv = 10)
rf_optimizado.fit(X_train[features_stad],y_train)
print(rf_optimizado.best_params_)
print(rf_optimizado.best_score_)
nrf = rf_optimizado.best_estimator_
# Out:
# {'n_estimators': 1000, 'min_samples_split': np.int64(6), 'min_samples_leaf': np.int64(18), 'max_features': 'sqrt', 'criterion': 'entropy'}
# 1.0

# %%
# Voy a optimizar el regresor lineal manualmente
dual=[True,False]
max_iter=[100,110,120,130,140]
param_grid = dict(dual=dual,max_iter=max_iter)

lr_clf_optimizado = GridSearchCV(estimator=lr_clf, param_grid=param_grid, cv = 10, n_jobs=-1)
grid_result = lr_clf_optimizado.fit(X_train_scalado[features_stad], y_train)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 1.000000 using {'dual': False, 'max_iter': 100}
# /Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 50 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py", line 68, in _check_solver
#     raise ValueError(f"Solver {solver} supports only dual=False, got dual={dual}")
# ValueError: Solver lbfgs supports only dual=False, got dual=True
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan  1.  1.  1.  1.  1.]
#   warnings.warn(

# %%
# Voy a aoptimizrla de manera aleatoria
random = RandomizedSearchCV(estimator=lr_clf, param_distributions=param_grid, cv = 10, n_jobs=-1)

random_result = random.fit(X_train_scalado[features_stad], y_train)
print("Best: %f using %s" % (random_result.best_score_, random_result.best_params_))
# Out:
# Best: 1.000000 using {'max_iter': 100, 'dual': False}
# /Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 50 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py", line 68, in _check_solver
#     raise ValueError(f"Solver {solver} supports only dual=False, got dual={dual}")
# ValueError: Solver lbfgs supports only dual=False, got dual=True
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/lauragarcia/.local/share/virtualenvs/lauragarcia-3NpKiQeF/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan  1.  1.  1.  1.  1.]
#   warnings.warn(

# %%
# Por últimoo voy a optimizar el Decission Tree
params={'criterion':['gini','entropy'],'min_samples_split':list(np.arange(2,51)),'min_samples_leaf':list(np.arange(2,51)),
        'max_features':['sqrt','log2',None]}
dt_optimizado = RandomizedSearchCV(dt_clf,param_distributions=params,scoring='accuracy',random_state=42,n_jobs=-1,cv=10)
dt_optimizado.fit(X_train[features_stad],y_train)
print(dt_optimizado.best_params_)
print(dt_optimizado.best_score_)
ndt=dt_optimizado.best_estimator_
# Out:
# {'min_samples_split': np.int64(20), 'min_samples_leaf': np.int64(3), 'max_features': 'sqrt', 'criterion': 'entropy'}
# 1.0

# %%
# Voy a evaluar contra test

# %%
# Voy a guardar valores para luego hacer matrices de confusion
cm_t=[] # almacen para matriiz de confusion para training set
cm=[] # almacén para matriz de confusión para test set

# %%
# Primero el Ramdom Forest
pred_train = nrf.predict(X_train[features_stad])
y_pred = nrf.predict(X_test[features_stad])
print(classification_report(y_test, y_pred))

cmrf_t=confusion_matrix(y_train, pred_train)
cm_t.append(cmrf_t)
cmrf=confusion_matrix(y_test, y_pred)
cm.append(cmrf)
# Out:
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00         7
#          Low       1.00      1.00      1.00         6
#       Medium       1.00      1.00      1.00         7
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %%
# Sobre el regresor lineal 
pred_train_2 = grid_result.predict(X_train_scalado[features_stad])
y_pred_2 = grid_result.predict(X_test_scalado[features_stad])
print(classification_report(y_test, y_pred_2))

cmrf_t_2 = confusion_matrix(y_train, pred_train_2)
cm_t.append(cmrf_t_2)
cmrf_2=confusion_matrix(y_test, y_pred_2)
cm.append(cmrf_2)
# Out:
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00         7
#          Low       1.00      1.00      1.00         6
#       Medium       1.00      1.00      1.00         7
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %%
# Sobre regresor lineal aleatorio
pred_train_3 = random_result.predict(X_train_scalado[features_stad])
y_pred_3 = random_result.predict(X_test_scalado[features_stad])
print(classification_report(y_test, y_pred_3))

cmrf_t_3 = confusion_matrix(y_train, pred_train_3)
cm_t.append(cmrf_t_3)
cmrf_3=confusion_matrix(y_test, y_pred_3)
cm.append(cmrf_3)
# Out:
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00         7
#          Low       1.00      1.00      1.00         6
#       Medium       1.00      1.00      1.00         7
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %%
# Sobre Deccision Tree
pred_train_4 = ndt.predict(X_train[features_stad])
y_pred_4 = ndt.predict(X_test[features_stad])
print(classification_report(y_test, y_pred_4))

cmrf_t_4 = confusion_matrix(y_train, pred_train_4)
cm_t.append(cmrf_t_4)
cmrf_4 = confusion_matrix(y_test, y_pred_4)
cm.append(cmrf_4)
# Out:
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00         7
#          Low       1.00      1.00      1.00         6
#       Medium       1.00      1.00      1.00         7
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %%
# matrices de confusion para ls modelos de entrenamiento
modelos =['Random Forest Classifier', 'Logistic Regressor manual', 'Logistic Regressor random', 'Decision Tree Classifier']
labels=['Low','Medium','High']
fig,ax=plt.subplots(2,2,figsize=(15,5))
r=0
c=0
for i, model in enumerate(modelos):
    sns.heatmap(cm_t[i],annot=True,fmt='d',ax=ax[r][c],xticklabels=labels,yticklabels=labels)
    ax[r][c].set_title(model)
    c+=1
    if(c==2):
        r+=1
        c=0
plt.suptitle('Confusion Matrices for Models on Training Set')
plt.tight_layout()
plt.show()

# %%
# matrices de confusion para ls modelos de test
modelos =['Random Forest Classifier', 'Logistic Regressor manual', 'Logistic Regressor random', 'Decision Tree Classifier']
labels=['Low','Medium','High']
fig,ax=plt.subplots(2,2,figsize=(15,5))
r=0
c=0
for i, model in enumerate(modelos):
    sns.heatmap(cm[i],annot=True,fmt='d',ax=ax[r][c],xticklabels=labels,yticklabels=labels)
    ax[r][c].set_title(model)
    c+=1
    if(c==2):
        r+=1
        c=0
plt.suptitle('Confusion Matrices for Models on Test Set')
plt.tight_layout()
plt.show()

# %%
# Conclusiones: cualquiera de los tres modelos con sus hiperparámetros optimizados o incluso sin optimizar dar muy buenos resultados
